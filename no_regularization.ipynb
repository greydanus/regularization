# %% [markdown]
# # No Regularization

# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

import time
import cPickle as pickle
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Model baseline

# %%
batch_size = 32
global_step = 0
save_path = 'models/noreg.ckpt'
xlen = 28*28
ylen = 10

train_steps = 150000
info_every = 250
test_every = 1000

# %% [markdown]
# ## Build model

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()

x = tf.placeholder(tf.float32, shape=[None, xlen], name="x")
y_ = tf.placeholder(tf.float32, shape=[None, ylen], name="y_")
init = tf.truncated_normal_initializer(mean=0., stddev=.075, seed=1234, dtype=tf.float32)

W = tf.get_variable("W", shape=[xlen,ylen], initializer=init)
output = tf.nn.softmax(tf.matmul(x, W))

# %%
loss = tf.nn.l2_loss( y_ - output ) / (ylen*batch_size)

optimizer = tf.train.AdamOptimizer(1e-4)
grads = optimizer.compute_gradients(loss, var_list=tf.trainable_variables())
train_op = optimizer.apply_gradients(grads)

sess.run(tf.initialize_all_variables())

# %% [markdown]
# ## Model overview

# %%
total_parameters = 0 ; print "Model overview:"
for variable in tf.trainable_variables():
    shape = variable.get_shape()
    variable_parameters = 1
    for dim in shape:
        variable_parameters *= dim.value
    print '\tvariable "{}" has {} parameters' \
        .format(variable.name, variable_parameters)
    total_parameters += variable_parameters
print "Total of {} parameters".format(total_parameters)
# Out:
# Model overview:
# 	variable "W:0" has 7840 parameters
# Total of 7840 parameters

# %% [markdown]
# ## Train

# %%
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
loss_curve = np.zeros((train_steps/info_every, 2))
acc_curve = np.zeros((train_steps/test_every, 2))

begin = time.time()
for i in range(train_steps):
    batch_start = time.time()
    
    batch = mnist.train.next_batch(batch_size)
    feed = {x: batch[0], y_: batch[1]}
    train_loss, _ = sess.run([loss, train_op], feed_dict=feed)
    
    if i%test_every == 0:
        feed = {x: mnist.test.images, y_: mnist.test.labels}
        acc = accuracy.eval(feed_dict=feed)
        acc_curve[i/test_every,:] = [i, acc]
        print "{}/{}: test accuracy: {:3f}".format(i, train_steps, acc)
    if i%info_every == 0:
        loss_curve[i/info_every,:] = [i, train_loss]
        print "\tstep {}, loss {:3f}, batch time {:3f}".format(i, train_loss, time.time()-batch_start)
print "\ntotal runtime: {:3f} seconds".format(time.time()-begin)
# Out:
# 0/150000: test accuracy: 0.121500
# 	step 0, loss 0.047250, batch time 0.049372
# 	step 250, loss 0.036354, batch time 0.000668
# 	step 500, loss 0.031989, batch time 0.000880
# 	step 750, loss 0.024198, batch time 0.000962
# 1000/150000: test accuracy: 0.821600
# 	step 1000, loss 0.015752, batch time 0.036811
# 	step 1250, loss 0.018305, batch time 0.000935
# 	step 1500, loss 0.014666, batch time 0.000715
# 	step 1750, loss 0.014514, batch time 0.000986
# 2000/150000: test accuracy: 0.863900
# 	step 2000, loss 0.014796, batch time 0.035221
# 	step 2250, loss 0.018415, batch time 0.000685
# 	step 2500, loss 0.018568, batch time 0.000769
# 	step 2750, loss 0.008733, batch time 0.000685
# 3000/150000: test accuracy: 0.881700
# 	step 3000, loss 0.011372, batch time 0.034031
# 	step 3250, loss 0.008817, batch time 0.000752
# 	step 3500, loss 0.009559, batch time 0.000956
# 	step 3750, loss 0.009465, batch time 0.000743
# 4000/150000: test accuracy: 0.891500
# 	step 4000, loss 0.009896, batch time 0.034833
# 	step 4250, loss 0.009538, batch time 0.001075
# 	step 4500, loss 0.011225, batch time 0.000737
# 	step 4750, loss 0.014324, batch time 0.000638
# 5000/150000: test accuracy: 0.898100
# 	step 5000, loss 0.009414, batch time 0.033483
# 	step 5250, loss 0.010386, batch time 0.000987
# 	step 5500, loss 0.006228, batch time 0.000826
# 	step 5750, loss 0.009884, batch time 0.000648
# 6000/150000: test accuracy: 0.903700
# 	step 6000, loss 0.011863, batch time 0.042272
# 	step 6250, loss 0.009177, batch time 0.000649
# 	step 6500, loss 0.009785, batch time 0.001014
# 	step 6750, loss 0.002974, batch time 0.000890
# 7000/150000: test accuracy: 0.906400
# 	step 7000, loss 0.011515, batch time 0.042684
# 	step 7250, loss 0.005628, batch time 0.000863
# 	step 7500, loss 0.005370, batch time 0.001045
# 	step 7750, loss 0.008415, batch time 0.000684
# 8000/150000: test accuracy: 0.910100
# 	step 8000, loss 0.007991, batch time 0.033127
# 	step 8250, loss 0.011874, batch time 0.000667
# 	step 8500, loss 0.005919, batch time 0.001078
# 	step 8750, loss 0.007127, batch time 0.000686
# 9000/150000: test accuracy: 0.912100
# 	step 9000, loss 0.010337, batch time 0.036774
# 	step 9250, loss 0.008565, batch time 0.000879
# 	step 9500, loss 0.009813, batch time 0.000878
# 	step 9750, loss 0.012030, batch time 0.000788
# 10000/150000: test accuracy: 0.913800
# 	step 10000, loss 0.011884, batch time 0.034706
# 	step 10250, loss 0.005421, batch time 0.000771
# 	step 10500, loss 0.012812, batch time 0.001171
# 	step 10750, loss 0.011715, batch time 0.001172
# 11000/150000: test accuracy: 0.915300
# 	step 11000, loss 0.010636, batch time 0.034393
# 	step 11250, loss 0.005790, batch time 0.000991
# 	step 11500, loss 0.006129, batch time 0.001214
# 	step 11750, loss 0.006477, batch time 0.000771
# 12000/150000: test accuracy: 0.915700
# 	step 12000, loss 0.011768, batch time 0.034922
# 	step 12250, loss 0.009669, batch time 0.000784
# 	step 12500, loss 0.008531, batch time 0.000685
# 	step 12750, loss 0.003668, batch time 0.002043
# 13000/150000: test accuracy: 0.916200
# 	step 13000, loss 0.010330, batch time 0.036371
# 	step 13250, loss 0.006628, batch time 0.000679
# 	step 13500, loss 0.008725, batch time 0.000691
# 	step 13750, loss 0.006850, batch time 0.000780
# 14000/150000: test accuracy: 0.918600
# 	step 14000, loss 0.010464, batch time 0.034385
# 	step 14250, loss 0.005992, batch time 0.000896
# 	step 14500, loss 0.008435, batch time 0.000698
# 	step 14750, loss 0.009239, batch time 0.000831
# 15000/150000: test accuracy: 0.918500
# 	step 15000, loss 0.004722, batch time 0.034762
# 	step 15250, loss 0.005358, batch time 0.000930
# 	step 15500, loss 0.005658, batch time 0.000780
# 	step 15750, loss 0.008591, batch time 0.000776
# 16000/150000: test accuracy: 0.919000
# 	step 16000, loss 0.004926, batch time 0.037354
# 	step 16250, loss 0.002448, batch time 0.000679
# 	step 16500, loss 0.003103, batch time 0.000985
# 	step 16750, loss 0.002838, batch time 0.000688
# 17000/150000: test accuracy: 0.921000
# 	step 17000, loss 0.006730, batch time 0.035983
# 	step 17250, loss 0.002993, batch time 0.000655
# 	step 17500, loss 0.007534, batch time 0.000979
# 	step 17750, loss 0.007284, batch time 0.000691
# 18000/150000: test accuracy: 0.920400
# 	step 18000, loss 0.004625, batch time 0.035876
# 	step 18250, loss 0.002962, batch time 0.000813
# 	step 18500, loss 0.003963, batch time 0.000677
# 	step 18750, loss 0.005627, batch time 0.000749
# 19000/150000: test accuracy: 0.921900
# 	step 19000, loss 0.004158, batch time 0.033905
# 	step 19250, loss 0.005579, batch time 0.000850
# 	step 19500, loss 0.012206, batch time 0.000649
# 	step 19750, loss 0.006935, batch time 0.000775
# 20000/150000: test accuracy: 0.921900
# 	step 20000, loss 0.004550, batch time 0.033305
# 	step 20250, loss 0.006482, batch time 0.000780
# 	step 20500, loss 0.004675, batch time 0.000878
# 	step 20750, loss 0.008397, batch time 0.002055
# 21000/150000: test accuracy: 0.922700
# 	step 21000, loss 0.008111, batch time 0.033012
# 	step 21250, loss 0.002709, batch time 0.000854
# 	step 21500, loss 0.011144, batch time 0.000700
# 	step 21750, loss 0.006315, batch time 0.000667
# 22000/150000: test accuracy: 0.923200
# 	step 22000, loss 0.011681, batch time 0.035145
# 	step 22250, loss 0.007560, batch time 0.000809
# 	step 22500, loss 0.005097, batch time 0.000784
# 	step 22750, loss 0.001944, batch time 0.000805
# 23000/150000: test accuracy: 0.923500
# 	step 23000, loss 0.003235, batch time 0.037976
# 	step 23250, loss 0.007544, batch time 0.000772
# 	step 23500, loss 0.000917, batch time 0.000885
# 	step 23750, loss 0.005050, batch time 0.000664
# 24000/150000: test accuracy: 0.924200
# 	step 24000, loss 0.008238, batch time 0.034138
# 	step 24250, loss 0.001694, batch time 0.000850
# 	step 24500, loss 0.007367, batch time 0.000852
# 	step 24750, loss 0.005407, batch time 0.000806
# 25000/150000: test accuracy: 0.924600
# 	step 25000, loss 0.006212, batch time 0.034510
# 	step 25250, loss 0.001924, batch time 0.000777
# 	step 25500, loss 0.005752, batch time 0.000830
# 	step 25750, loss 0.006873, batch time 0.000804
# 26000/150000: test accuracy: 0.924400
# 	step 26000, loss 0.006795, batch time 0.035218
# 	step 26250, loss 0.004690, batch time 0.000786
# 	step 26500, loss 0.004508, batch time 0.001041
# 	step 26750, loss 0.007564, batch time 0.000670
# 27000/150000: test accuracy: 0.924900
# 	step 27000, loss 0.002503, batch time 0.033004
# 	step 27250, loss 0.002530, batch time 0.000733
# 	step 27500, loss 0.000361, batch time 0.000755
# 	step 27750, loss 0.004421, batch time 0.000771
# 28000/150000: test accuracy: 0.925100
# 	step 28000, loss 0.004205, batch time 0.034579
# 	step 28250, loss 0.002197, batch time 0.000583
# 	step 28500, loss 0.004750, batch time 0.000721
# 	step 28750, loss 0.004127, batch time 0.000792
# 29000/150000: test accuracy: 0.926000
# 	step 29000, loss 0.002572, batch time 0.038158
# 	step 29250, loss 0.003574, batch time 0.001117
# 	step 29500, loss 0.004936, batch time 0.000746
# 	step 29750, loss 0.010703, batch time 0.000761
# 30000/150000: test accuracy: 0.925200
# 	step 30000, loss 0.001812, batch time 0.033490
# 	step 30250, loss 0.003604, batch time 0.000715
# 	step 30500, loss 0.009352, batch time 0.001089
# 	step 30750, loss 0.008377, batch time 0.001512
# 31000/150000: test accuracy: 0.926100
# 	step 31000, loss 0.001316, batch time 0.032803
# 	step 31250, loss 0.001179, batch time 0.000994
# 	step 31500, loss 0.003719, batch time 0.000926
# 	step 31750, loss 0.003463, batch time 0.000688
# 32000/150000: test accuracy: 0.926800
# 	step 32000, loss 0.005834, batch time 0.034531
# 	step 32250, loss 0.005602, batch time 0.000849
# 	step 32500, loss 0.004324, batch time 0.000864
# 	step 32750, loss 0.001790, batch time 0.000965
# 33000/150000: test accuracy: 0.926600
# 	step 33000, loss 0.003315, batch time 0.034184
# 	step 33250, loss 0.010063, batch time 0.000741
# 	step 33500, loss 0.005167, batch time 0.000835
# 	step 33750, loss 0.005199, batch time 0.000732
# 34000/150000: test accuracy: 0.926700
# 	step 34000, loss 0.007716, batch time 0.036745
# 	step 34250, loss 0.011065, batch time 0.000704
# 	step 34500, loss 0.009256, batch time 0.000810
# 	step 34750, loss 0.012879, batch time 0.000712
# 35000/150000: test accuracy: 0.927500
# 	step 35000, loss 0.006723, batch time 0.034774
# 	step 35250, loss 0.004952, batch time 0.000617
# 	step 35500, loss 0.004620, batch time 0.000816
# 	step 35750, loss 0.012555, batch time 0.000688
# 36000/150000: test accuracy: 0.926600
# 	step 36000, loss 0.009280, batch time 0.035542
# 	step 36250, loss 0.008880, batch time 0.000865
# 	step 36500, loss 0.004673, batch time 0.000907
# 	step 36750, loss 0.005451, batch time 0.000646
# 37000/150000: test accuracy: 0.927900
# 	step 37000, loss 0.001909, batch time 0.032343
# 	step 37250, loss 0.002350, batch time 0.000702
# 	step 37500, loss 0.002683, batch time 0.000828
# 	step 37750, loss 0.002321, batch time 0.000843
# 38000/150000: test accuracy: 0.927800
# 	step 38000, loss 0.004924, batch time 0.033488
# 	step 38250, loss 0.009345, batch time 0.000791
# 	step 38500, loss 0.011519, batch time 0.000692
# 	step 38750, loss 0.005294, batch time 0.000748
# 39000/150000: test accuracy: 0.928200
# 	step 39000, loss 0.003412, batch time 0.038286
# 	step 39250, loss 0.008812, batch time 0.000675
# 	step 39500, loss 0.003448, batch time 0.002122
# 	step 39750, loss 0.006725, batch time 0.000936
# 40000/150000: test accuracy: 0.927700
# 	step 40000, loss 0.008561, batch time 0.032175
# 	step 40250, loss 0.002343, batch time 0.000752
# 	step 40500, loss 0.002685, batch time 0.000812
# 	step 40750, loss 0.004970, batch time 0.000752
# 41000/150000: test accuracy: 0.927900
# 	step 41000, loss 0.008168, batch time 0.031387
# 	step 41250, loss 0.004841, batch time 0.000734
# 	step 41500, loss 0.002552, batch time 0.000759
# 	step 41750, loss 0.002087, batch time 0.000809
# 42000/150000: test accuracy: 0.928100
# 	step 42000, loss 0.003397, batch time 0.035394
# 	step 42250, loss 0.004802, batch time 0.000750
# 	step 42500, loss 0.004058, batch time 0.000712
# 	step 42750, loss 0.008041, batch time 0.000936
# 43000/150000: test accuracy: 0.928400
# 	step 43000, loss 0.008075, batch time 0.034329
# 	step 43250, loss 0.003250, batch time 0.000868
# 	step 43500, loss 0.003078, batch time 0.000665
# 	step 43750, loss 0.004728, batch time 0.000694
# 44000/150000: test accuracy: 0.928800
# 	step 44000, loss 0.010384, batch time 0.033531
# 	step 44250, loss 0.002778, batch time 0.000826
# 	step 44500, loss 0.001901, batch time 0.000668
# 	step 44750, loss 0.003310, batch time 0.002490
# 45000/150000: test accuracy: 0.928800
# 	step 45000, loss 0.004182, batch time 0.035061
# 	step 45250, loss 0.002279, batch time 0.000783
# 	step 45500, loss 0.001764, batch time 0.000729
# 	step 45750, loss 0.003927, batch time 0.000926
# 46000/150000: test accuracy: 0.929400
# 	step 46000, loss 0.004768, batch time 0.033327
# 	step 46250, loss 0.004495, batch time 0.000941
# 	step 46500, loss 0.002031, batch time 0.000653
# 	step 46750, loss 0.010394, batch time 0.002368
# 47000/150000: test accuracy: 0.929100
# 	step 47000, loss 0.007023, batch time 0.035303
# 	step 47250, loss 0.007252, batch time 0.000889
# 	step 47500, loss 0.004740, batch time 0.000784
# 	step 47750, loss 0.007244, batch time 0.000784
# 48000/150000: test accuracy: 0.929900
# 	step 48000, loss 0.004288, batch time 0.035646
# 	step 48250, loss 0.004677, batch time 0.000913
# 	step 48500, loss 0.005568, batch time 0.000720
# 	step 48750, loss 0.004081, batch time 0.001274
# 49000/150000: test accuracy: 0.930600
# 	step 49000, loss 0.001734, batch time 0.034149
# 	step 49250, loss 0.006428, batch time 0.001707
# 	step 49500, loss 0.003720, batch time 0.001138
# 	step 49750, loss 0.007636, batch time 0.000936
# 50000/150000: test accuracy: 0.930500
# 	step 50000, loss 0.003141, batch time 0.041398
# 	step 50250, loss 0.005604, batch time 0.000613
# 	step 50500, loss 0.003995, batch time 0.000840
# 	step 50750, loss 0.007669, batch time 0.000750
# 51000/150000: test accuracy: 0.928200
# 	step 51000, loss 0.007018, batch time 0.041105
# 	step 51250, loss 0.005040, batch time 0.000653
# 	step 51500, loss 0.002679, batch time 0.000737
# 	step 51750, loss 0.008060, batch time 0.000948
# 52000/150000: test accuracy: 0.930100
# 	step 52000, loss 0.001047, batch time 0.033306
# 	step 52250, loss 0.002792, batch time 0.000851
# 	step 52500, loss 0.008172, batch time 0.000632
# 	step 52750, loss 0.002654, batch time 0.000996
# 53000/150000: test accuracy: 0.929600
# 	step 53000, loss 0.010492, batch time 0.038348
# 	step 53250, loss 0.014499, batch time 0.000950
# 	step 53500, loss 0.005322, batch time 0.002764
# 	step 53750, loss 0.002640, batch time 0.000742
# 54000/150000: test accuracy: 0.930200
# 	step 54000, loss 0.004583, batch time 0.041986
# 	step 54250, loss 0.004265, batch time 0.001604
# 	step 54500, loss 0.001700, batch time 0.001149
# 	step 54750, loss 0.005414, batch time 0.000747
# 55000/150000: test accuracy: 0.931000
# 	step 55000, loss 0.003170, batch time 0.033089
# 	step 55250, loss 0.009361, batch time 0.000967
# 	step 55500, loss 0.010626, batch time 0.000715
# 	step 55750, loss 0.002384, batch time 0.000724
# 56000/150000: test accuracy: 0.930400
# 	step 56000, loss 0.007976, batch time 0.037379
# 	step 56250, loss 0.001939, batch time 0.000791
# 	step 56500, loss 0.005345, batch time 0.000700
# 	step 56750, loss 0.008156, batch time 0.000823
# 57000/150000: test accuracy: 0.930100
# 	step 57000, loss 0.004523, batch time 0.036584
# 	step 57250, loss 0.006814, batch time 0.000839
# 	step 57500, loss 0.002011, batch time 0.000768
# 	step 57750, loss 0.002115, batch time 0.000648
# 58000/150000: test accuracy: 0.929600
# 	step 58000, loss 0.003289, batch time 0.035361
# 	step 58250, loss 0.005162, batch time 0.000722
# 	step 58500, loss 0.010147, batch time 0.000819
# 	step 58750, loss 0.002677, batch time 0.000692
# 59000/150000: test accuracy: 0.929700
# 	step 59000, loss 0.006035, batch time 0.036687
# 	step 59250, loss 0.004758, batch time 0.000711
# 	step 59500, loss 0.002544, batch time 0.000842
# 	step 59750, loss 0.005154, batch time 0.000762
# 60000/150000: test accuracy: 0.930300
# 	step 60000, loss 0.014478, batch time 0.039100
# 	step 60250, loss 0.005294, batch time 0.000658
# 	step 60500, loss 0.005906, batch time 0.000754
# 	step 60750, loss 0.006600, batch time 0.001008
# 61000/150000: test accuracy: 0.930200
# 	step 61000, loss 0.006568, batch time 0.034845
# 	step 61250, loss 0.008607, batch time 0.000760
# 	step 61500, loss 0.006058, batch time 0.000738
# 	step 61750, loss 0.004149, batch time 0.000721
# 62000/150000: test accuracy: 0.930800
# 	step 62000, loss 0.006121, batch time 0.039691
# 	step 62250, loss 0.008261, batch time 0.000748
# 	step 62500, loss 0.004446, batch time 0.000777
# 	step 62750, loss 0.011879, batch time 0.000712
# 63000/150000: test accuracy: 0.930000
# 	step 63000, loss 0.001149, batch time 0.034513
# 	step 63250, loss 0.001172, batch time 0.000878
# 	step 63500, loss 0.004293, batch time 0.000730
# 	step 63750, loss 0.008456, batch time 0.000889
# 64000/150000: test accuracy: 0.930800
# 	step 64000, loss 0.003574, batch time 0.034245
# 	step 64250, loss 0.003272, batch time 0.000689
# 	step 64500, loss 0.007895, batch time 0.000656
# 	step 64750, loss 0.002286, batch time 0.000794
# 65000/150000: test accuracy: 0.930500
# 	step 65000, loss 0.006815, batch time 0.035132
# 	step 65250, loss 0.006893, batch time 0.000841
# 	step 65500, loss 0.017702, batch time 0.000814
# 	step 65750, loss 0.005355, batch time 0.000898
# 66000/150000: test accuracy: 0.931300
# 	step 66000, loss 0.009577, batch time 0.040328
# 	step 66250, loss 0.007864, batch time 0.001186
# 	step 66500, loss 0.005915, batch time 0.000727
# 	step 66750, loss 0.006438, batch time 0.000676
# 67000/150000: test accuracy: 0.931100
# 	step 67000, loss 0.004466, batch time 0.031789
# 	step 67250, loss 0.003507, batch time 0.000890
# 	step 67500, loss 0.012697, batch time 0.000803
# 	step 67750, loss 0.009135, batch time 0.000853
# 68000/150000: test accuracy: 0.931300
# 	step 68000, loss 0.005072, batch time 0.036479
# 	step 68250, loss 0.009884, batch time 0.000755
# 	step 68500, loss 0.005218, batch time 0.000707
# 	step 68750, loss 0.005964, batch time 0.000737
# 69000/150000: test accuracy: 0.931400
# 	step 69000, loss 0.008988, batch time 0.035691
# 	step 69250, loss 0.009675, batch time 0.000652
# 	step 69500, loss 0.001750, batch time 0.000725
# 	step 69750, loss 0.001896, batch time 0.000733
# 70000/150000: test accuracy: 0.930400
# 	step 70000, loss 0.006560, batch time 0.044099
# 	step 70250, loss 0.003770, batch time 0.001074
# 	step 70500, loss 0.005582, batch time 0.000793
# 	step 70750, loss 0.003518, batch time 0.000706
# 71000/150000: test accuracy: 0.931000
# 	step 71000, loss 0.004415, batch time 0.034513
# 	step 71250, loss 0.007402, batch time 0.000705
# 	step 71500, loss 0.004886, batch time 0.000780
# 	step 71750, loss 0.006294, batch time 0.000685
# 72000/150000: test accuracy: 0.932000
# 	step 72000, loss 0.002330, batch time 0.034046
# 	step 72250, loss 0.002236, batch time 0.000767
# 	step 72500, loss 0.002799, batch time 0.000749
# 	step 72750, loss 0.006269, batch time 0.000759
# 73000/150000: test accuracy: 0.931300
# 	step 73000, loss 0.005059, batch time 0.034050
# 	step 73250, loss 0.002919, batch time 0.000646
# 	step 73500, loss 0.010253, batch time 0.000712
# 	step 73750, loss 0.005986, batch time 0.001276
# 74000/150000: test accuracy: 0.931400
# 	step 74000, loss 0.003974, batch time 0.034135
# 	step 74250, loss 0.008189, batch time 0.000739
# 	step 74500, loss 0.003408, batch time 0.000789
# 	step 74750, loss 0.003565, batch time 0.000753
# 75000/150000: test accuracy: 0.931700
# 	step 75000, loss 0.008714, batch time 0.039674
# 	step 75250, loss 0.009938, batch time 0.000879
# 	step 75500, loss 0.005932, batch time 0.000766
# 	step 75750, loss 0.005302, batch time 0.000951
# 76000/150000: test accuracy: 0.931000
# 	step 76000, loss 0.003640, batch time 0.033390
# 	step 76250, loss 0.009432, batch time 0.004272
# 	step 76500, loss 0.006340, batch time 0.000908
# 	step 76750, loss 0.004147, batch time 0.000794
# 77000/150000: test accuracy: 0.931300
# 	step 77000, loss 0.003335, batch time 0.034360
# 	step 77250, loss 0.006508, batch time 0.000898
# 	step 77500, loss 0.006235, batch time 0.000946
# 	step 77750, loss 0.002647, batch time 0.000781
# 78000/150000: test accuracy: 0.931400
# 	step 78000, loss 0.003670, batch time 0.035647
# 	step 78250, loss 0.004251, batch time 0.000903
# 	step 78500, loss 0.002131, batch time 0.000744
# 	step 78750, loss 0.003960, batch time 0.000914
# 79000/150000: test accuracy: 0.931300
# 	step 79000, loss 0.004745, batch time 0.039766
# 	step 79250, loss 0.003910, batch time 0.000806
# 	step 79500, loss 0.007517, batch time 0.000729
# 	step 79750, loss 0.004203, batch time 0.000993
# 80000/150000: test accuracy: 0.931400
# 	step 80000, loss 0.003422, batch time 0.035853
# 	step 80250, loss 0.008040, batch time 0.000929
# 	step 80500, loss 0.012228, batch time 0.000692
# 	step 80750, loss 0.004539, batch time 0.000805
# 81000/150000: test accuracy: 0.930800
# 	step 81000, loss 0.003215, batch time 0.032462
# 	step 81250, loss 0.003909, batch time 0.000750
# 	step 81500, loss 0.005316, batch time 0.000993
# 	step 81750, loss 0.006806, batch time 0.000729
# 82000/150000: test accuracy: 0.931000
# 	step 82000, loss 0.005996, batch time 0.033020
# 	step 82250, loss 0.002493, batch time 0.000806
# 	step 82500, loss 0.007418, batch time 0.000836
# 	step 82750, loss 0.003852, batch time 0.000706
# 83000/150000: test accuracy: 0.931400
# 	step 83000, loss 0.001335, batch time 0.033951
# 	step 83250, loss 0.014174, batch time 0.000982
# 	step 83500, loss 0.002315, batch time 0.000775
# 	step 83750, loss 0.004914, batch time 0.000785
# 84000/150000: test accuracy: 0.930900
# 	step 84000, loss 0.002996, batch time 0.033840
# 	step 84250, loss 0.002633, batch time 0.000739
# 	step 84500, loss 0.005228, batch time 0.000744
# 	step 84750, loss 0.002644, batch time 0.000716
# 85000/150000: test accuracy: 0.930900
# 	step 85000, loss 0.009665, batch time 0.033142
# 	step 85250, loss 0.000775, batch time 0.000985
# 	step 85500, loss 0.002032, batch time 0.001078
# 	step 85750, loss 0.003509, batch time 0.000713
# 86000/150000: test accuracy: 0.931800
# 	step 86000, loss 0.001707, batch time 0.035977
# 	step 86250, loss 0.005518, batch time 0.000790
# 	step 86500, loss 0.004501, batch time 0.000834
# 	step 86750, loss 0.002769, batch time 0.000767
# 87000/150000: test accuracy: 0.931000
# 	step 87000, loss 0.003770, batch time 0.042436
# 	step 87250, loss 0.003176, batch time 0.000760
# 	step 87500, loss 0.008431, batch time 0.000882
# 	step 87750, loss 0.000399, batch time 0.000876
# 88000/150000: test accuracy: 0.931500
# 	step 88000, loss 0.002026, batch time 0.042691
# 	step 88250, loss 0.007109, batch time 0.000938
# 	step 88500, loss 0.002719, batch time 0.000944
# 	step 88750, loss 0.006703, batch time 0.000855
# 89000/150000: test accuracy: 0.931900
# 	step 89000, loss 0.006433, batch time 0.036085
# 	step 89250, loss 0.008614, batch time 0.000981
# 	step 89500, loss 0.005512, batch time 0.000921
# 	step 89750, loss 0.005087, batch time 0.000662
# 90000/150000: test accuracy: 0.931100
# 	step 90000, loss 0.006982, batch time 0.041831
# 	step 90250, loss 0.006705, batch time 0.000886
# 	step 90500, loss 0.004223, batch time 0.000744
# 	step 90750, loss 0.007470, batch time 0.000925
# 91000/150000: test accuracy: 0.932500
# 	step 91000, loss 0.004072, batch time 0.033797
# 	step 91250, loss 0.002405, batch time 0.000822
# 	step 91500, loss 0.005002, batch time 0.000661
# 	step 91750, loss 0.014518, batch time 0.001170
# 92000/150000: test accuracy: 0.931300
# 	step 92000, loss 0.000731, batch time 0.035438
# 	step 92250, loss 0.003770, batch time 0.000903
# 	step 92500, loss 0.006429, batch time 0.000648
# 	step 92750, loss 0.006025, batch time 0.000908
# 93000/150000: test accuracy: 0.931500
# 	step 93000, loss 0.004580, batch time 0.036501
# 	step 93250, loss 0.010817, batch time 0.000699
# 	step 93500, loss 0.004920, batch time 0.000925
# 	step 93750, loss 0.002008, batch time 0.000673
# 94000/150000: test accuracy: 0.931500
# 	step 94000, loss 0.001835, batch time 0.035213
# 	step 94250, loss 0.011025, batch time 0.000776
# 	step 94500, loss 0.001138, batch time 0.000974
# 	step 94750, loss 0.002884, batch time 0.000766
# 95000/150000: test accuracy: 0.931600
# 	step 95000, loss 0.005632, batch time 0.035050
# 	step 95250, loss 0.008517, batch time 0.000673
# 	step 95500, loss 0.004155, batch time 0.000781
# 	step 95750, loss 0.002428, batch time 0.000787
# 96000/150000: test accuracy: 0.931400
# 	step 96000, loss 0.006540, batch time 0.035257
# 	step 96250, loss 0.005081, batch time 0.000790
# 	step 96500, loss 0.004163, batch time 0.000744
# 	step 96750, loss 0.002856, batch time 0.000776
# 97000/150000: test accuracy: 0.931700
# 	step 97000, loss 0.003329, batch time 0.036758
# 	step 97250, loss 0.008225, batch time 0.000771
# 	step 97500, loss 0.001155, batch time 0.000771
# 	step 97750, loss 0.005751, batch time 0.000732
# 98000/150000: test accuracy: 0.931400
# 	step 98000, loss 0.001374, batch time 0.033027
# 	step 98250, loss 0.002785, batch time 0.000901
# 	step 98500, loss 0.007984, batch time 0.000782
# 	step 98750, loss 0.006936, batch time 0.000712
# 99000/150000: test accuracy: 0.931300
# 	step 99000, loss 0.011842, batch time 0.037953
# 	step 99250, loss 0.008110, batch time 0.001042
# 	step 99500, loss 0.003772, batch time 0.000979
# 	step 99750, loss 0.009867, batch time 0.000720
# 100000/150000: test accuracy: 0.931800
# 	step 100000, loss 0.005548, batch time 0.044794
# 	step 100250, loss 0.001021, batch time 0.001124
# 	step 100500, loss 0.010658, batch time 0.001444
# 	step 100750, loss 0.003614, batch time 0.000686
# 101000/150000: test accuracy: 0.931600
# 	step 101000, loss 0.003695, batch time 0.041013
# 	step 101250, loss 0.006698, batch time 0.001601
# 	step 101500, loss 0.008181, batch time 0.000670
# 	step 101750, loss 0.004883, batch time 0.000727
# 102000/150000: test accuracy: 0.932400
# 	step 102000, loss 0.007231, batch time 0.041158
# 	step 102250, loss 0.006723, batch time 0.000781
# 	step 102500, loss 0.002013, batch time 0.000742
# 	step 102750, loss 0.002993, batch time 0.000721
# 103000/150000: test accuracy: 0.931900
# 	step 103000, loss 0.005616, batch time 0.033410
# 	step 103250, loss 0.003906, batch time 0.001013
# 	step 103500, loss 0.004926, batch time 0.001651
# 	step 103750, loss 0.003881, batch time 0.000889
# 104000/150000: test accuracy: 0.931400
# 	step 104000, loss 0.003837, batch time 0.034493
# 	step 104250, loss 0.003270, batch time 0.001154
# 	step 104500, loss 0.009168, batch time 0.001035
# 	step 104750, loss 0.006695, batch time 0.000646
# 105000/150000: test accuracy: 0.931400
# 	step 105000, loss 0.002583, batch time 0.043543
# 	step 105250, loss 0.006357, batch time 0.000741
# 	step 105500, loss 0.003504, batch time 0.000842
# 	step 105750, loss 0.001434, batch time 0.001367
# 106000/150000: test accuracy: 0.931600
# 	step 106000, loss 0.003033, batch time 0.032572
# 	step 106250, loss 0.000595, batch time 0.000970
# 	step 106500, loss 0.004841, batch time 0.000550
# 	step 106750, loss 0.003504, batch time 0.001140
# 107000/150000: test accuracy: 0.932100
# 	step 107000, loss 0.003734, batch time 0.034266
# 	step 107250, loss 0.003174, batch time 0.000904
# 	step 107500, loss 0.006875, batch time 0.000893
# 	step 107750, loss 0.003479, batch time 0.000728
# 108000/150000: test accuracy: 0.932200
# 	step 108000, loss 0.004427, batch time 0.033435
# 	step 108250, loss 0.000903, batch time 0.000998
# 	step 108500, loss 0.004320, batch time 0.001085
# 	step 108750, loss 0.007623, batch time 0.000871
# 109000/150000: test accuracy: 0.931800
# 	step 109000, loss 0.001629, batch time 0.031924
# 	step 109250, loss 0.005714, batch time 0.000658
# 	step 109500, loss 0.006674, batch time 0.000737
# 	step 109750, loss 0.004217, batch time 0.000988
# 110000/150000: test accuracy: 0.931800
# 	step 110000, loss 0.005175, batch time 0.045410
# 	step 110250, loss 0.001878, batch time 0.000785
# 	step 110500, loss 0.007648, batch time 0.001189
# 	step 110750, loss 0.002657, batch time 0.000722
# 111000/150000: test accuracy: 0.932100
# 	step 111000, loss 0.004939, batch time 0.042039
# 	step 111250, loss 0.006986, batch time 0.001103
# 	step 111500, loss 0.007915, batch time 0.002467
# 	step 111750, loss 0.001991, batch time 0.000668
# 112000/150000: test accuracy: 0.931500
# 	step 112000, loss 0.001420, batch time 0.036753
# 	step 112250, loss 0.003384, batch time 0.000665
# 	step 112500, loss 0.003109, batch time 0.000761
# 	step 112750, loss 0.004192, batch time 0.001426
# 113000/150000: test accuracy: 0.931100
# 	step 113000, loss 0.002608, batch time 0.031978
# 	step 113250, loss 0.003214, batch time 0.000761
# 	step 113500, loss 0.001764, batch time 0.000894
# 	step 113750, loss 0.007425, batch time 0.000989
# 114000/150000: test accuracy: 0.932000
# 	step 114000, loss 0.004932, batch time 0.043405
# 	step 114250, loss 0.001568, batch time 0.001123
# 	step 114500, loss 0.004013, batch time 0.001074
# 	step 114750, loss 0.008121, batch time 0.000938
# 115000/150000: test accuracy: 0.931700
# 	step 115000, loss 0.004146, batch time 0.032708
# 	step 115250, loss 0.004446, batch time 0.000738
# 	step 115500, loss 0.004331, batch time 0.000749
# 	step 115750, loss 0.005022, batch time 0.000732
# 116000/150000: test accuracy: 0.931800
# 	step 116000, loss 0.004411, batch time 0.035978
# 	step 116250, loss 0.003566, batch time 0.000807
# 	step 116500, loss 0.002783, batch time 0.000672
# 	step 116750, loss 0.004009, batch time 0.000732
# 117000/150000: test accuracy: 0.931500
# 	step 117000, loss 0.008693, batch time 0.034481
# 	step 117250, loss 0.006228, batch time 0.000749
# 	step 117500, loss 0.009221, batch time 0.000672
# 	step 117750, loss 0.004668, batch time 0.000596
# 118000/150000: test accuracy: 0.931600
# 	step 118000, loss 0.001575, batch time 0.034500
# 	step 118250, loss 0.003968, batch time 0.000927
# 	step 118500, loss 0.004660, batch time 0.000752
# 	step 118750, loss 0.007015, batch time 0.000858
# 119000/150000: test accuracy: 0.931700
# 	step 119000, loss 0.006808, batch time 0.033539
# 	step 119250, loss 0.009500, batch time 0.000989
# 	step 119500, loss 0.002983, batch time 0.001013
# 	step 119750, loss 0.001833, batch time 0.001021
# 120000/150000: test accuracy: 0.931600
# 	step 120000, loss 0.000804, batch time 0.036693
# 	step 120250, loss 0.011937, batch time 0.001049
# 	step 120500, loss 0.004096, batch time 0.000682
# 	step 120750, loss 0.002977, batch time 0.000644
# 121000/150000: test accuracy: 0.931400
# 	step 121000, loss 0.006249, batch time 0.034172
# 	step 121250, loss 0.003792, batch time 0.000695
# 	step 121500, loss 0.003385, batch time 0.000688
# 	step 121750, loss 0.006424, batch time 0.002030
# 122000/150000: test accuracy: 0.932300
# 	step 122000, loss 0.003043, batch time 0.034521
# 	step 122250, loss 0.000608, batch time 0.000815
# 	step 122500, loss 0.003349, batch time 0.000788
# 	step 122750, loss 0.004344, batch time 0.000653
# 123000/150000: test accuracy: 0.932000
# 	step 123000, loss 0.004681, batch time 0.042246
# 	step 123250, loss 0.004587, batch time 0.000775
# 	step 123500, loss 0.005538, batch time 0.000795
# 	step 123750, loss 0.011118, batch time 0.000800
# 124000/150000: test accuracy: 0.931700
# 	step 124000, loss 0.004308, batch time 0.035793
# 	step 124250, loss 0.007784, batch time 0.000659
# 	step 124500, loss 0.003167, batch time 0.001179
# 	step 124750, loss 0.005669, batch time 0.000973
# 125000/150000: test accuracy: 0.931700
# 	step 125000, loss 0.004844, batch time 0.043032
# 	step 125250, loss 0.006597, batch time 0.000619
# 	step 125500, loss 0.007320, batch time 0.000778
# 	step 125750, loss 0.010808, batch time 0.000804
# 126000/150000: test accuracy: 0.932200
# 	step 126000, loss 0.004238, batch time 0.055478
# 	step 126250, loss 0.004254, batch time 0.000930
# 	step 126500, loss 0.006498, batch time 0.001056
# 	step 126750, loss 0.004976, batch time 0.001033
# 127000/150000: test accuracy: 0.932200
# 	step 127000, loss 0.005575, batch time 0.032981
# 	step 127250, loss 0.008745, batch time 0.000719
# 	step 127500, loss 0.005196, batch time 0.001091
# 	step 127750, loss 0.004370, batch time 0.000959
# 128000/150000: test accuracy: 0.931900
# 	step 128000, loss 0.010719, batch time 0.034372
# 	step 128250, loss 0.009918, batch time 0.000824
# 	step 128500, loss 0.006264, batch time 0.001180
# 	step 128750, loss 0.005292, batch time 0.001821
# 129000/150000: test accuracy: 0.932000
# 	step 129000, loss 0.003188, batch time 0.041491
# 	step 129250, loss 0.003617, batch time 0.000714
# 	step 129500, loss 0.003827, batch time 0.000700
# 	step 129750, loss 0.011477, batch time 0.001023
# 130000/150000: test accuracy: 0.932500
# 	step 130000, loss 0.006036, batch time 0.036985
# 	step 130250, loss 0.007480, batch time 0.000798
# 	step 130500, loss 0.001139, batch time 0.000731
# 	step 130750, loss 0.006921, batch time 0.001048
# 131000/150000: test accuracy: 0.932100
# 	step 131000, loss 0.003949, batch time 0.034444
# 	step 131250, loss 0.006462, batch time 0.000660
# 	step 131500, loss 0.001017, batch time 0.001077
# 	step 131750, loss 0.003473, batch time 0.000615
# 132000/150000: test accuracy: 0.932200
# 	step 132000, loss 0.003329, batch time 0.033367
# 	step 132250, loss 0.002979, batch time 0.001251
# 	step 132500, loss 0.005481, batch time 0.000725
# 	step 132750, loss 0.005098, batch time 0.001227
# 133000/150000: test accuracy: 0.931800
# 	step 133000, loss 0.006677, batch time 0.044386
# 	step 133250, loss 0.011440, batch time 0.002305
# 	step 133500, loss 0.007320, batch time 0.000777
# 	step 133750, loss 0.004254, batch time 0.000696
# 134000/150000: test accuracy: 0.931800
# 	step 134000, loss 0.006766, batch time 0.045478
# 	step 134250, loss 0.005909, batch time 0.001149
# 	step 134500, loss 0.005492, batch time 0.000772
# 	step 134750, loss 0.004889, batch time 0.000776
# 135000/150000: test accuracy: 0.932000
# 	step 135000, loss 0.004673, batch time 0.037306
# 	step 135250, loss 0.005991, batch time 0.000769
# 	step 135500, loss 0.005552, batch time 0.005666
# 	step 135750, loss 0.003330, batch time 0.002503
# 136000/150000: test accuracy: 0.931600
# 	step 136000, loss 0.002305, batch time 0.032756
# 	step 136250, loss 0.007440, batch time 0.000857
# 	step 136500, loss 0.005953, batch time 0.000775
# 	step 136750, loss 0.013186, batch time 0.000671
# 137000/150000: test accuracy: 0.932700
# 	step 137000, loss 0.006340, batch time 0.032798
# 	step 137250, loss 0.003893, batch time 0.001039
# 	step 137500, loss 0.006644, batch time 0.000832
# 	step 137750, loss 0.007180, batch time 0.000670
# 138000/150000: test accuracy: 0.932300
# 	step 138000, loss 0.006630, batch time 0.035659
# 	step 138250, loss 0.002635, batch time 0.000689
# 	step 138500, loss 0.002547, batch time 0.002020
# 	step 138750, loss 0.007185, batch time 0.000605
# 139000/150000: test accuracy: 0.932100
# 	step 139000, loss 0.007453, batch time 0.035593
# 	step 139250, loss 0.006966, batch time 0.000703
# 	step 139500, loss 0.000697, batch time 0.001124
# 	step 139750, loss 0.005216, batch time 0.000911
# 140000/150000: test accuracy: 0.932000
# 	step 140000, loss 0.001265, batch time 0.033670
# 	step 140250, loss 0.001866, batch time 0.005015
# 	step 140500, loss 0.014087, batch time 0.000891
# 	step 140750, loss 0.005966, batch time 0.001051
# 141000/150000: test accuracy: 0.932300
# 	step 141000, loss 0.003216, batch time 0.040945
# 	step 141250, loss 0.004123, batch time 0.000995
# 	step 141500, loss 0.005585, batch time 0.000684
# 	step 141750, loss 0.004655, batch time 0.000895
# 142000/150000: test accuracy: 0.932200
# 	step 142000, loss 0.004870, batch time 0.043246
# 	step 142250, loss 0.007472, batch time 0.000846
# 	step 142500, loss 0.014555, batch time 0.000656
# 	step 142750, loss 0.006056, batch time 0.001204
# 143000/150000: test accuracy: 0.932100
# 	step 143000, loss 0.008016, batch time 0.038175
# 	step 143250, loss 0.005266, batch time 0.001433
# 	step 143500, loss 0.002950, batch time 0.001045
# 	step 143750, loss 0.001843, batch time 0.000685
# 144000/150000: test accuracy: 0.932200
# 	step 144000, loss 0.004014, batch time 0.032172
# 	step 144250, loss 0.004718, batch time 0.002577
# 	step 144500, loss 0.005047, batch time 0.001113
# 	step 144750, loss 0.011393, batch time 0.001377
# 145000/150000: test accuracy: 0.932200
# 	step 145000, loss 0.000217, batch time 0.044129
# 	step 145250, loss 0.002839, batch time 0.000817
# 	step 145500, loss 0.003294, batch time 0.000702
# 	step 145750, loss 0.003763, batch time 0.000975
# 146000/150000: test accuracy: 0.932500
# 	step 146000, loss 0.005509, batch time 0.041516
# 	step 146250, loss 0.005581, batch time 0.000669
# 	step 146500, loss 0.008068, batch time 0.000695
# 	step 146750, loss 0.010038, batch time 0.000962
# 147000/150000: test accuracy: 0.932600
# 	step 147000, loss 0.009470, batch time 0.040038
# 	step 147250, loss 0.010083, batch time 0.001149
# 	step 147500, loss 0.008562, batch time 0.000634
# 	step 147750, loss 0.007137, batch time 0.000699
# 148000/150000: test accuracy: 0.931700
# 	step 148000, loss 0.003431, batch time 0.040814
# 	step 148250, loss 0.003584, batch time 0.001147
# 	step 148500, loss 0.005006, batch time 0.001480
# 	step 148750, loss 0.006437, batch time 0.000772
# 149000/150000: test accuracy: 0.932500
# 	step 149000, loss 0.008159, batch time 0.034944
# 	step 149250, loss 0.005157, batch time 0.000705
# 	step 149500, loss 0.007414, batch time 0.000715
# 	step 149750, loss 0.005196, batch time 0.001123
#
# total runtime: 157.045226 seconds

# %%
feed = {x: mnist.test.images, y_: mnist.test.labels}
acc = accuracy.eval(feed_dict=feed)
print "final test accuracy: {:3f}".format(acc)
# Out:
# final test accuracy: 0.931900

# %% [markdown]
# ## Plot performance

# %%
plt.figure(0, figsize=(16,4))
plt.subplot(121)
plt.title("Loss")
plt.plot(loss_curve[1:,0], loss_curve[1:,1], 'b-')
plt.subplot(122)
plt.title("Accuracy")
plt.plot(acc_curve[1:,0], acc_curve[1:,1], 'r-')

with open('noreg.p', 'w') as f:
    pickle.dump(acc_curve, f)

# %% [markdown]
# ## Plot weights

# %%
W_ = W.eval()
for i in range(0,10,5):
    img1 = np.reshape(W_[:,i], (28,28))
    img2 = np.reshape(W_[:,i+1], (28,28))
    img3 = np.reshape(W_[:,i+2], (28,28))
    img4 = np.reshape(W_[:,i+3], (28,28))
    img5 = np.reshape(W_[:,i+4], (28,28))
    plt.figure(i, figsize=(16,4))
    plt.subplot(151)
    plt.imshow(img1, cmap=cm.gray)
    plt.subplot(152)
    plt.imshow(img2, cmap=cm.gray)
    plt.subplot(153)
    plt.imshow(img3, cmap=cm.gray)
    plt.subplot(154)
    plt.imshow(img4, cmap=cm.gray)
    plt.subplot(155)
    plt.imshow(img5, cmap=cm.gray)

# %%
print np.min(W_), np.max(W_), "\n", W_
# Out:
# -1.94825 1.64264
# [[ 0.03850536 -0.01918605  0.04889935 ...,  0.02410696 -0.03227681
#    0.12101676]
#  [-0.10343652  0.01026842  0.09842224 ...,  0.10776041  0.10512403
#    0.14415807]
#  [ 0.02281166 -0.01020185 -0.03473994 ...,  0.07933947  0.0734944
#    0.00922439]
#  ...,
#  [ 0.05679378 -0.0197225  -0.04664761 ..., -0.08260879 -0.01550736
#    0.0088239 ]
#  [-0.03153034  0.01112991 -0.03470689 ...,  0.01366572 -0.03326581
#    0.03825216]
#  [ 0.00947612  0.01582363  0.0263431  ..., -0.14730136  0.05386596
#    0.02577173]]

# %% [markdown]
# ## Saver IO

# %%
# saver = tf.train.Saver(tf.all_variables())
# load_was_success = True # yes, I'm being optimistic
# try:
#     save_dir = '/'.join(save_path.split('/')[:-1])
#     ckpt = tf.train.get_checkpoint_state(save_dir)
#     load_path = ckpt.model_checkpoint_path
#     saver.restore(sess, load_path)
# except:
#     print "no saved model to load. starting new session"
#     load_was_success = False
# else:
#     print "loaded model: {}".format(load_path)
#     saver = tf.train.Saver(tf.all_variables())
#     global_step = int(load_path.split('-')[-1])

# %%
# #fc 1 layer
# W1 = tf.get_variable("W1", shape=[xlen,ylen], initializer=init)
# b1 = tf.get_variable("b1", shape=[ylen], initializer=init)
# output = tf.nn.softmax(tf.matmul(x, W1) + b1)
