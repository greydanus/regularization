# %% [markdown]
# # Weight Normalization

# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

import time
import cPickle as pickle
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Model baseline

# %%
batch_size = 32
global_step = 0
save_path = 'models/norm.ckpt'
xlen = 28*28
ylen = 10

train_steps = 150000
info_every = 250
test_every = 1000

# %% [markdown]
# ## Build model

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()

x = tf.placeholder(tf.float32, shape=[None, xlen], name="x")
y_ = tf.placeholder(tf.float32, shape=[None, ylen], name="y_")
init = tf.truncated_normal_initializer(mean=0., stddev=.075, seed=1234, dtype=tf.float32)

W_hat = tf.get_variable("W", shape=[xlen,ylen], initializer=init)
W = tf.nn.l2_normalize(W_hat, [0,1])

output = tf.nn.softmax(tf.matmul(x, W))
sess.run(tf.initialize_all_variables())

# %%
loss = tf.nn.l2_loss( y_ - output ) / (ylen*batch_size)

optimizer = tf.train.AdamOptimizer(1e-4)
grads = optimizer.compute_gradients(loss, var_list=tf.trainable_variables())
train_op = optimizer.apply_gradients(grads)

sess.run(tf.initialize_all_variables())

# %% [markdown]
# ## Model overview

# %%
total_parameters = 0 ; print "Model overview:"
for variable in tf.trainable_variables():
    shape = variable.get_shape()
    variable_parameters = 1
    for dim in shape:
        variable_parameters *= dim.value
    print '\tvariable "{}" has {} parameters' \
        .format(variable.name, variable_parameters)
    total_parameters += variable_parameters
print "Total of {} parameters".format(total_parameters)
# Out:
# Model overview:
# 	variable "W:0" has 7840 parameters
# Total of 7840 parameters

# %% [markdown]
# ## Train

# %%
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
loss_curve = np.zeros((train_steps/info_every, 2))
acc_curve = np.zeros((train_steps/test_every, 2))

begin = time.time()
for i in range(train_steps):
    batch_start = time.time()
    
    batch = mnist.train.next_batch(batch_size)
    feed = {x: batch[0], y_: batch[1]}
    train_loss, _ = sess.run([loss, train_op], feed_dict=feed)
    
    if i%test_every == 0:
        feed = {x: mnist.test.images, y_: mnist.test.labels}
        acc = accuracy.eval(feed_dict=feed)
        acc_curve[i/test_every,:] = [i, acc]
        print "{}/{}: test accuracy: {:3f}".format(i, train_steps, acc)
    if i%info_every == 0:
        loss_curve[i/info_every,:] = [i, train_loss]
        print "\tstep {}, loss {:3f}, batch time {:3f}".format(i, train_loss, time.time()-batch_start)
print "\ntotal runtime: {:3f} seconds".format(time.time()-begin)
# Out:
# 0/100000: test accuracy: 0.085100
# 	step 0, loss 0.045132, batch time 0.050311
# 	step 250, loss 0.043271, batch time 0.001262
# 	step 500, loss 0.041231, batch time 0.001649
# 	step 750, loss 0.040067, batch time 0.001818
# 1000/100000: test accuracy: 0.704500
# 	step 1000, loss 0.036882, batch time 0.036804
# 	step 1250, loss 0.035946, batch time 0.001111
# 	step 1500, loss 0.032686, batch time 0.001014
# 	step 1750, loss 0.030602, batch time 0.002302
# 2000/100000: test accuracy: 0.717800
# 	step 2000, loss 0.035544, batch time 0.037683
# 	step 2250, loss 0.031109, batch time 0.001669
# 	step 2500, loss 0.031216, batch time 0.001571
# 	step 2750, loss 0.030720, batch time 0.002091
# 3000/100000: test accuracy: 0.725600
# 	step 3000, loss 0.033170, batch time 0.037197
# 	step 3250, loss 0.036063, batch time 0.001644
# 	step 3500, loss 0.031307, batch time 0.001645
# 	step 3750, loss 0.034331, batch time 0.001727
# 4000/100000: test accuracy: 0.722600
# 	step 4000, loss 0.030588, batch time 0.034678
# 	step 4250, loss 0.032309, batch time 0.001585
# 	step 4500, loss 0.030728, batch time 0.001719
# 	step 4750, loss 0.032325, batch time 0.002383
# 5000/100000: test accuracy: 0.721600
# 	step 5000, loss 0.033397, batch time 0.037484
# 	step 5250, loss 0.032426, batch time 0.002271
# 	step 5500, loss 0.031957, batch time 0.002592
# 	step 5750, loss 0.028881, batch time 0.002620
# 6000/100000: test accuracy: 0.719900
# 	step 6000, loss 0.029101, batch time 0.040540
# 	step 6250, loss 0.032964, batch time 0.001543
# 	step 6500, loss 0.031685, batch time 0.001642
# 	step 6750, loss 0.031614, batch time 0.001569
# 7000/100000: test accuracy: 0.719900
# 	step 7000, loss 0.026527, batch time 0.056980
# 	step 7250, loss 0.033910, batch time 0.001575
# 	step 7500, loss 0.035702, batch time 0.002144
# 	step 7750, loss 0.032635, batch time 0.001677
# 8000/100000: test accuracy: 0.722000
# 	step 8000, loss 0.027308, batch time 0.038216
# 	step 8250, loss 0.033341, batch time 0.001618
# 	step 8500, loss 0.031431, batch time 0.003090
# 	step 8750, loss 0.033326, batch time 0.001878
# 9000/100000: test accuracy: 0.718300
# 	step 9000, loss 0.031145, batch time 0.037158
# 	step 9250, loss 0.033634, batch time 0.001598
# 	step 9500, loss 0.030595, batch time 0.001667
# 	step 9750, loss 0.029110, batch time 0.006964
# 10000/100000: test accuracy: 0.722900
# 	step 10000, loss 0.033621, batch time 0.038712
# 	step 10250, loss 0.031242, batch time 0.001621
# 	step 10500, loss 0.030441, batch time 0.003383
# 	step 10750, loss 0.031412, batch time 0.001539
# 11000/100000: test accuracy: 0.720400
# 	step 11000, loss 0.030923, batch time 0.043864
# 	step 11250, loss 0.031739, batch time 0.028255
# 	step 11500, loss 0.032603, batch time 0.002949
# 	step 11750, loss 0.031936, batch time 0.001633
# 12000/100000: test accuracy: 0.719100
# 	step 12000, loss 0.030864, batch time 0.035625
# 	step 12250, loss 0.030683, batch time 0.001565
# 	step 12500, loss 0.026543, batch time 0.001610
# 	step 12750, loss 0.032213, batch time 0.001614
# 13000/100000: test accuracy: 0.726300
# 	step 13000, loss 0.034725, batch time 0.041179
# 	step 13250, loss 0.030940, batch time 0.001850
# 	step 13500, loss 0.032172, batch time 0.001924
# 	step 13750, loss 0.033484, batch time 0.001829
# 14000/100000: test accuracy: 0.720200
# 	step 14000, loss 0.034159, batch time 0.052479
# 	step 14250, loss 0.033008, batch time 0.001592
# 	step 14500, loss 0.029118, batch time 0.001635
# 	step 14750, loss 0.031094, batch time 0.001736
# 15000/100000: test accuracy: 0.724100
# 	step 15000, loss 0.031574, batch time 0.071568
# 	step 15250, loss 0.029763, batch time 0.001635
# 	step 15500, loss 0.033689, batch time 0.002303
# 	step 15750, loss 0.034183, batch time 0.002370
# 16000/100000: test accuracy: 0.714600
# 	step 16000, loss 0.030137, batch time 0.063890
# 	step 16250, loss 0.035968, batch time 0.001596
# 	step 16500, loss 0.030720, batch time 0.002434
# 	step 16750, loss 0.030928, batch time 0.002370
# 17000/100000: test accuracy: 0.718500
# 	step 17000, loss 0.035492, batch time 0.056191
# 	step 17250, loss 0.030345, batch time 0.002088
# 	step 17500, loss 0.034538, batch time 0.002029
# 	step 17750, loss 0.031984, batch time 0.001759
# 18000/100000: test accuracy: 0.728800
# 	step 18000, loss 0.026909, batch time 0.054454
# 	step 18250, loss 0.030773, batch time 0.001549
# 	step 18500, loss 0.031357, batch time 0.002520
# 	step 18750, loss 0.033088, batch time 0.001673
# 19000/100000: test accuracy: 0.717600
# 	step 19000, loss 0.031222, batch time 0.115421
# 	step 19250, loss 0.029845, batch time 0.001836
# 	step 19500, loss 0.030942, batch time 0.002933
# 	step 19750, loss 0.032018, batch time 0.001734
# 20000/100000: test accuracy: 0.727200
# 	step 20000, loss 0.035213, batch time 0.082913
# 	step 20250, loss 0.033487, batch time 0.001661
# 	step 20500, loss 0.029352, batch time 0.002737
# 	step 20750, loss 0.029401, batch time 0.001869
# 21000/100000: test accuracy: 0.721200
# 	step 21000, loss 0.033074, batch time 0.064074
# 	step 21250, loss 0.032586, batch time 0.001728
# 	step 21500, loss 0.032618, batch time 0.002422
# 	step 21750, loss 0.029129, batch time 0.001800
# 22000/100000: test accuracy: 0.726200
# 	step 22000, loss 0.033920, batch time 0.134650
# 	step 22250, loss 0.029645, batch time 0.001863
# 	step 22500, loss 0.034151, batch time 0.001693
# 	step 22750, loss 0.032481, batch time 0.001742
# 23000/100000: test accuracy: 0.720700
# 	step 23000, loss 0.033173, batch time 0.079424
# 	step 23250, loss 0.034517, batch time 0.001885
# 	step 23500, loss 0.029577, batch time 0.002416
# 	step 23750, loss 0.033243, batch time 0.002899
# 24000/100000: test accuracy: 0.721800
# 	step 24000, loss 0.033505, batch time 0.040012
# 	step 24250, loss 0.033086, batch time 0.001874
# 	step 24500, loss 0.030442, batch time 0.001677
# 	step 24750, loss 0.031738, batch time 0.001741
# 25000/100000: test accuracy: 0.722400
# 	step 25000, loss 0.029716, batch time 0.047366
# 	step 25250, loss 0.034348, batch time 0.001747
# 	step 25500, loss 0.030674, batch time 0.001731
# 	step 25750, loss 0.033184, batch time 0.002296
# 26000/100000: test accuracy: 0.724700
# 	step 26000, loss 0.030355, batch time 0.038992
# 	step 26250, loss 0.030298, batch time 0.012660
# 	step 26500, loss 0.032739, batch time 0.001720
# 	step 26750, loss 0.030190, batch time 0.001666
# 27000/100000: test accuracy: 0.716200
# 	step 27000, loss 0.033135, batch time 0.051791
# 	step 27250, loss 0.033706, batch time 0.001909
# 	step 27500, loss 0.034006, batch time 0.001730
# 	step 27750, loss 0.032560, batch time 0.001756
# 28000/100000: test accuracy: 0.724000
# 	step 28000, loss 0.031187, batch time 0.086676
# 	step 28250, loss 0.028926, batch time 0.001683
# 	step 28500, loss 0.029782, batch time 0.039659
# 	step 28750, loss 0.031616, batch time 0.001878
# 29000/100000: test accuracy: 0.722000
# 	step 29000, loss 0.031391, batch time 0.042427
# 	step 29250, loss 0.032049, batch time 0.001716
# 	step 29500, loss 0.032937, batch time 0.001842
# 	step 29750, loss 0.032987, batch time 0.001708
# 30000/100000: test accuracy: 0.718400
# 	step 30000, loss 0.032836, batch time 0.054999
# 	step 30250, loss 0.033220, batch time 0.001787
# 	step 30500, loss 0.028167, batch time 0.001836
# 	step 30750, loss 0.031790, batch time 0.001674
# 31000/100000: test accuracy: 0.723900
# 	step 31000, loss 0.027702, batch time 0.102546
# 	step 31250, loss 0.031977, batch time 0.001747
# 	step 31500, loss 0.033187, batch time 0.001736
# 	step 31750, loss 0.032449, batch time 0.001858
# 32000/100000: test accuracy: 0.724200
# 	step 32000, loss 0.031768, batch time 0.113472
# 	step 32250, loss 0.029151, batch time 0.001739
# 	step 32500, loss 0.034643, batch time 0.002797
# 	step 32750, loss 0.031054, batch time 0.001651
# 33000/100000: test accuracy: 0.719300
# 	step 33000, loss 0.031293, batch time 0.045239
# 	step 33250, loss 0.031006, batch time 0.001796
# 	step 33500, loss 0.026093, batch time 0.001688
# 	step 33750, loss 0.032700, batch time 0.001862
# 34000/100000: test accuracy: 0.723100
# 	step 34000, loss 0.034540, batch time 0.056869
# 	step 34250, loss 0.032430, batch time 0.001680
# 	step 34500, loss 0.032997, batch time 0.001729
# 	step 34750, loss 0.029689, batch time 0.001775
# 35000/100000: test accuracy: 0.725500
# 	step 35000, loss 0.034494, batch time 0.261843
# 	step 35250, loss 0.027584, batch time 0.001771
# 	step 35500, loss 0.034097, batch time 0.002009
# 	step 35750, loss 0.033418, batch time 0.001775
# 36000/100000: test accuracy: 0.722800
# 	step 36000, loss 0.034219, batch time 0.043558
# 	step 36250, loss 0.029625, batch time 0.001804
# 	step 36500, loss 0.032352, batch time 0.001862
# 	step 36750, loss 0.033019, batch time 0.001782
# 37000/100000: test accuracy: 0.710400
# 	step 37000, loss 0.032950, batch time 0.082831
# 	step 37250, loss 0.032449, batch time 0.001775
# 	step 37500, loss 0.029814, batch time 0.001863
# 	step 37750, loss 0.034547, batch time 0.002808
# 38000/100000: test accuracy: 0.725700
# 	step 38000, loss 0.030307, batch time 0.104311
# 	step 38250, loss 0.032138, batch time 0.001728
# 	step 38500, loss 0.031984, batch time 0.004059
# 	step 38750, loss 0.033078, batch time 0.001767
# 39000/100000: test accuracy: 0.723700
# 	step 39000, loss 0.033425, batch time 0.036071
# 	step 39250, loss 0.031809, batch time 0.001573
# 	step 39500, loss 0.029348, batch time 0.001831
# 	step 39750, loss 0.033411, batch time 0.002669
# 40000/100000: test accuracy: 0.719600
# 	step 40000, loss 0.029473, batch time 0.064927
# 	step 40250, loss 0.028988, batch time 0.001806
# 	step 40500, loss 0.031946, batch time 0.001868
# 	step 40750, loss 0.031660, batch time 0.001702
# 41000/100000: test accuracy: 0.724000
# 	step 41000, loss 0.034054, batch time 0.065907
# 	step 41250, loss 0.027239, batch time 0.002056
# 	step 41500, loss 0.031682, batch time 0.001747
# 	step 41750, loss 0.033827, batch time 0.001776
# 42000/100000: test accuracy: 0.717800
# 	step 42000, loss 0.032548, batch time 0.041030
# 	step 42250, loss 0.031459, batch time 0.002082
# 	step 42500, loss 0.031363, batch time 0.001658
# 	step 42750, loss 0.033970, batch time 0.001759
# 43000/100000: test accuracy: 0.715500
# 	step 43000, loss 0.035856, batch time 0.095785
# 	step 43250, loss 0.035646, batch time 0.001696
# 	step 43500, loss 0.029241, batch time 0.001771
# 	step 43750, loss 0.033251, batch time 0.001763
# 44000/100000: test accuracy: 0.725400
# 	step 44000, loss 0.032606, batch time 0.059437
# 	step 44250, loss 0.031295, batch time 0.001815
# 	step 44500, loss 0.031283, batch time 0.002050
# 	step 44750, loss 0.027453, batch time 0.001737
# 45000/100000: test accuracy: 0.713400
# 	step 45000, loss 0.034970, batch time 0.095247
# 	step 45250, loss 0.032289, batch time 0.004627
# 	step 45500, loss 0.033054, batch time 0.002377
# 	step 45750, loss 0.032777, batch time 0.002442
# 46000/100000: test accuracy: 0.726900
# 	step 46000, loss 0.034048, batch time 0.130103
# 	step 46250, loss 0.034166, batch time 0.001628
# 	step 46500, loss 0.026723, batch time 0.001691
# 	step 46750, loss 0.031372, batch time 0.002045
# 47000/100000: test accuracy: 0.721900
# 	step 47000, loss 0.030439, batch time 0.052184
# 	step 47250, loss 0.028623, batch time 0.002050
# 	step 47500, loss 0.034130, batch time 0.001747
# 	step 47750, loss 0.035308, batch time 0.001723
# 48000/100000: test accuracy: 0.721800
# 	step 48000, loss 0.035104, batch time 0.080418
# 	step 48250, loss 0.028969, batch time 0.001829
# 	step 48500, loss 0.032640, batch time 0.001660
# 	step 48750, loss 0.032417, batch time 0.001797
# 49000/100000: test accuracy: 0.716900
# 	step 49000, loss 0.034687, batch time 0.098620
# 	step 49250, loss 0.031301, batch time 0.002564
# 	step 49500, loss 0.033343, batch time 0.001621
# 	step 49750, loss 0.033191, batch time 0.001720
# 50000/100000: test accuracy: 0.718200
# 	step 50000, loss 0.032622, batch time 0.041968
# 	step 50250, loss 0.034190, batch time 0.001780
# 	step 50500, loss 0.030582, batch time 0.001765
# 	step 50750, loss 0.030634, batch time 0.002885
# 51000/100000: test accuracy: 0.723700
# 	step 51000, loss 0.030406, batch time 0.150654
# 	step 51250, loss 0.029263, batch time 0.001727
# 	step 51500, loss 0.030305, batch time 0.001697
# 	step 51750, loss 0.031423, batch time 0.001639
# 52000/100000: test accuracy: 0.725600
# 	step 52000, loss 0.031050, batch time 0.036548
# 	step 52250, loss 0.034885, batch time 0.001751
# 	step 52500, loss 0.031324, batch time 0.001760
# 	step 52750, loss 0.029744, batch time 0.001784
# 53000/100000: test accuracy: 0.722100
# 	step 53000, loss 0.030934, batch time 0.099912
# 	step 53250, loss 0.033620, batch time 0.001807
# 	step 53500, loss 0.031705, batch time 0.001912
# 	step 53750, loss 0.031610, batch time 0.001818
# 54000/100000: test accuracy: 0.726200
# 	step 54000, loss 0.033601, batch time 0.041509
# 	step 54250, loss 0.032743, batch time 0.001755
# 	step 54500, loss 0.032506, batch time 0.004035
# 	step 54750, loss 0.030096, batch time 0.001712
# 55000/100000: test accuracy: 0.711400
# 	step 55000, loss 0.032518, batch time 0.117642
# 	step 55250, loss 0.032265, batch time 0.001828
# 	step 55500, loss 0.028680, batch time 0.001704
# 	step 55750, loss 0.030864, batch time 0.001724
# 56000/100000: test accuracy: 0.726800
# 	step 56000, loss 0.031181, batch time 0.046364
# 	step 56250, loss 0.033428, batch time 0.001802
# 	step 56500, loss 0.032818, batch time 0.001657
# 	step 56750, loss 0.032079, batch time 0.001719
# 57000/100000: test accuracy: 0.723400
# 	step 57000, loss 0.030195, batch time 0.100216
# 	step 57250, loss 0.030208, batch time 0.002607
# 	step 57500, loss 0.034163, batch time 0.006066
# 	step 57750, loss 0.031956, batch time 0.002716
# 58000/100000: test accuracy: 0.721300
# 	step 58000, loss 0.030125, batch time 0.040246
# 	step 58250, loss 0.032585, batch time 0.001692
# 	step 58500, loss 0.030617, batch time 0.001765
# 	step 58750, loss 0.036868, batch time 0.001701
# 59000/100000: test accuracy: 0.723300
# 	step 59000, loss 0.030082, batch time 0.054556
# 	step 59250, loss 0.027867, batch time 0.002209
# 	step 59500, loss 0.031430, batch time 0.001788
# 	step 59750, loss 0.034404, batch time 0.001603
# 60000/100000: test accuracy: 0.722300
# 	step 60000, loss 0.028648, batch time 0.086553
# 	step 60250, loss 0.031459, batch time 0.001765
# 	step 60500, loss 0.031247, batch time 0.002205
# 	step 60750, loss 0.031661, batch time 0.008914
# 61000/100000: test accuracy: 0.728700
# 	step 61000, loss 0.030951, batch time 0.041900
# 	step 61250, loss 0.032863, batch time 0.001911
# 	step 61500, loss 0.031952, batch time 0.001768
# 	step 61750, loss 0.030453, batch time 0.001767
# 62000/100000: test accuracy: 0.721600
# 	step 62000, loss 0.033389, batch time 0.053511
# 	step 62250, loss 0.030538, batch time 0.001907
# 	step 62500, loss 0.026954, batch time 0.001960
# 	step 62750, loss 0.030819, batch time 0.001670
# 63000/100000: test accuracy: 0.722700
# 	step 63000, loss 0.037092, batch time 0.064982
# 	step 63250, loss 0.032404, batch time 0.001628
# 	step 63500, loss 0.030066, batch time 0.001710
# 	step 63750, loss 0.029559, batch time 0.001738
# 64000/100000: test accuracy: 0.727100
# 	step 64000, loss 0.031493, batch time 0.066381
# 	step 64250, loss 0.032113, batch time 0.001688
# 	step 64500, loss 0.032082, batch time 0.001728
# 	step 64750, loss 0.027984, batch time 0.002513
# 65000/100000: test accuracy: 0.722600
# 	step 65000, loss 0.031986, batch time 0.042948
# 	step 65250, loss 0.031015, batch time 0.001624
# 	step 65500, loss 0.030820, batch time 0.001683
# 	step 65750, loss 0.031029, batch time 0.001804
# 66000/100000: test accuracy: 0.723500
# 	step 66000, loss 0.031577, batch time 0.041632
# 	step 66250, loss 0.030455, batch time 0.001766
# 	step 66500, loss 0.033941, batch time 0.001582
# 	step 66750, loss 0.027904, batch time 0.001690
# 67000/100000: test accuracy: 0.723500
# 	step 67000, loss 0.033678, batch time 0.037852
# 	step 67250, loss 0.029065, batch time 0.001726
# 	step 67500, loss 0.030207, batch time 0.001704
# 	step 67750, loss 0.030361, batch time 0.003498
# 68000/100000: test accuracy: 0.721800
# 	step 68000, loss 0.034262, batch time 0.050570
# 	step 68250, loss 0.035085, batch time 0.001785
# 	step 68500, loss 0.031588, batch time 0.001645
# 	step 68750, loss 0.031196, batch time 0.001600
# 69000/100000: test accuracy: 0.718300
# 	step 69000, loss 0.031795, batch time 0.065450
# 	step 69250, loss 0.028377, batch time 0.001647
# 	step 69500, loss 0.032902, batch time 0.001745
# 	step 69750, loss 0.031948, batch time 0.002179
# 70000/100000: test accuracy: 0.718600
# 	step 70000, loss 0.033739, batch time 0.042931
# 	step 70250, loss 0.033796, batch time 0.001736
# 	step 70500, loss 0.030194, batch time 0.001918
# 	step 70750, loss 0.030298, batch time 0.001887
# 71000/100000: test accuracy: 0.723700
# 	step 71000, loss 0.028474, batch time 0.087039
# 	step 71250, loss 0.035044, batch time 0.002594
# 	step 71500, loss 0.033358, batch time 0.001616
# 	step 71750, loss 0.034433, batch time 0.001721
# 72000/100000: test accuracy: 0.721000
# 	step 72000, loss 0.027862, batch time 0.036809
# 	step 72250, loss 0.029651, batch time 0.002000
# 	step 72500, loss 0.035516, batch time 0.001626
# 	step 72750, loss 0.032149, batch time 0.001642
# 73000/100000: test accuracy: 0.728500
# 	step 73000, loss 0.033912, batch time 0.123238
# 	step 73250, loss 0.029345, batch time 0.001777
# 	step 73500, loss 0.030814, batch time 0.001712
# 	step 73750, loss 0.031962, batch time 0.001739
# 74000/100000: test accuracy: 0.724000
# 	step 74000, loss 0.032111, batch time 0.065075
# 	step 74250, loss 0.031152, batch time 0.001655
# 	step 74500, loss 0.032908, batch time 0.001669
# 	step 74750, loss 0.032089, batch time 0.001726
# 75000/100000: test accuracy: 0.724100
# 	step 75000, loss 0.034382, batch time 0.078368
# 	step 75250, loss 0.032774, batch time 0.001700
# 	step 75500, loss 0.033068, batch time 0.014814
# 	step 75750, loss 0.030819, batch time 0.001880
# 76000/100000: test accuracy: 0.719200
# 	step 76000, loss 0.029987, batch time 0.063118
# 	step 76250, loss 0.031715, batch time 0.001748
# 	step 76500, loss 0.033399, batch time 0.001609
# 	step 76750, loss 0.032638, batch time 0.001734
# 77000/100000: test accuracy: 0.720800
# 	step 77000, loss 0.029402, batch time 0.056588
# 	step 77250, loss 0.035010, batch time 0.001717
# 	step 77500, loss 0.029243, batch time 0.001535
# 	step 77750, loss 0.028200, batch time 0.002195
# 78000/100000: test accuracy: 0.722900
# 	step 78000, loss 0.032394, batch time 0.052077
# 	step 78250, loss 0.030039, batch time 0.001603
# 	step 78500, loss 0.031455, batch time 0.001694
# 	step 78750, loss 0.029708, batch time 0.001792
# 79000/100000: test accuracy: 0.720400
# 	step 79000, loss 0.031654, batch time 0.059342
# 	step 79250, loss 0.031350, batch time 0.001821
# 	step 79500, loss 0.027199, batch time 0.001732
# 	step 79750, loss 0.027537, batch time 0.001666
# 80000/100000: test accuracy: 0.711400
# 	step 80000, loss 0.034473, batch time 0.038872
# 	step 80250, loss 0.031737, batch time 0.001853
# 	step 80500, loss 0.026507, batch time 0.001553
# 	step 80750, loss 0.035817, batch time 0.001771
# 81000/100000: test accuracy: 0.723800
# 	step 81000, loss 0.033112, batch time 0.088755
# 	step 81250, loss 0.033987, batch time 0.002090
# 	step 81500, loss 0.034389, batch time 0.001591
# 	step 81750, loss 0.033903, batch time 0.001688
# 82000/100000: test accuracy: 0.725800
# 	step 82000, loss 0.033874, batch time 0.039936
# 	step 82250, loss 0.033250, batch time 0.001663
# 	step 82500, loss 0.033814, batch time 0.001794
# 	step 82750, loss 0.028773, batch time 0.001791
# 83000/100000: test accuracy: 0.710500
# 	step 83000, loss 0.033984, batch time 0.037526
# 	step 83250, loss 0.029392, batch time 0.001686
# 	step 83500, loss 0.033071, batch time 0.002113
# 	step 83750, loss 0.032135, batch time 0.001831
# 84000/100000: test accuracy: 0.722300
# 	step 84000, loss 0.031528, batch time 0.037628
# 	step 84250, loss 0.031069, batch time 0.003549
# 	step 84500, loss 0.030769, batch time 0.001721
# 	step 84750, loss 0.029117, batch time 0.001657
# 85000/100000: test accuracy: 0.723000
# 	step 85000, loss 0.031323, batch time 0.042525
# 	step 85250, loss 0.034666, batch time 0.002614
# 	step 85500, loss 0.032486, batch time 0.001670
# 	step 85750, loss 0.031346, batch time 0.001770
# 86000/100000: test accuracy: 0.722300
# 	step 86000, loss 0.031805, batch time 0.043373
# 	step 86250, loss 0.034513, batch time 0.001720
# 	step 86500, loss 0.028081, batch time 0.001676
# 	step 86750, loss 0.032369, batch time 0.001711
# 87000/100000: test accuracy: 0.719800
# 	step 87000, loss 0.029344, batch time 0.040265
# 	step 87250, loss 0.033774, batch time 0.001697
# 	step 87500, loss 0.033977, batch time 0.001617
# 	step 87750, loss 0.033691, batch time 0.001510
# 88000/100000: test accuracy: 0.726000
# 	step 88000, loss 0.030736, batch time 0.040569
# 	step 88250, loss 0.034857, batch time 0.001685
# 	step 88500, loss 0.031112, batch time 0.001699
# 	step 88750, loss 0.030462, batch time 0.001750
# 89000/100000: test accuracy: 0.718500
# 	step 89000, loss 0.035692, batch time 0.048186
# 	step 89250, loss 0.035540, batch time 0.001662
# 	step 89500, loss 0.030183, batch time 0.001902
# 	step 89750, loss 0.030481, batch time 0.002333
# 90000/100000: test accuracy: 0.731000
# 	step 90000, loss 0.030019, batch time 0.051002
# 	step 90250, loss 0.032720, batch time 0.001625
# 	step 90500, loss 0.031519, batch time 0.001783
# 	step 90750, loss 0.033320, batch time 0.001749
# 91000/100000: test accuracy: 0.712300
# 	step 91000, loss 0.032391, batch time 0.043812
# 	step 91250, loss 0.033167, batch time 0.001599
# 	step 91500, loss 0.030243, batch time 0.001459
# 	step 91750, loss 0.030703, batch time 0.001666
# 92000/100000: test accuracy: 0.719700
# 	step 92000, loss 0.032079, batch time 0.039902
# 	step 92250, loss 0.030056, batch time 0.002143
# 	step 92500, loss 0.030486, batch time 0.001543
# 	step 92750, loss 0.030704, batch time 0.002169
# 93000/100000: test accuracy: 0.725500
# 	step 93000, loss 0.030821, batch time 0.038227
# 	step 93250, loss 0.033743, batch time 0.001602
# 	step 93500, loss 0.032586, batch time 0.001665
# 	step 93750, loss 0.031799, batch time 0.001742
# 94000/100000: test accuracy: 0.723100
# 	step 94000, loss 0.036531, batch time 0.036466
# 	step 94250, loss 0.030847, batch time 0.001612
# 	step 94500, loss 0.032902, batch time 0.001655
# 	step 94750, loss 0.031827, batch time 0.001551
# 95000/100000: test accuracy: 0.715900
# 	step 95000, loss 0.032610, batch time 0.037523
# 	step 95250, loss 0.027538, batch time 0.001594
# 	step 95500, loss 0.029594, batch time 0.001582
# 	step 95750, loss 0.032971, batch time 0.001689
# 96000/100000: test accuracy: 0.722800
# 	step 96000, loss 0.033232, batch time 0.036930
# 	step 96250, loss 0.030403, batch time 0.001926
# 	step 96500, loss 0.030417, batch time 0.001717
# 	step 96750, loss 0.029481, batch time 0.001652
# 97000/100000: test accuracy: 0.722200
# 	step 97000, loss 0.035955, batch time 0.038733
# 	step 97250, loss 0.029833, batch time 0.001627
# 	step 97500, loss 0.033186, batch time 0.001561
# 	step 97750, loss 0.030680, batch time 0.001684
# 98000/100000: test accuracy: 0.724200
# 	step 98000, loss 0.032921, batch time 0.041248
# 	step 98250, loss 0.032387, batch time 0.001617
# 	step 98500, loss 0.029721, batch time 0.001703
# 	step 98750, loss 0.030373, batch time 0.001916
# 99000/100000: test accuracy: 0.718800
# 	step 99000, loss 0.033097, batch time 0.036667
# 	step 99250, loss 0.030722, batch time 0.001615
# 	step 99500, loss 0.030230, batch time 0.001529
# 	step 99750, loss 0.031297, batch time 0.001553
#
# total runtime: 395.680895 seconds

# %%
feed = {x: mnist.test.images, y_: mnist.test.labels}
acc = accuracy.eval(feed_dict=feed)
print "final test accuracy: {:3f}".format(acc)
# Out:
# final test accuracy: 0.729600

# %% [markdown]
# ## Plot performance

# %%
plt.figure(0, figsize=(16,4))
plt.subplot(121)
plt.title("Loss")
plt.plot(loss_curve[1:,0], loss_curve[1:,1], 'b-')
plt.subplot(122)
plt.title("Accuracy")
plt.plot(acc_curve[1:,0], acc_curve[1:,1], 'r-')

with open('norm.p', 'w') as f:
    pickle.dump(acc_curve, f)

# %% [markdown]
# ## Plot weights

# %%
W_ = W.eval()
for i in range(0,10,5):
    img1 = np.reshape(W_[:,i], (28,28))
    img2 = np.reshape(W_[:,i+1], (28,28))
    img3 = np.reshape(W_[:,i+2], (28,28))
    img4 = np.reshape(W_[:,i+3], (28,28))
    img5 = np.reshape(W_[:,i+4], (28,28))
    plt.figure(i, figsize=(16,4))
    plt.subplot(151)
    plt.imshow(img1, cmap=cm.gray)
    plt.subplot(152)
    plt.imshow(img2, cmap=cm.gray)
    plt.subplot(153)
    plt.imshow(img3, cmap=cm.gray)
    plt.subplot(154)
    plt.imshow(img4, cmap=cm.gray)
    plt.subplot(155)
    plt.imshow(img5, cmap=cm.gray)

# %% [markdown]
# ## Saver IO

# %%
# saver = tf.train.Saver(tf.all_variables())
# load_was_success = True # yes, I'm being optimistic
# try:
#     save_dir = '/'.join(save_path.split('/')[:-1])
#     ckpt = tf.train.get_checkpoint_state(save_dir)
#     load_path = ckpt.model_checkpoint_path
#     saver.restore(sess, load_path)
# except:
#     print "no saved model to load. starting new session"
#     load_was_success = False
# else:
#     print "loaded model: {}".format(load_path)
#     saver = tf.train.Saver(tf.all_variables())
#     global_step = int(load_path.split('-')[-1])

# %%
# #fc 1 layer
# W1 = tf.get_variable("W1", shape=[xlen,ylen], initializer=init)
# b1 = tf.get_variable("b1", shape=[ylen], initializer=init)
# output = tf.nn.softmax(tf.matmul(x, W1) + b1)
