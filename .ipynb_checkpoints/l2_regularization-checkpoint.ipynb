# %% [markdown]
# # Magnitude Regularization

# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

import time
import cPickle as pickle
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Model baseline

# %%
batch_size = 32
global_step = 0
save_path = 'models/mag.ckpt'
xlen = 28*28
ylen = 10
reg_param = 1e-2

train_steps = 150000
info_every = 250
test_every = 1000

# %% [markdown]
# ## Build model

# %%
#awn
tf.reset_default_graph()
sess = tf.InteractiveSession()

x = tf.placeholder(tf.float32, shape=[None, xlen], name="x")
y_ = tf.placeholder(tf.float32, shape=[None, ylen], name="y_")
init = tf.truncated_normal_initializer(mean=0., stddev=.075, seed=1234, dtype=tf.float32)

reg = tf.contrib.layers.l2_regularizer(reg_param)
with tf.variable_scope("model", regularizer=reg):
    W = tf.get_variable("W", shape=[xlen,ylen], initializer=init)
output = tf.nn.softmax(tf.matmul(x, W))
sess.run(tf.initialize_all_variables())

# %%
loss = tf.nn.l2_loss( y_ - output ) / (ylen*batch_size) + sum(tf.get_collection(tf.GraphKeys.REGULARIZATION_LOSSES))

optimizer = tf.train.AdamOptimizer(1e-4)
grads = optimizer.compute_gradients(loss, var_list=tf.trainable_variables())
train_op = optimizer.apply_gradients(grads)

sess.run(tf.initialize_all_variables())

# %% [markdown]
# ## Model overview

# %%
total_parameters = 0 ; print "Model overview:"
for variable in tf.trainable_variables():
    shape = variable.get_shape()
    variable_parameters = 1
    for dim in shape:
        variable_parameters *= dim.value
    print '\tvariable "{}" has {} parameters' \
        .format(variable.name, variable_parameters)
    total_parameters += variable_parameters
print "Total of {} parameters".format(total_parameters)
# Out:
# Model overview:
# 	variable "model/W:0" has 7840 parameters
# Total of 7840 parameters

# %% [markdown]
# ## Train

# %%
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
loss_curve = np.zeros((train_steps/info_every, 2))
acc_curve = np.zeros((train_steps/test_every, 2))

begin = time.time()
for i in range(train_steps):
    batch_start = time.time()
    
    batch = mnist.train.next_batch(batch_size)
    feed = {x: batch[0], y_: batch[1]}
    train_loss, _ = sess.run([loss, train_op], feed_dict=feed)
    
    if i%test_every == 0:
        feed = {x: mnist.test.images, y_: mnist.test.labels}
        acc = accuracy.eval(feed_dict=feed)
        acc_curve[i/test_every,:] = [i, acc]
        print "{}/{}: test accuracy: {:3f}".format(i, train_steps, acc)
    if i%info_every == 0:
        loss_curve[i/info_every,:] = [i, train_loss]
        print "\tstep {}, loss {:3f}, batch time {:3f}".format(i, train_loss, time.time()-batch_start)
print "\ntotal runtime: {:3f} seconds".format(time.time()-begin)
# Out:
# 0/100000: test accuracy: 0.084700
# 	step 0, loss 0.218412, batch time 0.055922
# 	step 250, loss 0.137189, batch time 0.001238
# 	step 500, loss 0.092095, batch time 0.001843
# 	step 750, loss 0.069516, batch time 0.001791
# 1000/100000: test accuracy: 0.669500
# 	step 1000, loss 0.051340, batch time 0.038561
# 	step 1250, loss 0.045199, batch time 0.001020
# 	step 1500, loss 0.038524, batch time 0.001284
# 	step 1750, loss 0.041010, batch time 0.001788
# 2000/100000: test accuracy: 0.734800
# 	step 2000, loss 0.040785, batch time 0.041178
# 	step 2250, loss 0.036828, batch time 0.001560
# 	step 2500, loss 0.033737, batch time 0.002072
# 	step 2750, loss 0.031371, batch time 0.002807
# 3000/100000: test accuracy: 0.754700
# 	step 3000, loss 0.036411, batch time 0.035434
# 	step 3250, loss 0.030638, batch time 0.002129
# 	step 3500, loss 0.039213, batch time 0.001548
# 	step 3750, loss 0.039105, batch time 0.001032
# 4000/100000: test accuracy: 0.765600
# 	step 4000, loss 0.036747, batch time 0.048221
# 	step 4250, loss 0.039326, batch time 0.001103
# 	step 4500, loss 0.038411, batch time 0.001619
# 	step 4750, loss 0.038548, batch time 0.001135
# 5000/100000: test accuracy: 0.763000
# 	step 5000, loss 0.034007, batch time 0.036628
# 	step 5250, loss 0.036880, batch time 0.001522
# 	step 5500, loss 0.039111, batch time 0.001755
# 	step 5750, loss 0.035607, batch time 0.001174
# 6000/100000: test accuracy: 0.753900
# 	step 6000, loss 0.036658, batch time 0.134364
# 	step 6250, loss 0.037320, batch time 0.001231
# 	step 6500, loss 0.034809, batch time 0.001120
# 	step 6750, loss 0.038844, batch time 0.001120
# 7000/100000: test accuracy: 0.764800
# 	step 7000, loss 0.038640, batch time 0.044226
# 	step 7250, loss 0.037135, batch time 0.001347
# 	step 7500, loss 0.028444, batch time 0.001262
# 	step 7750, loss 0.035414, batch time 0.001004
# 8000/100000: test accuracy: 0.748100
# 	step 8000, loss 0.034846, batch time 0.068530
# 	step 8250, loss 0.039349, batch time 0.001267
# 	step 8500, loss 0.038887, batch time 0.001235
# 	step 8750, loss 0.038000, batch time 0.001158
# 9000/100000: test accuracy: 0.759300
# 	step 9000, loss 0.035140, batch time 0.034960
# 	step 9250, loss 0.036695, batch time 0.001494
# 	step 9500, loss 0.033388, batch time 0.001161
# 	step 9750, loss 0.036866, batch time 0.001147
# 10000/100000: test accuracy: 0.766700
# 	step 10000, loss 0.036410, batch time 0.034876
# 	step 10250, loss 0.037081, batch time 0.001088
# 	step 10500, loss 0.036900, batch time 0.001411
# 	step 10750, loss 0.035878, batch time 0.001346
# 11000/100000: test accuracy: 0.755800
# 	step 11000, loss 0.033381, batch time 0.037429
# 	step 11250, loss 0.035120, batch time 0.001633
# 	step 11500, loss 0.039351, batch time 0.001203
# 	step 11750, loss 0.036986, batch time 0.001079
# 12000/100000: test accuracy: 0.754300
# 	step 12000, loss 0.035458, batch time 0.120965
# 	step 12250, loss 0.032386, batch time 0.001034
# 	step 12500, loss 0.035377, batch time 0.001549
# 	step 12750, loss 0.038494, batch time 0.001410
# 13000/100000: test accuracy: 0.756200
# 	step 13000, loss 0.038102, batch time 0.086653
# 	step 13250, loss 0.039344, batch time 0.001503
# 	step 13500, loss 0.035371, batch time 0.001227
# 	step 13750, loss 0.036503, batch time 0.001320
# 14000/100000: test accuracy: 0.753100
# 	step 14000, loss 0.036349, batch time 0.080428
# 	step 14250, loss 0.038403, batch time 0.001233
# 	step 14500, loss 0.034874, batch time 0.003057
# 	step 14750, loss 0.037600, batch time 0.001445
# 15000/100000: test accuracy: 0.765300
# 	step 15000, loss 0.032101, batch time 0.036539
# 	step 15250, loss 0.037167, batch time 0.001230
# 	step 15500, loss 0.032163, batch time 0.001257
# 	step 15750, loss 0.038380, batch time 0.001161
# 16000/100000: test accuracy: 0.744100
# 	step 16000, loss 0.038310, batch time 0.039161
# 	step 16250, loss 0.036803, batch time 0.001200
# 	step 16500, loss 0.036248, batch time 0.001235
# 	step 16750, loss 0.032358, batch time 0.012834
# 17000/100000: test accuracy: 0.759800
# 	step 17000, loss 0.038007, batch time 0.112608
# 	step 17250, loss 0.035921, batch time 0.001119
# 	step 17500, loss 0.034998, batch time 0.001455
# 	step 17750, loss 0.035868, batch time 0.001304
# 18000/100000: test accuracy: 0.763600
# 	step 18000, loss 0.037832, batch time 0.069447
# 	step 18250, loss 0.035923, batch time 0.001315
# 	step 18500, loss 0.037522, batch time 0.001468
# 	step 18750, loss 0.033471, batch time 0.001887
# 19000/100000: test accuracy: 0.763200
# 	step 19000, loss 0.037917, batch time 0.039874
# 	step 19250, loss 0.040023, batch time 0.001393
# 	step 19500, loss 0.034823, batch time 0.001214
# 	step 19750, loss 0.035707, batch time 0.001297
# 20000/100000: test accuracy: 0.766400
# 	step 20000, loss 0.037589, batch time 0.087297
# 	step 20250, loss 0.034803, batch time 0.001193
# 	step 20500, loss 0.037119, batch time 0.001550
# 	step 20750, loss 0.038415, batch time 0.001576
# 21000/100000: test accuracy: 0.765300
# 	step 21000, loss 0.036572, batch time 0.077796
# 	step 21250, loss 0.035812, batch time 0.001276
# 	step 21500, loss 0.039315, batch time 0.001799
# 	step 21750, loss 0.039726, batch time 0.001301
# 22000/100000: test accuracy: 0.741300
# 	step 22000, loss 0.035552, batch time 0.081989
# 	step 22250, loss 0.037253, batch time 0.001434
# 	step 22500, loss 0.033577, batch time 0.001744
# 	step 22750, loss 0.036736, batch time 0.001159
# 23000/100000: test accuracy: 0.761000
# 	step 23000, loss 0.037683, batch time 0.105712
# 	step 23250, loss 0.035182, batch time 0.001346
# 	step 23500, loss 0.035815, batch time 0.001322
# 	step 23750, loss 0.038309, batch time 0.001163
# 24000/100000: test accuracy: 0.763200
# 	step 24000, loss 0.033683, batch time 0.049304
# 	step 24250, loss 0.037166, batch time 0.003362
# 	step 24500, loss 0.036958, batch time 0.001359
# 	step 24750, loss 0.035895, batch time 0.001770
# 25000/100000: test accuracy: 0.761000
# 	step 25000, loss 0.039467, batch time 0.124489
# 	step 25250, loss 0.037553, batch time 0.001545
# 	step 25500, loss 0.037151, batch time 0.002988
# 	step 25750, loss 0.038865, batch time 0.001072
# 26000/100000: test accuracy: 0.759600
# 	step 26000, loss 0.038846, batch time 0.133975
# 	step 26250, loss 0.038459, batch time 0.001311
# 	step 26500, loss 0.037170, batch time 0.001442
# 	step 26750, loss 0.037697, batch time 0.001412
# 27000/100000: test accuracy: 0.750800
# 	step 27000, loss 0.037229, batch time 0.066724
# 	step 27250, loss 0.037764, batch time 0.001392
# 	step 27500, loss 0.038201, batch time 0.001363
# 	step 27750, loss 0.034795, batch time 0.001423
# 28000/100000: test accuracy: 0.748100
# 	step 28000, loss 0.036731, batch time 0.103239
# 	step 28250, loss 0.038055, batch time 0.001274
# 	step 28500, loss 0.034588, batch time 0.001306
# 	step 28750, loss 0.033158, batch time 0.001275
# 29000/100000: test accuracy: 0.764100
# 	step 29000, loss 0.036902, batch time 0.100292
# 	step 29250, loss 0.033886, batch time 0.001315
# 	step 29500, loss 0.035571, batch time 0.001277
# 	step 29750, loss 0.037506, batch time 0.001246
# 30000/100000: test accuracy: 0.754500
# 	step 30000, loss 0.037186, batch time 0.046546
# 	step 30250, loss 0.034239, batch time 0.002007
# 	step 30500, loss 0.037615, batch time 0.001219
# 	step 30750, loss 0.034768, batch time 0.001043
# 31000/100000: test accuracy: 0.762900
# 	step 31000, loss 0.036881, batch time 0.069525
# 	step 31250, loss 0.036402, batch time 0.016782
# 	step 31500, loss 0.035623, batch time 0.001570
# 	step 31750, loss 0.036888, batch time 0.001416
# 32000/100000: test accuracy: 0.763900
# 	step 32000, loss 0.035099, batch time 0.070445
# 	step 32250, loss 0.036843, batch time 0.001751
# 	step 32500, loss 0.032088, batch time 0.001759
# 	step 32750, loss 0.035705, batch time 0.001380
# 33000/100000: test accuracy: 0.761800
# 	step 33000, loss 0.035640, batch time 0.089870
# 	step 33250, loss 0.038470, batch time 0.001078
# 	step 33500, loss 0.033338, batch time 0.001199
# 	step 33750, loss 0.032419, batch time 0.001102
# 34000/100000: test accuracy: 0.757700
# 	step 34000, loss 0.037819, batch time 0.040222
# 	step 34250, loss 0.037897, batch time 0.001437
# 	step 34500, loss 0.035729, batch time 0.001226
# 	step 34750, loss 0.036762, batch time 0.001493
# 35000/100000: test accuracy: 0.760100
# 	step 35000, loss 0.038449, batch time 0.099799
# 	step 35250, loss 0.034327, batch time 0.002106
# 	step 35500, loss 0.038412, batch time 0.001241
# 	step 35750, loss 0.035600, batch time 0.001650
# 36000/100000: test accuracy: 0.761900
# 	step 36000, loss 0.035465, batch time 0.094660
# 	step 36250, loss 0.036367, batch time 0.001537
# 	step 36500, loss 0.039431, batch time 0.001216
# 	step 36750, loss 0.036768, batch time 0.001122
# 37000/100000: test accuracy: 0.752300
# 	step 37000, loss 0.036858, batch time 0.039420
# 	step 37250, loss 0.037686, batch time 0.002056
# 	step 37500, loss 0.039775, batch time 0.001565
# 	step 37750, loss 0.037017, batch time 0.018709
# 38000/100000: test accuracy: 0.754500
# 	step 38000, loss 0.039871, batch time 0.045812
# 	step 38250, loss 0.035707, batch time 0.001118
# 	step 38500, loss 0.036365, batch time 0.001255
# 	step 38750, loss 0.038728, batch time 0.001329
# 39000/100000: test accuracy: 0.760300
# 	step 39000, loss 0.038672, batch time 0.113875
# 	step 39250, loss 0.034339, batch time 0.001252
# 	step 39500, loss 0.035049, batch time 0.083329
# 	step 39750, loss 0.033018, batch time 0.001382
# 40000/100000: test accuracy: 0.766300
# 	step 40000, loss 0.039028, batch time 0.038691
# 	step 40250, loss 0.039377, batch time 0.001350
# 	step 40500, loss 0.032671, batch time 0.001275
# 	step 40750, loss 0.037979, batch time 0.001316
# 41000/100000: test accuracy: 0.754200
# 	step 41000, loss 0.037410, batch time 0.054370
# 	step 41250, loss 0.035777, batch time 0.001496
# 	step 41500, loss 0.038030, batch time 0.001480
# 	step 41750, loss 0.037751, batch time 0.001433
# 42000/100000: test accuracy: 0.755100
# 	step 42000, loss 0.034269, batch time 0.057329
# 	step 42250, loss 0.034540, batch time 0.001658
# 	step 42500, loss 0.037913, batch time 0.001220
# 	step 42750, loss 0.039774, batch time 0.001270
# 43000/100000: test accuracy: 0.759600
# 	step 43000, loss 0.038024, batch time 0.080856
# 	step 43250, loss 0.037072, batch time 0.001282
# 	step 43500, loss 0.035842, batch time 0.001723
# 	step 43750, loss 0.037220, batch time 0.011501
# 44000/100000: test accuracy: 0.761300
# 	step 44000, loss 0.036464, batch time 0.108423
# 	step 44250, loss 0.040732, batch time 0.001149
# 	step 44500, loss 0.037193, batch time 0.001343
# 	step 44750, loss 0.036046, batch time 0.001136
# 45000/100000: test accuracy: 0.740000
# 	step 45000, loss 0.036180, batch time 0.041499
# 	step 45250, loss 0.033649, batch time 0.001664
# 	step 45500, loss 0.036772, batch time 0.001061
# 	step 45750, loss 0.035460, batch time 0.001565
# 46000/100000: test accuracy: 0.764200
# 	step 46000, loss 0.035798, batch time 0.042432
# 	step 46250, loss 0.037057, batch time 0.001404
# 	step 46500, loss 0.033770, batch time 0.026531
# 	step 46750, loss 0.039428, batch time 0.001391
# 47000/100000: test accuracy: 0.756500
# 	step 47000, loss 0.038457, batch time 0.135365
# 	step 47250, loss 0.036789, batch time 0.001306
# 	step 47500, loss 0.034615, batch time 0.001243
# 	step 47750, loss 0.033465, batch time 0.002831
# 48000/100000: test accuracy: 0.766800
# 	step 48000, loss 0.034826, batch time 0.039278
# 	step 48250, loss 0.037660, batch time 0.001119
# 	step 48500, loss 0.034404, batch time 0.001310
# 	step 48750, loss 0.035021, batch time 0.001354
# 49000/100000: test accuracy: 0.757400
# 	step 49000, loss 0.030158, batch time 0.146528
# 	step 49250, loss 0.038392, batch time 0.001112
# 	step 49500, loss 0.035756, batch time 0.001290
# 	step 49750, loss 0.037017, batch time 0.001118
# 50000/100000: test accuracy: 0.749300
# 	step 50000, loss 0.031737, batch time 0.126329
# 	step 50250, loss 0.039332, batch time 0.001772
# 	step 50500, loss 0.031104, batch time 0.001041
# 	step 50750, loss 0.038883, batch time 0.001197
# 51000/100000: test accuracy: 0.765600
# 	step 51000, loss 0.039102, batch time 0.055813
# 	step 51250, loss 0.034824, batch time 0.004394
# 	step 51500, loss 0.038336, batch time 0.001275
# 	step 51750, loss 0.035157, batch time 0.001487
# 52000/100000: test accuracy: 0.764000
# 	step 52000, loss 0.033870, batch time 0.058208
# 	step 52250, loss 0.036822, batch time 0.001927
# 	step 52500, loss 0.035674, batch time 0.001063
# 	step 52750, loss 0.033789, batch time 0.001257
# 53000/100000: test accuracy: 0.743000
# 	step 53000, loss 0.034843, batch time 0.058541
# 	step 53250, loss 0.037780, batch time 0.001305
# 	step 53500, loss 0.036154, batch time 0.022606
# 	step 53750, loss 0.037079, batch time 0.011453
# 54000/100000: test accuracy: 0.768300
# 	step 54000, loss 0.034470, batch time 0.074090
# 	step 54250, loss 0.041540, batch time 0.001426
# 	step 54500, loss 0.036360, batch time 0.001323
# 	step 54750, loss 0.033832, batch time 0.001720
# 55000/100000: test accuracy: 0.758700
# 	step 55000, loss 0.039289, batch time 0.036414
# 	step 55250, loss 0.034990, batch time 0.001337
# 	step 55500, loss 0.038347, batch time 0.000996
# 	step 55750, loss 0.034124, batch time 0.001321
# 56000/100000: test accuracy: 0.772800
# 	step 56000, loss 0.035734, batch time 0.084458
# 	step 56250, loss 0.036232, batch time 0.025659
# 	step 56500, loss 0.034901, batch time 0.001247
# 	step 56750, loss 0.036718, batch time 0.001910
# 57000/100000: test accuracy: 0.750600
# 	step 57000, loss 0.036103, batch time 0.121240
# 	step 57250, loss 0.035923, batch time 0.001208
# 	step 57500, loss 0.038137, batch time 0.001130
# 	step 57750, loss 0.037004, batch time 0.001367
# 58000/100000: test accuracy: 0.761100
# 	step 58000, loss 0.037504, batch time 0.105575
# 	step 58250, loss 0.035288, batch time 0.004200
# 	step 58500, loss 0.034843, batch time 0.002594
# 	step 58750, loss 0.036227, batch time 0.001283
# 59000/100000: test accuracy: 0.755200
# 	step 59000, loss 0.037975, batch time 0.104270
# 	step 59250, loss 0.037130, batch time 0.001346
# 	step 59500, loss 0.036041, batch time 0.001149
# 	step 59750, loss 0.034381, batch time 0.001245
# 60000/100000: test accuracy: 0.756400
# 	step 60000, loss 0.037492, batch time 0.108818
# 	step 60250, loss 0.035351, batch time 0.001586
# 	step 60500, loss 0.036452, batch time 0.001263
# 	step 60750, loss 0.041439, batch time 0.001130
# 61000/100000: test accuracy: 0.763000
# 	step 61000, loss 0.037217, batch time 0.085352
# 	step 61250, loss 0.038539, batch time 0.001587
# 	step 61500, loss 0.035313, batch time 0.001253
# 	step 61750, loss 0.038149, batch time 0.001297
# 62000/100000: test accuracy: 0.760400
# 	step 62000, loss 0.037334, batch time 0.050001
# 	step 62250, loss 0.037735, batch time 0.001232
# 	step 62500, loss 0.035157, batch time 0.001470
# 	step 62750, loss 0.034331, batch time 0.001600
# 63000/100000: test accuracy: 0.764800
# 	step 63000, loss 0.034528, batch time 0.077497
# 	step 63250, loss 0.037994, batch time 0.001578
# 	step 63500, loss 0.035360, batch time 0.001249
# 	step 63750, loss 0.036894, batch time 0.014465
# 64000/100000: test accuracy: 0.765700
# 	step 64000, loss 0.035553, batch time 0.040467
# 	step 64250, loss 0.036983, batch time 0.001297
# 	step 64500, loss 0.035570, batch time 0.001314
# 	step 64750, loss 0.036446, batch time 0.001907
# 65000/100000: test accuracy: 0.764500
# 	step 65000, loss 0.037992, batch time 0.048510
# 	step 65250, loss 0.031926, batch time 0.001295
# 	step 65500, loss 0.034874, batch time 0.001362
# 	step 65750, loss 0.035654, batch time 0.001217
# 66000/100000: test accuracy: 0.753200
# 	step 66000, loss 0.034796, batch time 0.062935
# 	step 66250, loss 0.034928, batch time 0.001351
# 	step 66500, loss 0.038905, batch time 0.001606
# 	step 66750, loss 0.033328, batch time 0.001181
# 67000/100000: test accuracy: 0.760700
# 	step 67000, loss 0.040504, batch time 0.048835
# 	step 67250, loss 0.034331, batch time 0.001217
# 	step 67500, loss 0.038473, batch time 0.001585
# 	step 67750, loss 0.035478, batch time 0.001210
# 68000/100000: test accuracy: 0.765700
# 	step 68000, loss 0.032270, batch time 0.087139
# 	step 68250, loss 0.034322, batch time 0.001217
# 	step 68500, loss 0.038316, batch time 0.001260
# 	step 68750, loss 0.035573, batch time 0.001338
# 69000/100000: test accuracy: 0.755100
# 	step 69000, loss 0.034450, batch time 0.073195
# 	step 69250, loss 0.037956, batch time 0.001505
# 	step 69500, loss 0.037058, batch time 0.001829
# 	step 69750, loss 0.038488, batch time 0.001362
# 70000/100000: test accuracy: 0.752900
# 	step 70000, loss 0.034366, batch time 0.082262
# 	step 70250, loss 0.035059, batch time 0.001434
# 	step 70500, loss 0.036288, batch time 0.001502
# 	step 70750, loss 0.033593, batch time 0.001270
# 71000/100000: test accuracy: 0.763100
# 	step 71000, loss 0.037098, batch time 0.160523
# 	step 71250, loss 0.036393, batch time 0.001111
# 	step 71500, loss 0.038181, batch time 0.001121
# 	step 71750, loss 0.036043, batch time 0.002407
# 72000/100000: test accuracy: 0.757600
# 	step 72000, loss 0.032533, batch time 0.095444
# 	step 72250, loss 0.035384, batch time 0.001571
# 	step 72500, loss 0.033307, batch time 0.001370
# 	step 72750, loss 0.036730, batch time 0.001184
# 73000/100000: test accuracy: 0.755300
# 	step 73000, loss 0.035669, batch time 0.044407
# 	step 73250, loss 0.038678, batch time 0.001420
# 	step 73500, loss 0.039414, batch time 0.001178
# 	step 73750, loss 0.035696, batch time 0.002027
# 74000/100000: test accuracy: 0.763200
# 	step 74000, loss 0.041329, batch time 0.037218
# 	step 74250, loss 0.033227, batch time 0.001560
# 	step 74500, loss 0.031639, batch time 0.001055
# 	step 74750, loss 0.035067, batch time 0.001178
# 75000/100000: test accuracy: 0.760600
# 	step 75000, loss 0.038913, batch time 0.084415
# 	step 75250, loss 0.036223, batch time 0.001950
# 	step 75500, loss 0.036972, batch time 0.000986
# 	step 75750, loss 0.038080, batch time 0.001929
# 76000/100000: test accuracy: 0.763900
# 	step 76000, loss 0.036509, batch time 0.039186
# 	step 76250, loss 0.034092, batch time 0.001048
# 	step 76500, loss 0.033865, batch time 0.001428
# 	step 76750, loss 0.036924, batch time 0.001370
# 77000/100000: test accuracy: 0.751600
# 	step 77000, loss 0.039820, batch time 0.048187
# 	step 77250, loss 0.035801, batch time 0.001253
# 	step 77500, loss 0.035412, batch time 0.001898
# 	step 77750, loss 0.039451, batch time 0.001223
# 78000/100000: test accuracy: 0.755100
# 	step 78000, loss 0.031722, batch time 0.069856
# 	step 78250, loss 0.036122, batch time 0.001270
# 	step 78500, loss 0.033517, batch time 0.003565
# 	step 78750, loss 0.036247, batch time 0.001193
# 79000/100000: test accuracy: 0.762600
# 	step 79000, loss 0.036965, batch time 0.061965
# 	step 79250, loss 0.033497, batch time 0.001420
# 	step 79500, loss 0.036204, batch time 0.001337
# 	step 79750, loss 0.034639, batch time 0.001245
# 80000/100000: test accuracy: 0.765800
# 	step 80000, loss 0.037496, batch time 0.114464
# 	step 80250, loss 0.038508, batch time 0.002118
# 	step 80500, loss 0.035641, batch time 0.001218
# 	step 80750, loss 0.037102, batch time 0.001208
# 81000/100000: test accuracy: 0.750000
# 	step 81000, loss 0.035338, batch time 0.049724
# 	step 81250, loss 0.036881, batch time 0.001427
# 	step 81500, loss 0.039332, batch time 0.001334
# 	step 81750, loss 0.036670, batch time 0.001182
# 82000/100000: test accuracy: 0.761700
# 	step 82000, loss 0.038230, batch time 0.043403
# 	step 82250, loss 0.040506, batch time 0.001650
# 	step 82500, loss 0.037621, batch time 0.001503
# 	step 82750, loss 0.036558, batch time 0.001233
# 83000/100000: test accuracy: 0.759700
# 	step 83000, loss 0.038793, batch time 0.067940
# 	step 83250, loss 0.033183, batch time 0.001295
# 	step 83500, loss 0.034894, batch time 0.033739
# 	step 83750, loss 0.032913, batch time 0.001278
# 84000/100000: test accuracy: 0.753600
# 	step 84000, loss 0.037431, batch time 0.047505
# 	step 84250, loss 0.036399, batch time 0.001544
# 	step 84500, loss 0.034683, batch time 0.001319
# 	step 84750, loss 0.036344, batch time 0.001181
# 85000/100000: test accuracy: 0.756900
# 	step 85000, loss 0.039143, batch time 0.037497
# 	step 85250, loss 0.040291, batch time 0.001246
# 	step 85500, loss 0.035506, batch time 0.001307
# 	step 85750, loss 0.037210, batch time 0.001285
# 86000/100000: test accuracy: 0.746700
# 	step 86000, loss 0.037311, batch time 0.184942
# 	step 86250, loss 0.038243, batch time 0.001044
# 	step 86500, loss 0.033537, batch time 0.001101
# 	step 86750, loss 0.037368, batch time 0.001402
# 87000/100000: test accuracy: 0.771600
# 	step 87000, loss 0.037150, batch time 0.058447
# 	step 87250, loss 0.035114, batch time 0.001154
# 	step 87500, loss 0.039292, batch time 0.001653
# 	step 87750, loss 0.035561, batch time 0.001095
# 88000/100000: test accuracy: 0.759700
# 	step 88000, loss 0.035550, batch time 0.067054
# 	step 88250, loss 0.036997, batch time 0.013733
# 	step 88500, loss 0.035151, batch time 0.001778
# 	step 88750, loss 0.036308, batch time 0.001111
# 89000/100000: test accuracy: 0.763700
# 	step 89000, loss 0.034898, batch time 0.035875
# 	step 89250, loss 0.036349, batch time 0.001293
# 	step 89500, loss 0.032741, batch time 0.001639
# 	step 89750, loss 0.035972, batch time 0.001199
# 90000/100000: test accuracy: 0.752200
# 	step 90000, loss 0.036257, batch time 0.040656
# 	step 90250, loss 0.036890, batch time 0.001290
# 	step 90500, loss 0.036201, batch time 0.001140
# 	step 90750, loss 0.033897, batch time 0.001213
# 91000/100000: test accuracy: 0.766600
# 	step 91000, loss 0.033926, batch time 0.034826
# 	step 91250, loss 0.034913, batch time 0.001242
# 	step 91500, loss 0.040245, batch time 0.001194
# 	step 91750, loss 0.037876, batch time 0.001187
# 92000/100000: test accuracy: 0.762300
# 	step 92000, loss 0.039026, batch time 0.061206
# 	step 92250, loss 0.037012, batch time 0.003369
# 	step 92500, loss 0.036376, batch time 0.001444
# 	step 92750, loss 0.037558, batch time 0.012510
# 93000/100000: test accuracy: 0.754300
# 	step 93000, loss 0.036465, batch time 0.043045
# 	step 93250, loss 0.035932, batch time 0.001231
# 	step 93500, loss 0.039000, batch time 0.010748
# 	step 93750, loss 0.038481, batch time 0.001335
# 94000/100000: test accuracy: 0.761500
# 	step 94000, loss 0.033818, batch time 0.048924
# 	step 94250, loss 0.036392, batch time 0.001322
# 	step 94500, loss 0.035999, batch time 0.002131
# 	step 94750, loss 0.036168, batch time 0.003585
# 95000/100000: test accuracy: 0.758900
# 	step 95000, loss 0.035407, batch time 0.045478
# 	step 95250, loss 0.037497, batch time 0.001480
# 	step 95500, loss 0.037116, batch time 0.001217
# 	step 95750, loss 0.034400, batch time 0.001192
# 96000/100000: test accuracy: 0.762200
# 	step 96000, loss 0.034532, batch time 0.048783
# 	step 96250, loss 0.038401, batch time 0.001256
# 	step 96500, loss 0.039558, batch time 0.001228
# 	step 96750, loss 0.027810, batch time 0.001115
# 97000/100000: test accuracy: 0.768800
# 	step 97000, loss 0.034650, batch time 0.040559
# 	step 97250, loss 0.035104, batch time 0.001349
# 	step 97500, loss 0.036973, batch time 0.001181
# 	step 97750, loss 0.036453, batch time 0.001132
# 98000/100000: test accuracy: 0.758100
# 	step 98000, loss 0.033175, batch time 0.101761
# 	step 98250, loss 0.038160, batch time 0.001143
# 	step 98500, loss 0.037041, batch time 0.002254
# 	step 98750, loss 0.036923, batch time 0.001820
# 99000/100000: test accuracy: 0.760400
# 	step 99000, loss 0.032337, batch time 0.058644
# 	step 99250, loss 0.036975, batch time 0.001447
# 	step 99500, loss 0.033963, batch time 0.001244
# 	step 99750, loss 0.033736, batch time 0.003399
#
# total runtime: 230.479945 seconds

# %%
feed = {x: mnist.test.images, y_: mnist.test.labels}
acc = accuracy.eval(feed_dict=feed)
print "final test accuracy: {:3f}".format(acc)
# Out:
# final test accuracy: 0.756300

# %% [markdown]
# ## Plot performance

# %%
plt.figure(0, figsize=(16,4))
plt.subplot(121)
plt.title("Loss")
plt.plot(loss_curve[1:,0], loss_curve[1:,1], 'b-')
plt.subplot(122)
plt.title("Accuracy")
plt.plot(acc_curve[1:,0], acc_curve[1:,1], 'r-')

with open('mag.p', 'w') as f:
    pickle.dump(acc_curve, f)

# %% [markdown]
# ## Plot weights

# %%
W_ = W.eval()
for i in range(0,10,5):
    img1 = np.reshape(W_[:,i], (28,28))
    img2 = np.reshape(W_[:,i+1], (28,28))
    img3 = np.reshape(W_[:,i+2], (28,28))
    img4 = np.reshape(W_[:,i+3], (28,28))
    img5 = np.reshape(W_[:,i+4], (28,28))
    plt.figure(i, figsize=(16,4))
    plt.subplot(151)
    plt.imshow(img1, cmap=cm.gray)
    plt.subplot(152)
    plt.imshow(img2, cmap=cm.gray)
    plt.subplot(153)
    plt.imshow(img3, cmap=cm.gray)
    plt.subplot(154)
    plt.imshow(img4, cmap=cm.gray)
    plt.subplot(155)
    plt.imshow(img5, cmap=cm.gray)

# %% [markdown]
# ## Saver IO

# %%
# saver = tf.train.Saver(tf.all_variables())
# load_was_success = True # yes, I'm being optimistic
# try:
#     save_dir = '/'.join(save_path.split('/')[:-1])
#     ckpt = tf.train.get_checkpoint_state(save_dir)
#     load_path = ckpt.model_checkpoint_path
#     saver.restore(sess, load_path)
# except:
#     print "no saved model to load. starting new session"
#     load_was_success = False
# else:
#     print "loaded model: {}".format(load_path)
#     saver = tf.train.Saver(tf.all_variables())
#     global_step = int(load_path.split('-')[-1])

# %%
# #fc 1 layer
# W1 = tf.get_variable("W1", shape=[xlen,ylen], initializer=init)
# b1 = tf.get_variable("b1", shape=[ylen], initializer=init)
# output = tf.nn.softmax(tf.matmul(x, W1) + b1)
