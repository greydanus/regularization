# %% [markdown]
# # No Regularization

# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

import time
import cPickle as pickle
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Model baseline

# %%
batch_size = 32
global_step = 0
save_path = 'models/noreg.ckpt'
xlen = 28*28
ylen = 10

train_steps = 150000
info_every = 250
test_every = 1000

# %% [markdown]
# ## Build model

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()

x = tf.placeholder(tf.float32, shape=[None, xlen], name="x")
y_ = tf.placeholder(tf.float32, shape=[None, ylen], name="y_")
init = tf.truncated_normal_initializer(mean=0., stddev=.075, seed=1234, dtype=tf.float32)

W = tf.get_variable("W", shape=[xlen,ylen], initializer=init)
output = tf.nn.softmax(tf.matmul(x, W))

# %%
loss = tf.nn.l2_loss( y_ - output ) / (ylen*batch_size)

optimizer = tf.train.AdamOptimizer(1e-4)
grads = optimizer.compute_gradients(loss, var_list=tf.trainable_variables())
train_op = optimizer.apply_gradients(grads)

sess.run(tf.initialize_all_variables())

# %% [markdown]
# ## Model overview

# %%
total_parameters = 0 ; print "Model overview:"
for variable in tf.trainable_variables():
    shape = variable.get_shape()
    variable_parameters = 1
    for dim in shape:
        variable_parameters *= dim.value
    print '\tvariable "{}" has {} parameters' \
        .format(variable.name, variable_parameters)
    total_parameters += variable_parameters
print "Total of {} parameters".format(total_parameters)
# Out:
# Model overview:
# 	variable "W:0" has 7840 parameters
# Total of 7840 parameters

# %% [markdown]
# ## Train

# %%
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
loss_curve = np.zeros((train_steps/info_every, 2))
acc_curve = np.zeros((train_steps/test_every, 2))

begin = time.time()
for i in range(train_steps):
    batch_start = time.time()
    
    batch = mnist.train.next_batch(batch_size)
    feed = {x: batch[0], y_: batch[1]}
    train_loss, _ = sess.run([loss, train_op], feed_dict=feed)
    
    if i%test_every == 0:
        feed = {x: mnist.test.images, y_: mnist.test.labels}
        acc = accuracy.eval(feed_dict=feed)
        acc_curve[i/test_every,:] = [i, acc]
        print "{}/{}: test accuracy: {:3f}".format(i, train_steps, acc)
    if i%info_every == 0:
        loss_curve[i/info_every,:] = [i, train_loss]
        print "\tstep {}, loss {:3f}, batch time {:3f}".format(i, train_loss, time.time()-batch_start)
print "\ntotal runtime: {:3f} seconds".format(time.time()-begin)
# Out:
# 0/150000: test accuracy: 0.121500
# 	step 0, loss 0.047250, batch time 0.049375
# 	step 250, loss 0.036354, batch time 0.000831
# 	step 500, loss 0.031989, batch time 0.000775
# 	step 750, loss 0.024198, batch time 0.000854
# 1000/150000: test accuracy: 0.821600
# 	step 1000, loss 0.015752, batch time 0.035006
# 	step 1250, loss 0.018305, batch time 0.002728
# 	step 1500, loss 0.014666, batch time 0.000870
# 	step 1750, loss 0.015437, batch time 0.000865
# 2000/150000: test accuracy: 0.864400
# 	step 2000, loss 0.016859, batch time 0.041249
# 	step 2250, loss 0.011484, batch time 0.000769
# 	step 2500, loss 0.010172, batch time 0.000971
# 	step 2750, loss 0.006286, batch time 0.000946
# 3000/150000: test accuracy: 0.881400
# 	step 3000, loss 0.008799, batch time 0.037275
# 	step 3250, loss 0.010131, batch time 0.000678
# 	step 3500, loss 0.015509, batch time 0.001228
# 	step 3750, loss 0.007880, batch time 0.000664
# 4000/150000: test accuracy: 0.893000
# 	step 4000, loss 0.005527, batch time 0.037200
# 	step 4250, loss 0.009101, batch time 0.000729
# 	step 4500, loss 0.015044, batch time 0.001072
# 	step 4750, loss 0.010318, batch time 0.000711
# 5000/150000: test accuracy: 0.898400
# 	step 5000, loss 0.008482, batch time 0.037910
# 	step 5250, loss 0.007866, batch time 0.001122
# 	step 5500, loss 0.009140, batch time 0.000812
# 	step 5750, loss 0.006074, batch time 0.000848
# 6000/150000: test accuracy: 0.903000
# 	step 6000, loss 0.010286, batch time 0.034905
# 	step 6250, loss 0.011226, batch time 0.000643
# 	step 6500, loss 0.006069, batch time 0.000642
# 	step 6750, loss 0.012114, batch time 0.000772
# 7000/150000: test accuracy: 0.907900
# 	step 7000, loss 0.004648, batch time 0.034464
# 	step 7250, loss 0.005406, batch time 0.001027
# 	step 7500, loss 0.003281, batch time 0.000849
# 	step 7750, loss 0.007828, batch time 0.000866
# 8000/150000: test accuracy: 0.909700
# 	step 8000, loss 0.003391, batch time 0.035048
# 	step 8250, loss 0.004201, batch time 0.001102
# 	step 8500, loss 0.008396, batch time 0.000767
# 	step 8750, loss 0.005919, batch time 0.000960
# 9000/150000: test accuracy: 0.912000
# 	step 9000, loss 0.009407, batch time 0.036040
# 	step 9250, loss 0.002139, batch time 0.000815
# 	step 9500, loss 0.010093, batch time 0.000913
# 	step 9750, loss 0.006656, batch time 0.000786
# 10000/150000: test accuracy: 0.913900
# 	step 10000, loss 0.005707, batch time 0.033132
# 	step 10250, loss 0.004112, batch time 0.000762
# 	step 10500, loss 0.009075, batch time 0.000752
# 	step 10750, loss 0.005131, batch time 0.000647
# 11000/150000: test accuracy: 0.914700
# 	step 11000, loss 0.005328, batch time 0.040477
# 	step 11250, loss 0.009654, batch time 0.000927
# 	step 11500, loss 0.007382, batch time 0.000622
# 	step 11750, loss 0.004216, batch time 0.000988
# 12000/150000: test accuracy: 0.916900
# 	step 12000, loss 0.010158, batch time 0.032659
# 	step 12250, loss 0.008043, batch time 0.000707
# 	step 12500, loss 0.006510, batch time 0.001002
# 	step 12750, loss 0.006225, batch time 0.000781
# 13000/150000: test accuracy: 0.916800
# 	step 13000, loss 0.004424, batch time 0.035351
# 	step 13250, loss 0.008784, batch time 0.000822
# 	step 13500, loss 0.008200, batch time 0.000832
# 	step 13750, loss 0.006205, batch time 0.001066
# 14000/150000: test accuracy: 0.917900
# 	step 14000, loss 0.006342, batch time 0.037107
# 	step 14250, loss 0.005274, batch time 0.000981
# 	step 14500, loss 0.007293, batch time 0.000670
# 	step 14750, loss 0.009172, batch time 0.000839
# 15000/150000: test accuracy: 0.918900
# 	step 15000, loss 0.006654, batch time 0.032333
# 	step 15250, loss 0.013979, batch time 0.000934
# 	step 15500, loss 0.007717, batch time 0.001678
# 	step 15750, loss 0.010070, batch time 0.000786
# 16000/150000: test accuracy: 0.918900
# 	step 16000, loss 0.006892, batch time 0.035150
# 	step 16250, loss 0.006924, batch time 0.000669
# 	step 16500, loss 0.005625, batch time 0.000667
# 	step 16750, loss 0.010671, batch time 0.001227
# 17000/150000: test accuracy: 0.921100
# 	step 17000, loss 0.008572, batch time 0.035636
# 	step 17250, loss 0.007725, batch time 0.001324
# 	step 17500, loss 0.009664, batch time 0.000749
# 	step 17750, loss 0.003730, batch time 0.000728
# 18000/150000: test accuracy: 0.921500
# 	step 18000, loss 0.005014, batch time 0.034695
# 	step 18250, loss 0.014765, batch time 0.000805
# 	step 18500, loss 0.004831, batch time 0.000948
# 	step 18750, loss 0.007276, batch time 0.000760
# 19000/150000: test accuracy: 0.921400
# 	step 19000, loss 0.006391, batch time 0.039941
# 	step 19250, loss 0.006009, batch time 0.000885
# 	step 19500, loss 0.002765, batch time 0.000806
# 	step 19750, loss 0.005724, batch time 0.000783
# 20000/150000: test accuracy: 0.922900
# 	step 20000, loss 0.002495, batch time 0.037820
# 	step 20250, loss 0.007935, batch time 0.000830
# 	step 20500, loss 0.011277, batch time 0.000679
# 	step 20750, loss 0.005360, batch time 0.001063
# 21000/150000: test accuracy: 0.922700
# 	step 21000, loss 0.003714, batch time 0.035560
# 	step 21250, loss 0.001944, batch time 0.000813
# 	step 21500, loss 0.007684, batch time 0.001014
# 	step 21750, loss 0.008007, batch time 0.000827
# 22000/150000: test accuracy: 0.923400
# 	step 22000, loss 0.004006, batch time 0.032867
# 	step 22250, loss 0.007664, batch time 0.000809
# 	step 22500, loss 0.004177, batch time 0.000873
# 	step 22750, loss 0.006276, batch time 0.000753
# 23000/150000: test accuracy: 0.923600
# 	step 23000, loss 0.006211, batch time 0.036004
# 	step 23250, loss 0.012258, batch time 0.000637
# 	step 23500, loss 0.007706, batch time 0.001540
# 	step 23750, loss 0.008722, batch time 0.000798
# 24000/150000: test accuracy: 0.924600
# 	step 24000, loss 0.009326, batch time 0.032602
# 	step 24250, loss 0.001573, batch time 0.000849
# 	step 24500, loss 0.008452, batch time 0.000699
# 	step 24750, loss 0.007988, batch time 0.000755
# 25000/150000: test accuracy: 0.924200
# 	step 25000, loss 0.007301, batch time 0.036306
# 	step 25250, loss 0.007226, batch time 0.000674
# 	step 25500, loss 0.004247, batch time 0.000839
# 	step 25750, loss 0.006736, batch time 0.001104
# 26000/150000: test accuracy: 0.924600
# 	step 26000, loss 0.002750, batch time 0.034914
# 	step 26250, loss 0.003776, batch time 0.000808
# 	step 26500, loss 0.004852, batch time 0.000837
# 	step 26750, loss 0.002326, batch time 0.000743
# 27000/150000: test accuracy: 0.924900
# 	step 27000, loss 0.004693, batch time 0.033050
# 	step 27250, loss 0.011681, batch time 0.000636
# 	step 27500, loss 0.008726, batch time 0.000790
# 	step 27750, loss 0.004294, batch time 0.000830
# 28000/150000: test accuracy: 0.925000
# 	step 28000, loss 0.008319, batch time 0.034047
# 	step 28250, loss 0.005986, batch time 0.000681
# 	step 28500, loss 0.004943, batch time 0.001872
# 	step 28750, loss 0.005876, batch time 0.000664
# 29000/150000: test accuracy: 0.925300
# 	step 29000, loss 0.006114, batch time 0.034510
# 	step 29250, loss 0.004168, batch time 0.000949
# 	step 29500, loss 0.002678, batch time 0.000632
# 	step 29750, loss 0.007863, batch time 0.001144
# 30000/150000: test accuracy: 0.926100
# 	step 30000, loss 0.006865, batch time 0.036042
# 	step 30250, loss 0.004445, batch time 0.000715
# 	step 30500, loss 0.002202, batch time 0.000810
# 	step 30750, loss 0.008960, batch time 0.000672
# 31000/150000: test accuracy: 0.926400
# 	step 31000, loss 0.004168, batch time 0.037765
# 	step 31250, loss 0.010298, batch time 0.000699
# 	step 31500, loss 0.002786, batch time 0.000650
# 	step 31750, loss 0.005193, batch time 0.000872
# 32000/150000: test accuracy: 0.926600
# 	step 32000, loss 0.006430, batch time 0.030686
# 	step 32250, loss 0.007862, batch time 0.000900
# 	step 32500, loss 0.006013, batch time 0.000740
# 	step 32750, loss 0.001719, batch time 0.000888
# 33000/150000: test accuracy: 0.925500
# 	step 33000, loss 0.006474, batch time 0.031738
# 	step 33250, loss 0.002766, batch time 0.000691
# 	step 33500, loss 0.011109, batch time 0.000813
# 	step 33750, loss 0.007298, batch time 0.000752
# 34000/150000: test accuracy: 0.926200
# 	step 34000, loss 0.000265, batch time 0.033073
# 	step 34250, loss 0.007756, batch time 0.000797
# 	step 34500, loss 0.003776, batch time 0.000833
# 	step 34750, loss 0.005564, batch time 0.000720
# 35000/150000: test accuracy: 0.925800
# 	step 35000, loss 0.004183, batch time 0.032823
# 	step 35250, loss 0.008901, batch time 0.000813
# 	step 35500, loss 0.007221, batch time 0.000795
# 	step 35750, loss 0.001096, batch time 0.000860
# 36000/150000: test accuracy: 0.927200
# 	step 36000, loss 0.003280, batch time 0.033685
# 	step 36250, loss 0.004151, batch time 0.000666
# 	step 36500, loss 0.006385, batch time 0.000716
# 	step 36750, loss 0.003010, batch time 0.000763
# 37000/150000: test accuracy: 0.927200
# 	step 37000, loss 0.005801, batch time 0.033194
# 	step 37250, loss 0.010869, batch time 0.001942
# 	step 37500, loss 0.002279, batch time 0.001096
# 	step 37750, loss 0.003651, batch time 0.000703
# 38000/150000: test accuracy: 0.927500
# 	step 38000, loss 0.001737, batch time 0.035077
# 	step 38250, loss 0.006890, batch time 0.001035
# 	step 38500, loss 0.006445, batch time 0.000766
# 	step 38750, loss 0.007213, batch time 0.000636
# 39000/150000: test accuracy: 0.927200
# 	step 39000, loss 0.005850, batch time 0.033174
# 	step 39250, loss 0.002737, batch time 0.000710
# 	step 39500, loss 0.003639, batch time 0.000892
# 	step 39750, loss 0.004577, batch time 0.000911
# 40000/150000: test accuracy: 0.927300
# 	step 40000, loss 0.007673, batch time 0.031810
# 	step 40250, loss 0.001382, batch time 0.000773
# 	step 40500, loss 0.009712, batch time 0.000704
# 	step 40750, loss 0.006768, batch time 0.000653
# 41000/150000: test accuracy: 0.928800
# 	step 41000, loss 0.000741, batch time 0.035069
# 	step 41250, loss 0.006080, batch time 0.000812
# 	step 41500, loss 0.003418, batch time 0.000744
# 	step 41750, loss 0.010848, batch time 0.000962
# 42000/150000: test accuracy: 0.928600
# 	step 42000, loss 0.004925, batch time 0.032339
# 	step 42250, loss 0.008598, batch time 0.000706
# 	step 42500, loss 0.005563, batch time 0.000747
# 	step 42750, loss 0.002984, batch time 0.000629
# 43000/150000: test accuracy: 0.928100
# 	step 43000, loss 0.004474, batch time 0.032231
# 	step 43250, loss 0.001255, batch time 0.000638
# 	step 43500, loss 0.002953, batch time 0.000838
# 	step 43750, loss 0.006880, batch time 0.000719
# 44000/150000: test accuracy: 0.928900
# 	step 44000, loss 0.004752, batch time 0.034075
# 	step 44250, loss 0.005975, batch time 0.000767
# 	step 44500, loss 0.005781, batch time 0.000714
# 	step 44750, loss 0.008173, batch time 0.000749
# 45000/150000: test accuracy: 0.929400
# 	step 45000, loss 0.008012, batch time 0.034788
# 	step 45250, loss 0.003172, batch time 0.000900
# 	step 45500, loss 0.006376, batch time 0.000662
# 	step 45750, loss 0.005602, batch time 0.001150
# 46000/150000: test accuracy: 0.928700
# 	step 46000, loss 0.004152, batch time 0.032729
# 	step 46250, loss 0.009190, batch time 0.000681
# 	step 46500, loss 0.005662, batch time 0.000822
# 	step 46750, loss 0.010784, batch time 0.000634
# 47000/150000: test accuracy: 0.929700
# 	step 47000, loss 0.007499, batch time 0.032256
# 	step 47250, loss 0.002956, batch time 0.000702
# 	step 47500, loss 0.006647, batch time 0.000723
# 	step 47750, loss 0.006788, batch time 0.000699
# 48000/150000: test accuracy: 0.929200
# 	step 48000, loss 0.002005, batch time 0.034232
# 	step 48250, loss 0.004978, batch time 0.000736
# 	step 48500, loss 0.004933, batch time 0.000674
# 	step 48750, loss 0.011071, batch time 0.000730
# 49000/150000: test accuracy: 0.930200
# 	step 49000, loss 0.004321, batch time 0.032215
# 	step 49250, loss 0.001443, batch time 0.000786
# 	step 49500, loss 0.003224, batch time 0.000897
# 	step 49750, loss 0.003928, batch time 0.000817
# 50000/150000: test accuracy: 0.928700
# 	step 50000, loss 0.007055, batch time 0.036980
# 	step 50250, loss 0.003346, batch time 0.000778
# 	step 50500, loss 0.007953, batch time 0.000707
# 	step 50750, loss 0.004718, batch time 0.000721
# 51000/150000: test accuracy: 0.929400
# 	step 51000, loss 0.009711, batch time 0.035398
# 	step 51250, loss 0.006678, batch time 0.000728
# 	step 51500, loss 0.005529, batch time 0.000861
# 	step 51750, loss 0.007117, batch time 0.001656
# 52000/150000: test accuracy: 0.930100
# 	step 52000, loss 0.002613, batch time 0.034181
# 	step 52250, loss 0.005992, batch time 0.000720
# 	step 52500, loss 0.007656, batch time 0.000879
# 	step 52750, loss 0.006203, batch time 0.000762
# 53000/150000: test accuracy: 0.929700
# 	step 53000, loss 0.006311, batch time 0.035441
# 	step 53250, loss 0.009500, batch time 0.000667
# 	step 53500, loss 0.006268, batch time 0.000747
# 	step 53750, loss 0.005444, batch time 0.000989
# 54000/150000: test accuracy: 0.930100
# 	step 54000, loss 0.006092, batch time 0.032798
# 	step 54250, loss 0.002959, batch time 0.000700
# 	step 54500, loss 0.000470, batch time 0.000891
# 	step 54750, loss 0.003978, batch time 0.000761
# 55000/150000: test accuracy: 0.929400
# 	step 55000, loss 0.008277, batch time 0.034128
# 	step 55250, loss 0.006034, batch time 0.000750
# 	step 55500, loss 0.004340, batch time 0.000780
# 	step 55750, loss 0.002763, batch time 0.000882
# 56000/150000: test accuracy: 0.930700
# 	step 56000, loss 0.002876, batch time 0.034058
# 	step 56250, loss 0.000583, batch time 0.000726
# 	step 56500, loss 0.007508, batch time 0.000714
# 	step 56750, loss 0.013911, batch time 0.000889
# 57000/150000: test accuracy: 0.929600
# 	step 57000, loss 0.010631, batch time 0.034514
# 	step 57250, loss 0.008508, batch time 0.000659
# 	step 57500, loss 0.005297, batch time 0.001799
# 	step 57750, loss 0.008785, batch time 0.000840
# 58000/150000: test accuracy: 0.930600
# 	step 58000, loss 0.006062, batch time 0.035448
# 	step 58250, loss 0.003385, batch time 0.001078
# 	step 58500, loss 0.008746, batch time 0.000680
# 	step 58750, loss 0.005146, batch time 0.000945
# 59000/150000: test accuracy: 0.930100
# 	step 59000, loss 0.008156, batch time 0.036361
# 	step 59250, loss 0.004026, batch time 0.000706
# 	step 59500, loss 0.003303, batch time 0.000679
# 	step 59750, loss 0.000549, batch time 0.000874
# 60000/150000: test accuracy: 0.930000
# 	step 60000, loss 0.003336, batch time 0.033379
# 	step 60250, loss 0.003772, batch time 0.000768
# 	step 60500, loss 0.000753, batch time 0.000692
# 	step 60750, loss 0.010861, batch time 0.000733
# 61000/150000: test accuracy: 0.930200
# 	step 61000, loss 0.006779, batch time 0.035164
# 	step 61250, loss 0.004504, batch time 0.000938
# 	step 61500, loss 0.005184, batch time 0.000796
# 	step 61750, loss 0.009401, batch time 0.000754
# 62000/150000: test accuracy: 0.930400
# 	step 62000, loss 0.000312, batch time 0.032173
# 	step 62250, loss 0.004637, batch time 0.000797
# 	step 62500, loss 0.003814, batch time 0.000919
# 	step 62750, loss 0.012033, batch time 0.000921
# 63000/150000: test accuracy: 0.930700
# 	step 63000, loss 0.006188, batch time 0.033979
# 	step 63250, loss 0.008705, batch time 0.001008
# 	step 63500, loss 0.001970, batch time 0.000717
# 	step 63750, loss 0.001549, batch time 0.000736
# 64000/150000: test accuracy: 0.930400
# 	step 64000, loss 0.000940, batch time 0.034560
# 	step 64250, loss 0.011800, batch time 0.000848
# 	step 64500, loss 0.001661, batch time 0.000635
# 	step 64750, loss 0.009072, batch time 0.000811
# 65000/150000: test accuracy: 0.930600
# 	step 65000, loss 0.001321, batch time 0.032029
# 	step 65250, loss 0.004400, batch time 0.000894
# 	step 65500, loss 0.004720, batch time 0.000712
# 	step 65750, loss 0.007264, batch time 0.000870
# 66000/150000: test accuracy: 0.930100
# 	step 66000, loss 0.000643, batch time 0.033232
# 	step 66250, loss 0.002267, batch time 0.000912
# 	step 66500, loss 0.008177, batch time 0.000780
# 	step 66750, loss 0.007602, batch time 0.000860
# 67000/150000: test accuracy: 0.931100
# 	step 67000, loss 0.000988, batch time 0.032995
# 	step 67250, loss 0.004525, batch time 0.000756
# 	step 67500, loss 0.004160, batch time 0.001054
# 	step 67750, loss 0.006006, batch time 0.000951
# 68000/150000: test accuracy: 0.931000
# 	step 68000, loss 0.004160, batch time 0.034391
# 	step 68250, loss 0.009897, batch time 0.000750
# 	step 68500, loss 0.009163, batch time 0.000813
# 	step 68750, loss 0.007091, batch time 0.000779
# 69000/150000: test accuracy: 0.931000
# 	step 69000, loss 0.005399, batch time 0.037481
# 	step 69250, loss 0.003957, batch time 0.000733
# 	step 69500, loss 0.002429, batch time 0.000780
# 	step 69750, loss 0.009041, batch time 0.000742
# 70000/150000: test accuracy: 0.931500
# 	step 70000, loss 0.004692, batch time 0.032455
# 	step 70250, loss 0.005664, batch time 0.000984
# 	step 70500, loss 0.004349, batch time 0.000791
# 	step 70750, loss 0.004718, batch time 0.000657
# 71000/150000: test accuracy: 0.930700
# 	step 71000, loss 0.004760, batch time 0.033719
# 	step 71250, loss 0.004673, batch time 0.000762
# 	step 71500, loss 0.004234, batch time 0.000976
# 	step 71750, loss 0.003786, batch time 0.000745
# 72000/150000: test accuracy: 0.930500
# 	step 72000, loss 0.004512, batch time 0.036568
# 	step 72250, loss 0.003880, batch time 0.000913
# 	step 72500, loss 0.005109, batch time 0.000659
# 	step 72750, loss 0.002330, batch time 0.000810
# 73000/150000: test accuracy: 0.930700
# 	step 73000, loss 0.002631, batch time 0.034580
# 	step 73250, loss 0.001805, batch time 0.000706
# 	step 73500, loss 0.005916, batch time 0.001039
# 	step 73750, loss 0.007028, batch time 0.000995
# 74000/150000: test accuracy: 0.931000
# 	step 74000, loss 0.004568, batch time 0.034896
# 	step 74250, loss 0.009565, batch time 0.000935
# 	step 74500, loss 0.006879, batch time 0.000777
# 	step 74750, loss 0.007168, batch time 0.000938
# 75000/150000: test accuracy: 0.930900
# 	step 75000, loss 0.004232, batch time 0.036836
# 	step 75250, loss 0.011204, batch time 0.000828
# 	step 75500, loss 0.004712, batch time 0.000881
# 	step 75750, loss 0.005829, batch time 0.000728
# 76000/150000: test accuracy: 0.930600
# 	step 76000, loss 0.008049, batch time 0.033059
# 	step 76250, loss 0.004430, batch time 0.000786
# 	step 76500, loss 0.004698, batch time 0.000703
# 	step 76750, loss 0.006087, batch time 0.000773
# 77000/150000: test accuracy: 0.931400
# 	step 77000, loss 0.010303, batch time 0.034265
# 	step 77250, loss 0.005533, batch time 0.000664
# 	step 77500, loss 0.004500, batch time 0.000754
# 	step 77750, loss 0.009859, batch time 0.001295
# 78000/150000: test accuracy: 0.931400
# 	step 78000, loss 0.006924, batch time 0.033896
# 	step 78250, loss 0.007882, batch time 0.001250
# 	step 78500, loss 0.006696, batch time 0.000802
# 	step 78750, loss 0.010341, batch time 0.000738
# 79000/150000: test accuracy: 0.930700
# 	step 79000, loss 0.009066, batch time 0.033637
# 	step 79250, loss 0.004167, batch time 0.000884
# 	step 79500, loss 0.002439, batch time 0.001107
# 	step 79750, loss 0.009232, batch time 0.000696
# 80000/150000: test accuracy: 0.931400
# 	step 80000, loss 0.008817, batch time 0.035580
# 	step 80250, loss 0.001772, batch time 0.000972
# 	step 80500, loss 0.004247, batch time 0.000723
# 	step 80750, loss 0.003121, batch time 0.000858
# 81000/150000: test accuracy: 0.931300
# 	step 81000, loss 0.010512, batch time 0.034701
# 	step 81250, loss 0.002459, batch time 0.000690
# 	step 81500, loss 0.002470, batch time 0.001039
# 	step 81750, loss 0.004082, batch time 0.000776
# 82000/150000: test accuracy: 0.930900
# 	step 82000, loss 0.001963, batch time 0.033630
# 	step 82250, loss 0.005549, batch time 0.000887
# 	step 82500, loss 0.003878, batch time 0.000785
# 	step 82750, loss 0.008064, batch time 0.000961
# 83000/150000: test accuracy: 0.931800
# 	step 83000, loss 0.001796, batch time 0.033687
# 	step 83250, loss 0.005618, batch time 0.003930
# 	step 83500, loss 0.008283, batch time 0.000659
# 	step 83750, loss 0.006659, batch time 0.000868
# 84000/150000: test accuracy: 0.931800
# 	step 84000, loss 0.004647, batch time 0.033741
# 	step 84250, loss 0.003373, batch time 0.000763
# 	step 84500, loss 0.007010, batch time 0.000571
# 	step 84750, loss 0.004680, batch time 0.001163
# 85000/150000: test accuracy: 0.931800
# 	step 85000, loss 0.006161, batch time 0.033018
# 	step 85250, loss 0.004395, batch time 0.000678
# 	step 85500, loss 0.013527, batch time 0.001066
# 	step 85750, loss 0.007954, batch time 0.000687
# 86000/150000: test accuracy: 0.931600
# 	step 86000, loss 0.003711, batch time 0.034793
# 	step 86250, loss 0.003999, batch time 0.000910
# 	step 86500, loss 0.003773, batch time 0.001834
# 	step 86750, loss 0.007087, batch time 0.000740
# 87000/150000: test accuracy: 0.931300
# 	step 87000, loss 0.005345, batch time 0.032537
# 	step 87250, loss 0.005835, batch time 0.000867
# 	step 87500, loss 0.005875, batch time 0.001042
# 	step 87750, loss 0.008850, batch time 0.000757
# 88000/150000: test accuracy: 0.931700
# 	step 88000, loss 0.005631, batch time 0.038372
# 	step 88250, loss 0.001810, batch time 0.000681
# 	step 88500, loss 0.011242, batch time 0.000799
# 	step 88750, loss 0.004039, batch time 0.001008
# 89000/150000: test accuracy: 0.931200
# 	step 89000, loss 0.005704, batch time 0.034888
# 	step 89250, loss 0.006151, batch time 0.000805
# 	step 89500, loss 0.010487, batch time 0.000675
# 	step 89750, loss 0.001333, batch time 0.000709
# 90000/150000: test accuracy: 0.931100
# 	step 90000, loss 0.009396, batch time 0.032193
# 	step 90250, loss 0.001808, batch time 0.000778
# 	step 90500, loss 0.005866, batch time 0.000825
# 	step 90750, loss 0.010034, batch time 0.001446
# 91000/150000: test accuracy: 0.931400
# 	step 91000, loss 0.004057, batch time 0.035847
# 	step 91250, loss 0.007438, batch time 0.000688
# 	step 91500, loss 0.004837, batch time 0.000708
# 	step 91750, loss 0.005943, batch time 0.000652
# 92000/150000: test accuracy: 0.931300
# 	step 92000, loss 0.003372, batch time 0.032563
# 	step 92250, loss 0.002880, batch time 0.000803
# 	step 92500, loss 0.006761, batch time 0.000928
# 	step 92750, loss 0.007022, batch time 0.001156
# 93000/150000: test accuracy: 0.931400
# 	step 93000, loss 0.005055, batch time 0.035939
# 	step 93250, loss 0.003237, batch time 0.000634
# 	step 93500, loss 0.002856, batch time 0.000921
# 	step 93750, loss 0.001697, batch time 0.000736
# 94000/150000: test accuracy: 0.931600
# 	step 94000, loss 0.003967, batch time 0.032484
# 	step 94250, loss 0.002687, batch time 0.000727
# 	step 94500, loss 0.011455, batch time 0.000983
# 	step 94750, loss 0.005493, batch time 0.000920
# 95000/150000: test accuracy: 0.932300
# 	step 95000, loss 0.002237, batch time 0.036517
# 	step 95250, loss 0.003078, batch time 0.000668
# 	step 95500, loss 0.004280, batch time 0.000652
# 	step 95750, loss 0.001408, batch time 0.000751
# 96000/150000: test accuracy: 0.931500
# 	step 96000, loss 0.001449, batch time 0.032749
# 	step 96250, loss 0.001525, batch time 0.000674
# 	step 96500, loss 0.006222, batch time 0.000723
# 	step 96750, loss 0.003024, batch time 0.000714
# 97000/150000: test accuracy: 0.931100
# 	step 97000, loss 0.005500, batch time 0.034776
# 	step 97250, loss 0.002860, batch time 0.000630
# 	step 97500, loss 0.001008, batch time 0.000966
# 	step 97750, loss 0.008306, batch time 0.001016
# 98000/150000: test accuracy: 0.931500
# 	step 98000, loss 0.007157, batch time 0.032574
# 	step 98250, loss 0.004213, batch time 0.000796
# 	step 98500, loss 0.002947, batch time 0.000640
# 	step 98750, loss 0.005275, batch time 0.000914
# 99000/150000: test accuracy: 0.932200
# 	step 99000, loss 0.005974, batch time 0.031748
# 	step 99250, loss 0.001152, batch time 0.000931
# 	step 99500, loss 0.004278, batch time 0.000720
# 	step 99750, loss 0.011022, batch time 0.000724
# 100000/150000: test accuracy: 0.931500
# 	step 100000, loss 0.004797, batch time 0.033045
# 	step 100250, loss 0.003111, batch time 0.001070
# 	step 100500, loss 0.003345, batch time 0.000785
# 	step 100750, loss 0.002960, batch time 0.000842
# 101000/150000: test accuracy: 0.931600
# 	step 101000, loss 0.006730, batch time 0.036250
# 	step 101250, loss 0.003337, batch time 0.001051
# 	step 101500, loss 0.008325, batch time 0.000890
# 	step 101750, loss 0.002532, batch time 0.000811
# 102000/150000: test accuracy: 0.931500
# 	step 102000, loss 0.003279, batch time 0.034208
# 	step 102250, loss 0.001431, batch time 0.000879
# 	step 102500, loss 0.006200, batch time 0.000963
# 	step 102750, loss 0.005482, batch time 0.000723
# 103000/150000: test accuracy: 0.932200
# 	step 103000, loss 0.007377, batch time 0.032800
# 	step 103250, loss 0.005983, batch time 0.000895
# 	step 103500, loss 0.007804, batch time 0.000755
# 	step 103750, loss 0.002845, batch time 0.000949
# 104000/150000: test accuracy: 0.932100
# 	step 104000, loss 0.006921, batch time 0.036499
# 	step 104250, loss 0.002175, batch time 0.000697
# 	step 104500, loss 0.004423, batch time 0.000831
# 	step 104750, loss 0.006966, batch time 0.000726
# 105000/150000: test accuracy: 0.931400
# 	step 105000, loss 0.001711, batch time 0.033028
# 	step 105250, loss 0.014610, batch time 0.001066
# 	step 105500, loss 0.006359, batch time 0.000706
# 	step 105750, loss 0.003251, batch time 0.000633
# 106000/150000: test accuracy: 0.932300
# 	step 106000, loss 0.004597, batch time 0.034479
# 	step 106250, loss 0.005670, batch time 0.000937
# 	step 106500, loss 0.008694, batch time 0.000931
# 	step 106750, loss 0.008169, batch time 0.000792
# 107000/150000: test accuracy: 0.931800
# 	step 107000, loss 0.004265, batch time 0.033307
# 	step 107250, loss 0.008937, batch time 0.000991
# 	step 107500, loss 0.003491, batch time 0.000655
# 	step 107750, loss 0.009310, batch time 0.000814
# 108000/150000: test accuracy: 0.931700
# 	step 108000, loss 0.002625, batch time 0.032521
# 	step 108250, loss 0.004786, batch time 0.000805
# 	step 108500, loss 0.006197, batch time 0.000752
# 	step 108750, loss 0.006551, batch time 0.000941
# 109000/150000: test accuracy: 0.931600
# 	step 109000, loss 0.004063, batch time 0.033830
# 	step 109250, loss 0.003399, batch time 0.000914
# 	step 109500, loss 0.013752, batch time 0.000714
# 	step 109750, loss 0.003018, batch time 0.000711
# 110000/150000: test accuracy: 0.931200
# 	step 110000, loss 0.011064, batch time 0.033168
# 	step 110250, loss 0.001549, batch time 0.000977
# 	step 110500, loss 0.004434, batch time 0.000830
# 	step 110750, loss 0.004976, batch time 0.000730
# 111000/150000: test accuracy: 0.931800
# 	step 111000, loss 0.003389, batch time 0.035837
# 	step 111250, loss 0.002558, batch time 0.000632
# 	step 111500, loss 0.003232, batch time 0.000728
# 	step 111750, loss 0.002678, batch time 0.000941
# 112000/150000: test accuracy: 0.931800
# 	step 112000, loss 0.002617, batch time 0.033506
# 	step 112250, loss 0.003718, batch time 0.000733
# 	step 112500, loss 0.004020, batch time 0.001005
# 	step 112750, loss 0.002206, batch time 0.000718
# 113000/150000: test accuracy: 0.932100
# 	step 113000, loss 0.001833, batch time 0.034377
# 	step 113250, loss 0.008145, batch time 0.000928
# 	step 113500, loss 0.003845, batch time 0.000819
# 	step 113750, loss 0.002568, batch time 0.000789
# 114000/150000: test accuracy: 0.932000
# 	step 114000, loss 0.007462, batch time 0.033277
# 	step 114250, loss 0.006722, batch time 0.000660
# 	step 114500, loss 0.005402, batch time 0.000896
# 	step 114750, loss 0.003502, batch time 0.000915
# 115000/150000: test accuracy: 0.931400
# 	step 115000, loss 0.006602, batch time 0.033556
# 	step 115250, loss 0.010776, batch time 0.001936
# 	step 115500, loss 0.006723, batch time 0.000854
# 	step 115750, loss 0.003027, batch time 0.000876
# 116000/150000: test accuracy: 0.931800
# 	step 116000, loss 0.003976, batch time 0.032570
# 	step 116250, loss 0.010199, batch time 0.000718
# 	step 116500, loss 0.010205, batch time 0.000825
# 	step 116750, loss 0.005893, batch time 0.000794
# 117000/150000: test accuracy: 0.931500
# 	step 117000, loss 0.003015, batch time 0.034556
# 	step 117250, loss 0.005442, batch time 0.000707
# 	step 117500, loss 0.001195, batch time 0.000670
# 	step 117750, loss 0.005481, batch time 0.000913
# 118000/150000: test accuracy: 0.932000
# 	step 118000, loss 0.001485, batch time 0.032595
# 	step 118250, loss 0.008431, batch time 0.000831
# 	step 118500, loss 0.004120, batch time 0.000757
# 	step 118750, loss 0.007937, batch time 0.000862
# 119000/150000: test accuracy: 0.931800
# 	step 119000, loss 0.007697, batch time 0.033279
# 	step 119250, loss 0.003090, batch time 0.000939
# 	step 119500, loss 0.001384, batch time 0.000742
# 	step 119750, loss 0.001655, batch time 0.000791
# 120000/150000: test accuracy: 0.931700
# 	step 120000, loss 0.005539, batch time 0.035489
# 	step 120250, loss 0.001300, batch time 0.000930
# 	step 120500, loss 0.001557, batch time 0.000893
# 	step 120750, loss 0.004526, batch time 0.000898
# 121000/150000: test accuracy: 0.932500
# 	step 121000, loss 0.001266, batch time 0.034599
# 	step 121250, loss 0.007679, batch time 0.000732
# 	step 121500, loss 0.005956, batch time 0.000713
# 	step 121750, loss 0.001050, batch time 0.000680
# 122000/150000: test accuracy: 0.932200
# 	step 122000, loss 0.002315, batch time 0.032017
# 	step 122250, loss 0.011142, batch time 0.000908
# 	step 122500, loss 0.004177, batch time 0.001281
# 	step 122750, loss 0.004209, batch time 0.000733
# 123000/150000: test accuracy: 0.932000
# 	step 123000, loss 0.007232, batch time 0.036359
# 	step 123250, loss 0.001246, batch time 0.000776
# 	step 123500, loss 0.000973, batch time 0.001179
# 	step 123750, loss 0.007584, batch time 0.000797
# 124000/150000: test accuracy: 0.931900
# 	step 124000, loss 0.004836, batch time 0.031364
# 	step 124250, loss 0.004038, batch time 0.000699
# 	step 124500, loss 0.002525, batch time 0.000726
# 	step 124750, loss 0.004205, batch time 0.000820
# 125000/150000: test accuracy: 0.931900
# 	step 125000, loss 0.002749, batch time 0.036490
# 	step 125250, loss 0.002449, batch time 0.000670
# 	step 125500, loss 0.006595, batch time 0.000984
# 	step 125750, loss 0.006934, batch time 0.000739
# 126000/150000: test accuracy: 0.932000
# 	step 126000, loss 0.003700, batch time 0.032516
# 	step 126250, loss 0.008563, batch time 0.000846
# 	step 126500, loss 0.002123, batch time 0.000787
# 	step 126750, loss 0.005759, batch time 0.000750
# 127000/150000: test accuracy: 0.932100
# 	step 127000, loss 0.008004, batch time 0.032678
# 	step 127250, loss 0.006021, batch time 0.000695
# 	step 127500, loss 0.007810, batch time 0.000712
# 	step 127750, loss 0.008016, batch time 0.000786
# 128000/150000: test accuracy: 0.931900
# 	step 128000, loss 0.007363, batch time 0.033244
# 	step 128250, loss 0.008232, batch time 0.000718
# 	step 128500, loss 0.009241, batch time 0.000729
# 	step 128750, loss 0.003271, batch time 0.000746
# 129000/150000: test accuracy: 0.931700
# 	step 129000, loss 0.011741, batch time 0.031894
# 	step 129250, loss 0.002523, batch time 0.000760
# 	step 129500, loss 0.006226, batch time 0.000740
# 	step 129750, loss 0.006956, batch time 0.000713
# 130000/150000: test accuracy: 0.932500
# 	step 130000, loss 0.002609, batch time 0.031619
# 	step 130250, loss 0.005255, batch time 0.000741
# 	step 130500, loss 0.008277, batch time 0.000858
# 	step 130750, loss 0.004635, batch time 0.000945
# 131000/150000: test accuracy: 0.932300
# 	step 131000, loss 0.004677, batch time 0.032413
# 	step 131250, loss 0.007060, batch time 0.000781
# 	step 131500, loss 0.006037, batch time 0.000912
# 	step 131750, loss 0.008449, batch time 0.000729
# 132000/150000: test accuracy: 0.931500
# 	step 132000, loss 0.002421, batch time 0.033122
# 	step 132250, loss 0.005232, batch time 0.000703
# 	step 132500, loss 0.002661, batch time 0.000689
# 	step 132750, loss 0.008845, batch time 0.000690
# 133000/150000: test accuracy: 0.932400
# 	step 133000, loss 0.009120, batch time 0.036565
# 	step 133250, loss 0.003693, batch time 0.000634
# 	step 133500, loss 0.004202, batch time 0.000665
# 	step 133750, loss 0.004602, batch time 0.000773
# 134000/150000: test accuracy: 0.932300
# 	step 134000, loss 0.004002, batch time 0.032088
# 	step 134250, loss 0.005754, batch time 0.000744
# 	step 134500, loss 0.003995, batch time 0.000920
# 	step 134750, loss 0.002593, batch time 0.000639
# 135000/150000: test accuracy: 0.931900
# 	step 135000, loss 0.002078, batch time 0.035239
# 	step 135250, loss 0.005615, batch time 0.000990
# 	step 135500, loss 0.003245, batch time 0.000795
# 	step 135750, loss 0.003305, batch time 0.000668
# 136000/150000: test accuracy: 0.932200
# 	step 136000, loss 0.003044, batch time 0.033056
# 	step 136250, loss 0.000449, batch time 0.000676
# 	step 136500, loss 0.004135, batch time 0.000748
# 	step 136750, loss 0.004670, batch time 0.000773
# 137000/150000: test accuracy: 0.932700
# 	step 137000, loss 0.003661, batch time 0.034551
# 	step 137250, loss 0.001051, batch time 0.000903
# 	step 137500, loss 0.008189, batch time 0.000944
# 	step 137750, loss 0.003599, batch time 0.000642
# 138000/150000: test accuracy: 0.931600
# 	step 138000, loss 0.006939, batch time 0.031932
# 	step 138250, loss 0.005824, batch time 0.001014
# 	step 138500, loss 0.006321, batch time 0.000698
# 	step 138750, loss 0.005121, batch time 0.000862
# 139000/150000: test accuracy: 0.932800
# 	step 139000, loss 0.002748, batch time 0.032946
# 	step 139250, loss 0.002118, batch time 0.000702
# 	step 139500, loss 0.003432, batch time 0.000831
# 	step 139750, loss 0.004014, batch time 0.000933
# 140000/150000: test accuracy: 0.931500
# 	step 140000, loss 0.005974, batch time 0.032298
# 	step 140250, loss 0.005078, batch time 0.000726
# 	step 140500, loss 0.003887, batch time 0.000932
# 	step 140750, loss 0.002478, batch time 0.000730
# 141000/150000: test accuracy: 0.932500
# 	step 141000, loss 0.009225, batch time 0.034823
# 	step 141250, loss 0.004048, batch time 0.000638
# 	step 141500, loss 0.008953, batch time 0.000652
# 	step 141750, loss 0.002043, batch time 0.000728
# 142000/150000: test accuracy: 0.932500
# 	step 142000, loss 0.004034, batch time 0.033444
# 	step 142250, loss 0.002690, batch time 0.000731
# 	step 142500, loss 0.006334, batch time 0.001020
# 	step 142750, loss 0.008081, batch time 0.000914
# 143000/150000: test accuracy: 0.932600
# 	step 143000, loss 0.010502, batch time 0.032376
# 	step 143250, loss 0.006300, batch time 0.000788
# 	step 143500, loss 0.003783, batch time 0.000924
# 	step 143750, loss 0.009524, batch time 0.000659
# 144000/150000: test accuracy: 0.932600
# 	step 144000, loss 0.007219, batch time 0.036418
# 	step 144250, loss 0.003330, batch time 0.000798
# 	step 144500, loss 0.004058, batch time 0.000790
# 	step 144750, loss 0.003958, batch time 0.000838
# 145000/150000: test accuracy: 0.932200
# 	step 145000, loss 0.001726, batch time 0.033503
# 	step 145250, loss 0.001709, batch time 0.000749
# 	step 145500, loss 0.001164, batch time 0.000815
# 	step 145750, loss 0.004548, batch time 0.000697
# 146000/150000: test accuracy: 0.932500
# 	step 146000, loss 0.000199, batch time 0.033006
# 	step 146250, loss 0.000805, batch time 0.001254
# 	step 146500, loss 0.007481, batch time 0.000742
# 	step 146750, loss 0.002149, batch time 0.000860
# 147000/150000: test accuracy: 0.931800
# 	step 147000, loss 0.002891, batch time 0.031603
# 	step 147250, loss 0.004658, batch time 0.000572
# 	step 147500, loss 0.005302, batch time 0.000726
# 	step 147750, loss 0.005183, batch time 0.000711
# 148000/150000: test accuracy: 0.932200
# 	step 148000, loss 0.001796, batch time 0.031967
# 	step 148250, loss 0.003973, batch time 0.001007
# 	step 148500, loss 0.005068, batch time 0.000709
# 	step 148750, loss 0.003552, batch time 0.000974
# 149000/150000: test accuracy: 0.933000
# 	step 149000, loss 0.006133, batch time 0.033450
# 	step 149250, loss 0.003391, batch time 0.001140
# 	step 149500, loss 0.003029, batch time 0.001106
# 	step 149750, loss 0.006069, batch time 0.000703
#
# total runtime: 145.516554 seconds

# %%
feed = {x: mnist.test.images, y_: mnist.test.labels}
acc = accuracy.eval(feed_dict=feed)
print "final test accuracy: {:3f}".format(acc)
# Out:
# final test accuracy: 0.932900

# %% [markdown]
# ## Plot performance

# %%
plt.figure(0, figsize=(16,4))
plt.subplot(121)
plt.title("Loss")
plt.plot(loss_curve[1:,0], loss_curve[1:,1], 'b-')
plt.subplot(122)
plt.title("Accuracy")
plt.plot(acc_curve[1:,0], acc_curve[1:,1], 'r-')

with open('noreg.p', 'w') as f:
    pickle.dump(acc_curve, f)

# %% [markdown]
# ## Plot weights

# %%
W_ = W.eval()
for i in range(0,10,5):
    img1 = np.reshape(W_[:,i], (28,28))
    img2 = np.reshape(W_[:,i+1], (28,28))
    img3 = np.reshape(W_[:,i+2], (28,28))
    img4 = np.reshape(W_[:,i+3], (28,28))
    img5 = np.reshape(W_[:,i+4], (28,28))
    plt.figure(i, figsize=(16,4))
    plt.subplot(151)
    plt.imshow(img1, cmap=cm.gray)
    plt.subplot(152)
    plt.imshow(img2, cmap=cm.gray)
    plt.subplot(153)
    plt.imshow(img3, cmap=cm.gray)
    plt.subplot(154)
    plt.imshow(img4, cmap=cm.gray)
    plt.subplot(155)
    plt.imshow(img5, cmap=cm.gray)

# %%
print np.min(W_), np.max(W_), "\n", W_
# Out:
# -1.93896 1.64877
# [[ 0.03850536 -0.01918605  0.04889935 ...,  0.02410696 -0.03227681
#    0.12101676]
#  [-0.10343652  0.01026842  0.09842224 ...,  0.10776041  0.10512403
#    0.14415807]
#  [ 0.02281166 -0.01020185 -0.03473994 ...,  0.07933947  0.0734944
#    0.00922439]
#  ...,
#  [ 0.05679378 -0.0197225  -0.04664761 ..., -0.08260879 -0.01550736
#    0.0088239 ]
#  [-0.03153034  0.01112991 -0.03470689 ...,  0.01366572 -0.03326581
#    0.03825216]
#  [ 0.00947612  0.01582363  0.0263431  ..., -0.14730136  0.05386596
#    0.02577173]]

# %% [markdown]
# ## Saver IO

# %%
# saver = tf.train.Saver(tf.all_variables())
# load_was_success = True # yes, I'm being optimistic
# try:
#     save_dir = '/'.join(save_path.split('/')[:-1])
#     ckpt = tf.train.get_checkpoint_state(save_dir)
#     load_path = ckpt.model_checkpoint_path
#     saver.restore(sess, load_path)
# except:
#     print "no saved model to load. starting new session"
#     load_was_success = False
# else:
#     print "loaded model: {}".format(load_path)
#     saver = tf.train.Saver(tf.all_variables())
#     global_step = int(load_path.split('-')[-1])

# %%
# #fc 1 layer
# W1 = tf.get_variable("W1", shape=[xlen,ylen], initializer=init)
# b1 = tf.get_variable("b1", shape=[ylen], initializer=init)
# output = tf.nn.softmax(tf.matmul(x, W1) + b1)
