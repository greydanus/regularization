# %% [markdown]
# # Adaptive Weight Noise Regularization

# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

import time
import cPickle as pickle
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Model baseline

# %%
batch_size = 32
global_step = 0
save_path = 'models/awn.ckpt'
xlen = 28*28
ylen = 10
reg_param = 0.01

train_steps = 150000
info_every = 250
test_every = 1000

# %% [markdown]
# ## Build model

# %%
def gaussian(X, mu, sigma):
    x_mu = tf.sub(X, mu)
    Z = tf.square(tf.div(x_mu, sigma))
    power_e = tf.exp(tf.div(-Z,2*sigma**2))
    regularize_term = np.sqrt(2*np.pi)*sigma
    gaussian = tf.div(power_e, regularize_term)
    return gaussian

# %%
#awn
tf.reset_default_graph()
sess = tf.InteractiveSession()

awn_param = tf.placeholder(tf.float32)
x = tf.placeholder(tf.float32, shape=[None, xlen], name="x")
noise_source = tf.placeholder(tf.float32, shape=[xlen, ylen], name="noise_source")
y_ = tf.placeholder(tf.float32, shape=[None, ylen], name="y_")
init = tf.truncated_normal_initializer(mean=0., stddev=.075, seed=1234, dtype=tf.float32)

S_hat = tf.get_variable("S_hat", shape=[xlen,ylen], initializer=init)
S = tf.exp(S_hat)

mu = tf.get_variable("mu", shape=[xlen,ylen], initializer=init)
W = gaussian(noise_source*awn_param, mu, S)

output = tf.nn.softmax(tf.matmul(x, W))

# %%
loss = tf.nn.l2_loss( y_ - output ) / (ylen*batch_size)

optimizer = tf.train.AdamOptimizer(1e-3)
grads = optimizer.compute_gradients(loss, var_list=tf.trainable_variables())
train_op = optimizer.apply_gradients(grads)

sess.run(tf.initialize_all_variables())

# %% [markdown]
# ## Model overview

# %%
total_parameters = 0 ; print "Model overview:"
for variable in tf.trainable_variables():
    shape = variable.get_shape()
    variable_parameters = 1
    for dim in shape:
        variable_parameters *= dim.value
    print '\tvariable "{}" has {} parameters' \
        .format(variable.name, variable_parameters)
    total_parameters += variable_parameters
print "Total of {} parameters".format(total_parameters)
# Out:
# Model overview:
# 	variable "S_hat:0" has 7840 parameters
# 	variable "mu:0" has 7840 parameters
# Total of 15680 parameters

# %% [markdown]
# ## Train

# %%
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
loss_curve = np.zeros((train_steps/info_every, 2))
acc_curve = np.zeros((train_steps/test_every, 2))

normal_noise = np.random.randn(xlen*ylen)
begin = time.time()
for i in range(train_steps):
    batch_start = time.time()
    normal_noise = np.concatenate((normal_noise.ravel()[-2:-1], normal_noise.ravel()[:-1]))
    normal_noise = np.reshape(normal_noise, (xlen,ylen))
    
    batch = mnist.train.next_batch(batch_size)
    feed = {x: batch[0], y_: batch[1], noise_source: normal_noise, awn_param: reg_param}
    train_loss, _ = sess.run([loss, train_op], feed_dict=feed)
    
    if i%test_every == 0:
        feed = {x: mnist.test.images, y_: mnist.test.labels, noise_source: normal_noise, awn_param: 0}
        acc = accuracy.eval(feed_dict=feed)
        acc_curve[i/test_every,:] = [i, acc]
        print "{}/{}: test accuracy: {:3f}".format(i, train_steps, acc)
    if i%info_every == 0:
        loss_curve[i/info_every,:] = [i, train_loss]
        print "\tstep {}, loss {:3f}, batch time {:3f}".format(i, train_loss, time.time()-batch_start)
print "\ntotal runtime: {:3f} seconds".format(time.time()-begin)
# Out:
# 0/150000: test accuracy: 0.157000
# 	step 0, loss 0.044884, batch time 0.065629
# 	step 250, loss 0.023999, batch time 0.003387
# 	step 500, loss 0.015365, batch time 0.001869
# 	step 750, loss 0.009214, batch time 0.001731
# 1000/150000: test accuracy: 0.896300
# 	step 1000, loss 0.006854, batch time 0.034387
# 	step 1250, loss 0.010705, batch time 0.003033
# 	step 1500, loss 0.010920, batch time 0.002270
# 	step 1750, loss 0.005427, batch time 0.001726
# 2000/150000: test accuracy: 0.906400
# 	step 2000, loss 0.010948, batch time 0.039157
# 	step 2250, loss 0.007050, batch time 0.002509
# 	step 2500, loss 0.012097, batch time 0.001700
# 	step 2750, loss 0.006698, batch time 0.001723
# 3000/150000: test accuracy: 0.913800
# 	step 3000, loss 0.002641, batch time 0.036351
# 	step 3250, loss 0.004390, batch time 0.002252
# 	step 3500, loss 0.006778, batch time 0.004013
# 	step 3750, loss 0.008060, batch time 0.002571
# 4000/150000: test accuracy: 0.916200
# 	step 4000, loss 0.002874, batch time 0.036646
# 	step 4250, loss 0.007790, batch time 0.002912
# 	step 4500, loss 0.006252, batch time 0.001538
# 	step 4750, loss 0.008343, batch time 0.001649
# 5000/150000: test accuracy: 0.917900
# 	step 5000, loss 0.006943, batch time 0.034701
# 	step 5250, loss 0.005494, batch time 0.001900
# 	step 5500, loss 0.008122, batch time 0.001986
# 	step 5750, loss 0.005536, batch time 0.002106
# 6000/150000: test accuracy: 0.920900
# 	step 6000, loss 0.006986, batch time 0.046905
# 	step 6250, loss 0.003199, batch time 0.002026
# 	step 6500, loss 0.005982, batch time 0.001808
# 	step 6750, loss 0.006136, batch time 0.001478
# 7000/150000: test accuracy: 0.921900
# 	step 7000, loss 0.007051, batch time 0.034376
# 	step 7250, loss 0.008259, batch time 0.001987
# 	step 7500, loss 0.008272, batch time 0.001889
# 	step 7750, loss 0.002764, batch time 0.003713
# 8000/150000: test accuracy: 0.923900
# 	step 8000, loss 0.008302, batch time 0.035975
# 	step 8250, loss 0.008376, batch time 0.002069
# 	step 8500, loss 0.002533, batch time 0.002120
# 	step 8750, loss 0.007858, batch time 0.001849
# 9000/150000: test accuracy: 0.922600
# 	step 9000, loss 0.007103, batch time 0.035325
# 	step 9250, loss 0.008268, batch time 0.002102
# 	step 9500, loss 0.006596, batch time 0.002126
# 	step 9750, loss 0.005407, batch time 0.001768
# 10000/150000: test accuracy: 0.924500
# 	step 10000, loss 0.006496, batch time 0.038775
# 	step 10250, loss 0.007920, batch time 0.002077
# 	step 10500, loss 0.002422, batch time 0.002033
# 	step 10750, loss 0.002102, batch time 0.002489
# 11000/150000: test accuracy: 0.925700
# 	step 11000, loss 0.004563, batch time 0.046975
# 	step 11250, loss 0.005790, batch time 0.003295
# 	step 11500, loss 0.008917, batch time 0.002129
# 	step 11750, loss 0.007772, batch time 0.003403
# 12000/150000: test accuracy: 0.925100
# 	step 12000, loss 0.003957, batch time 0.036158
# 	step 12250, loss 0.003050, batch time 0.001892
# 	step 12500, loss 0.002557, batch time 0.001980
# 	step 12750, loss 0.008309, batch time 0.001775
# 13000/150000: test accuracy: 0.925000
# 	step 13000, loss 0.010167, batch time 0.037129
# 	step 13250, loss 0.002152, batch time 0.002547
# 	step 13500, loss 0.002390, batch time 0.001785
# 	step 13750, loss 0.003392, batch time 0.002224
# 14000/150000: test accuracy: 0.927700
# 	step 14000, loss 0.005943, batch time 0.049078
# 	step 14250, loss 0.003259, batch time 0.001910
# 	step 14500, loss 0.009182, batch time 0.001974
# 	step 14750, loss 0.005183, batch time 0.001737
# 15000/150000: test accuracy: 0.926500
# 	step 15000, loss 0.008265, batch time 0.035409
# 	step 15250, loss 0.007450, batch time 0.001874
# 	step 15500, loss 0.006686, batch time 0.003245
# 	step 15750, loss 0.005450, batch time 0.002526
# 16000/150000: test accuracy: 0.927600
# 	step 16000, loss 0.006243, batch time 0.041661
# 	step 16250, loss 0.014352, batch time 0.001721
# 	step 16500, loss 0.002074, batch time 0.001661
# 	step 16750, loss 0.003989, batch time 0.001730
# 17000/150000: test accuracy: 0.928100
# 	step 17000, loss 0.004038, batch time 0.038343
# 	step 17250, loss 0.002670, batch time 0.001574
# 	step 17500, loss 0.003373, batch time 0.001645
# 	step 17750, loss 0.003901, batch time 0.001758
# 18000/150000: test accuracy: 0.927300
# 	step 18000, loss 0.001739, batch time 0.035495
# 	step 18250, loss 0.004780, batch time 0.001548
# 	step 18500, loss 0.004604, batch time 0.001797
# 	step 18750, loss 0.005961, batch time 0.003110
# 19000/150000: test accuracy: 0.927400
# 	step 19000, loss 0.001820, batch time 0.035385
# 	step 19250, loss 0.009468, batch time 0.001682
# 	step 19500, loss 0.003343, batch time 0.003723
# 	step 19750, loss 0.002531, batch time 0.002086
# 20000/150000: test accuracy: 0.928100
# 	step 20000, loss 0.008829, batch time 0.035819
# 	step 20250, loss 0.003784, batch time 0.002038
# 	step 20500, loss 0.006334, batch time 0.001566
# 	step 20750, loss 0.001745, batch time 0.002173
# 21000/150000: test accuracy: 0.928500
# 	step 21000, loss 0.004593, batch time 0.037392
# 	step 21250, loss 0.009915, batch time 0.001941
# 	step 21500, loss 0.005937, batch time 0.002838
# 	step 21750, loss 0.005196, batch time 0.003639
# 22000/150000: test accuracy: 0.929100
# 	step 22000, loss 0.004127, batch time 0.041219
# 	step 22250, loss 0.002999, batch time 0.001726
# 	step 22500, loss 0.006869, batch time 0.001885
# 	step 22750, loss 0.003651, batch time 0.001537
# 23000/150000: test accuracy: 0.927500
# 	step 23000, loss 0.005031, batch time 0.043025
# 	step 23250, loss 0.007971, batch time 0.001498
# 	step 23500, loss 0.007677, batch time 0.002311
# 	step 23750, loss 0.003998, batch time 0.003089
# 24000/150000: test accuracy: 0.927900
# 	step 24000, loss 0.005313, batch time 0.039136
# 	step 24250, loss 0.004049, batch time 0.001993
# 	step 24500, loss 0.004648, batch time 0.002081
# 	step 24750, loss 0.006531, batch time 0.002950
# 25000/150000: test accuracy: 0.928700
# 	step 25000, loss 0.008142, batch time 0.036642
# 	step 25250, loss 0.002214, batch time 0.003596
# 	step 25500, loss 0.000892, batch time 0.001879
# 	step 25750, loss 0.008124, batch time 0.003107
# 26000/150000: test accuracy: 0.928600
# 	step 26000, loss 0.004361, batch time 0.045105
# 	step 26250, loss 0.006855, batch time 0.003024
# 	step 26500, loss 0.007124, batch time 0.001778
# 	step 26750, loss 0.010712, batch time 0.001590
# 27000/150000: test accuracy: 0.928500
# 	step 27000, loss 0.008423, batch time 0.036095
# 	step 27250, loss 0.004916, batch time 0.001869
# 	step 27500, loss 0.001791, batch time 0.002135
# 	step 27750, loss 0.007918, batch time 0.002217
# 28000/150000: test accuracy: 0.927500
# 	step 28000, loss 0.003354, batch time 0.040787
# 	step 28250, loss 0.003507, batch time 0.001824
# 	step 28500, loss 0.006307, batch time 0.002523
# 	step 28750, loss 0.004139, batch time 0.002451
# 29000/150000: test accuracy: 0.927900
# 	step 29000, loss 0.006000, batch time 0.036076
# 	step 29250, loss 0.003393, batch time 0.001935
# 	step 29500, loss 0.008607, batch time 0.001826
# 	step 29750, loss 0.006640, batch time 0.001895
# 30000/150000: test accuracy: 0.929800
# 	step 30000, loss 0.002724, batch time 0.038538
# 	step 30250, loss 0.002609, batch time 0.001762
# 	step 30500, loss 0.003737, batch time 0.001908
# 	step 30750, loss 0.006646, batch time 0.001789
# 31000/150000: test accuracy: 0.929400
# 	step 31000, loss 0.001776, batch time 0.038010
# 	step 31250, loss 0.008200, batch time 0.001764
# 	step 31500, loss 0.007760, batch time 0.001688
# 	step 31750, loss 0.002919, batch time 0.002171
# 32000/150000: test accuracy: 0.929600
# 	step 32000, loss 0.005118, batch time 0.035007
# 	step 32250, loss 0.009462, batch time 0.002188
# 	step 32500, loss 0.004651, batch time 0.001942
# 	step 32750, loss 0.003727, batch time 0.002022
# 33000/150000: test accuracy: 0.928300
# 	step 33000, loss 0.006487, batch time 0.034472
# 	step 33250, loss 0.006303, batch time 0.009661
# 	step 33500, loss 0.002441, batch time 0.001915
# 	step 33750, loss 0.003635, batch time 0.001488
# 34000/150000: test accuracy: 0.930000
# 	step 34000, loss 0.008027, batch time 0.037158
# 	step 34250, loss 0.002581, batch time 0.001630
# 	step 34500, loss 0.006320, batch time 0.002349
# 	step 34750, loss 0.005970, batch time 0.003213
# 35000/150000: test accuracy: 0.929300
# 	step 35000, loss 0.005226, batch time 0.073208
# 	step 35250, loss 0.004589, batch time 0.002230
# 	step 35500, loss 0.005058, batch time 0.001935
# 	step 35750, loss 0.003643, batch time 0.004510
# 36000/150000: test accuracy: 0.928800
# 	step 36000, loss 0.005981, batch time 0.039718
# 	step 36250, loss 0.006727, batch time 0.001688
# 	step 36500, loss 0.009574, batch time 0.001815
# 	step 36750, loss 0.005791, batch time 0.001775
# 37000/150000: test accuracy: 0.928700
# 	step 37000, loss 0.010110, batch time 0.035405
# 	step 37250, loss 0.006480, batch time 0.001547
# 	step 37500, loss 0.003478, batch time 0.002015
# 	step 37750, loss 0.005278, batch time 0.001656
# 38000/150000: test accuracy: 0.928200
# 	step 38000, loss 0.005098, batch time 0.035165
# 	step 38250, loss 0.007928, batch time 0.001989
# 	step 38500, loss 0.005278, batch time 0.001830
# 	step 38750, loss 0.000681, batch time 0.001889
# 39000/150000: test accuracy: 0.928900
# 	step 39000, loss 0.009315, batch time 0.037558
# 	step 39250, loss 0.005938, batch time 0.002017
# 	step 39500, loss 0.003160, batch time 0.001748
# 	step 39750, loss 0.003117, batch time 0.003079
# 40000/150000: test accuracy: 0.930500
# 	step 40000, loss 0.002136, batch time 0.035091
# 	step 40250, loss 0.000973, batch time 0.001963
# 	step 40500, loss 0.004111, batch time 0.002020
# 	step 40750, loss 0.006368, batch time 0.001829
# 41000/150000: test accuracy: 0.929600
# 	step 41000, loss 0.003256, batch time 0.035610
# 	step 41250, loss 0.004107, batch time 0.001780
# 	step 41500, loss 0.005638, batch time 0.002720
# 	step 41750, loss 0.000441, batch time 0.001887
# 42000/150000: test accuracy: 0.929800
# 	step 42000, loss 0.004004, batch time 0.036500
# 	step 42250, loss 0.004156, batch time 0.001857
# 	step 42500, loss 0.005694, batch time 0.002006
# 	step 42750, loss 0.010563, batch time 0.001982
# 43000/150000: test accuracy: 0.929900
# 	step 43000, loss 0.004544, batch time 0.036890
# 	step 43250, loss 0.000568, batch time 0.001776
# 	step 43500, loss 0.002877, batch time 0.002239
# 	step 43750, loss 0.010466, batch time 0.001805
# 44000/150000: test accuracy: 0.930100
# 	step 44000, loss 0.007806, batch time 0.035448
# 	step 44250, loss 0.005613, batch time 0.001970
# 	step 44500, loss 0.003975, batch time 0.001724
# 	step 44750, loss 0.002685, batch time 0.001876
# 45000/150000: test accuracy: 0.930000
# 	step 45000, loss 0.005244, batch time 0.036648
# 	step 45250, loss 0.008461, batch time 0.001788
# 	step 45500, loss 0.006567, batch time 0.001612
# 	step 45750, loss 0.002046, batch time 0.001761
# 46000/150000: test accuracy: 0.929200
# 	step 46000, loss 0.006731, batch time 0.036174
# 	step 46250, loss 0.002078, batch time 0.001714
# 	step 46500, loss 0.008674, batch time 0.001987
# 	step 46750, loss 0.004202, batch time 0.002199
# 47000/150000: test accuracy: 0.929600
# 	step 47000, loss 0.006419, batch time 0.036718
# 	step 47250, loss 0.004412, batch time 0.001776
# 	step 47500, loss 0.005330, batch time 0.001759
# 	step 47750, loss 0.000598, batch time 0.001636
# 48000/150000: test accuracy: 0.929300
# 	step 48000, loss 0.003318, batch time 0.036761
# 	step 48250, loss 0.001932, batch time 0.005220
# 	step 48500, loss 0.000511, batch time 0.002390
# 	step 48750, loss 0.006515, batch time 0.002000
# 49000/150000: test accuracy: 0.929200
# 	step 49000, loss 0.005569, batch time 0.036042
# 	step 49250, loss 0.004078, batch time 0.001677
# 	step 49500, loss 0.000802, batch time 0.001892
# 	step 49750, loss 0.009768, batch time 0.001920
# 50000/150000: test accuracy: 0.928900
# 	step 50000, loss 0.004501, batch time 0.034639
# 	step 50250, loss 0.004891, batch time 0.001693
# 	step 50500, loss 0.004069, batch time 0.001804
# 	step 50750, loss 0.009019, batch time 0.001786
# 51000/150000: test accuracy: 0.928800
# 	step 51000, loss 0.009694, batch time 0.035193
# 	step 51250, loss 0.007618, batch time 0.002424
# 	step 51500, loss 0.004022, batch time 0.001966
# 	step 51750, loss 0.006626, batch time 0.001801
# 52000/150000: test accuracy: 0.929700
# 	step 52000, loss 0.006865, batch time 0.033889
# 	step 52250, loss 0.006694, batch time 0.001702
# 	step 52500, loss 0.008646, batch time 0.002063
# 	step 52750, loss 0.001735, batch time 0.001675
# 53000/150000: test accuracy: 0.929600
# 	step 53000, loss 0.006533, batch time 0.036227
# 	step 53250, loss 0.001538, batch time 0.001752
# 	step 53500, loss 0.001395, batch time 0.001982
# 	step 53750, loss 0.003364, batch time 0.001798
# 54000/150000: test accuracy: 0.927100
# 	step 54000, loss 0.009201, batch time 0.034261
# 	step 54250, loss 0.005544, batch time 0.001725
# 	step 54500, loss 0.004907, batch time 0.001741
# 	step 54750, loss 0.002908, batch time 0.001924
# 55000/150000: test accuracy: 0.929200
# 	step 55000, loss 0.007298, batch time 0.036189
# 	step 55250, loss 0.006380, batch time 0.001990
# 	step 55500, loss 0.003943, batch time 0.001662
# 	step 55750, loss 0.004025, batch time 0.002319
# 56000/150000: test accuracy: 0.928700
# 	step 56000, loss 0.006254, batch time 0.036686
# 	step 56250, loss 0.007369, batch time 0.001740
# 	step 56500, loss 0.002898, batch time 0.002182
# 	step 56750, loss 0.003557, batch time 0.001829
# 57000/150000: test accuracy: 0.928800
# 	step 57000, loss 0.008608, batch time 0.033698
# 	step 57250, loss 0.003406, batch time 0.002090
# 	step 57500, loss 0.003887, batch time 0.001797
# 	step 57750, loss 0.003835, batch time 0.002187
# 58000/150000: test accuracy: 0.929700
# 	step 58000, loss 0.014777, batch time 0.035750
# 	step 58250, loss 0.006426, batch time 0.001720
# 	step 58500, loss 0.003105, batch time 0.001976
# 	step 58750, loss 0.001128, batch time 0.001906
# 59000/150000: test accuracy: 0.929300
# 	step 59000, loss 0.001592, batch time 0.035904
# 	step 59250, loss 0.002713, batch time 0.001907
# 	step 59500, loss 0.002154, batch time 0.001807
# 	step 59750, loss 0.001575, batch time 0.001904
# 60000/150000: test accuracy: 0.929000
# 	step 60000, loss 0.005013, batch time 0.035738
# 	step 60250, loss 0.004093, batch time 0.001379
# 	step 60500, loss 0.002798, batch time 0.001638
# 	step 60750, loss 0.004887, batch time 0.001602
# 61000/150000: test accuracy: 0.929600
# 	step 61000, loss 0.005418, batch time 0.035510
# 	step 61250, loss 0.008991, batch time 0.001983
# 	step 61500, loss 0.002741, batch time 0.001732
# 	step 61750, loss 0.006727, batch time 0.002751
# 62000/150000: test accuracy: 0.928900
# 	step 62000, loss 0.005125, batch time 0.034679
# 	step 62250, loss 0.008656, batch time 0.002006
# 	step 62500, loss 0.003093, batch time 0.001910
# 	step 62750, loss 0.001400, batch time 0.001928
# 63000/150000: test accuracy: 0.928100
# 	step 63000, loss 0.009331, batch time 0.042464
# 	step 63250, loss 0.002902, batch time 0.001843
# 	step 63500, loss 0.000563, batch time 0.002404
# 	step 63750, loss 0.001759, batch time 0.001835
# 64000/150000: test accuracy: 0.928500
# 	step 64000, loss 0.001053, batch time 0.034642
# 	step 64250, loss 0.008800, batch time 0.002039
# 	step 64500, loss 0.006657, batch time 0.002164
# 	step 64750, loss 0.008514, batch time 0.001901
# 65000/150000: test accuracy: 0.929400
# 	step 65000, loss 0.005543, batch time 0.036016
# 	step 65250, loss 0.002521, batch time 0.002104
# 	step 65500, loss 0.001564, batch time 0.002195
# 	step 65750, loss 0.007763, batch time 0.001955
# 66000/150000: test accuracy: 0.929400
# 	step 66000, loss 0.012637, batch time 0.042364
# 	step 66250, loss 0.001133, batch time 0.001486
# 	step 66500, loss 0.011837, batch time 0.002318
# 	step 66750, loss 0.006380, batch time 0.001667
# 67000/150000: test accuracy: 0.927800
# 	step 67000, loss 0.002925, batch time 0.037945
# 	step 67250, loss 0.006993, batch time 0.001911
# 	step 67500, loss 0.000901, batch time 0.001724
# 	step 67750, loss 0.009304, batch time 0.001702
# 68000/150000: test accuracy: 0.929000
# 	step 68000, loss 0.010077, batch time 0.035285
# 	step 68250, loss 0.002653, batch time 0.001755
# 	step 68500, loss 0.005198, batch time 0.002283
# 	step 68750, loss 0.002441, batch time 0.002129
# 69000/150000: test accuracy: 0.927900
# 	step 69000, loss 0.001880, batch time 0.035996
# 	step 69250, loss 0.004798, batch time 0.001706
# 	step 69500, loss 0.000415, batch time 0.001535
# 	step 69750, loss 0.005433, batch time 0.002049
# 70000/150000: test accuracy: 0.928200
# 	step 70000, loss 0.007325, batch time 0.035467
# 	step 70250, loss 0.004468, batch time 0.001620
# 	step 70500, loss 0.008728, batch time 0.001943
# 	step 70750, loss 0.003168, batch time 0.003125
# 71000/150000: test accuracy: 0.929000
# 	step 71000, loss 0.005333, batch time 0.037247
# 	step 71250, loss 0.007293, batch time 0.002054
# 	step 71500, loss 0.001837, batch time 0.001755
# 	step 71750, loss 0.006154, batch time 0.001713
# 72000/150000: test accuracy: 0.929000
# 	step 72000, loss 0.003187, batch time 0.037718
# 	step 72250, loss 0.003944, batch time 0.001930
# 	step 72500, loss 0.004243, batch time 0.002033
# 	step 72750, loss 0.011072, batch time 0.002092
# 73000/150000: test accuracy: 0.929000
# 	step 73000, loss 0.008965, batch time 0.035319
# 	step 73250, loss 0.002616, batch time 0.001930
# 	step 73500, loss 0.010946, batch time 0.001613
# 	step 73750, loss 0.007898, batch time 0.001770
# 74000/150000: test accuracy: 0.928700
# 	step 74000, loss 0.003395, batch time 0.037345
# 	step 74250, loss 0.003739, batch time 0.001746
# 	step 74500, loss 0.005537, batch time 0.001797
# 	step 74750, loss 0.004716, batch time 0.002307
# 75000/150000: test accuracy: 0.927800
# 	step 75000, loss 0.004496, batch time 0.039378
# 	step 75250, loss 0.004811, batch time 0.003293
# 	step 75500, loss 0.006824, batch time 0.002841
# 	step 75750, loss 0.003982, batch time 0.005674
# 76000/150000: test accuracy: 0.926300
# 	step 76000, loss 0.000604, batch time 0.034982
# 	step 76250, loss 0.004919, batch time 0.003083
# 	step 76500, loss 0.000299, batch time 0.003764
# 	step 76750, loss 0.004164, batch time 0.002026
# 77000/150000: test accuracy: 0.928900
# 	step 77000, loss 0.004058, batch time 0.036258
# 	step 77250, loss 0.007151, batch time 0.002256
# 	step 77500, loss 0.002473, batch time 0.001805
# 	step 77750, loss 0.000575, batch time 0.002099
# 78000/150000: test accuracy: 0.929300
# 	step 78000, loss 0.009467, batch time 0.036663
# 	step 78250, loss 0.010512, batch time 0.001736
# 	step 78500, loss 0.009329, batch time 0.001868
# 	step 78750, loss 0.002444, batch time 0.001817
# 79000/150000: test accuracy: 0.928400
# 	step 79000, loss 0.004421, batch time 0.036222
# 	step 79250, loss 0.003805, batch time 0.002053
# 	step 79500, loss 0.006271, batch time 0.002025
# 	step 79750, loss 0.005456, batch time 0.001946
# 80000/150000: test accuracy: 0.928300
# 	step 80000, loss 0.007293, batch time 0.035073
# 	step 80250, loss 0.004472, batch time 0.001737
# 	step 80500, loss 0.004699, batch time 0.001812
# 	step 80750, loss 0.000976, batch time 0.001895
# 81000/150000: test accuracy: 0.927800
# 	step 81000, loss 0.000244, batch time 0.036787
# 	step 81250, loss 0.007812, batch time 0.002514
# 	step 81500, loss 0.004763, batch time 0.001987
# 	step 81750, loss 0.003829, batch time 0.001250
# 82000/150000: test accuracy: 0.928100
# 	step 82000, loss 0.005076, batch time 0.034487
# 	step 82250, loss 0.003683, batch time 0.001722
# 	step 82500, loss 0.005603, batch time 0.001878
# 	step 82750, loss 0.005091, batch time 0.001390
# 83000/150000: test accuracy: 0.929600
# 	step 83000, loss 0.001912, batch time 0.041925
# 	step 83250, loss 0.002190, batch time 0.001785
# 	step 83500, loss 0.003506, batch time 0.001932
# 	step 83750, loss 0.010930, batch time 0.002244
# 84000/150000: test accuracy: 0.928800
# 	step 84000, loss 0.003937, batch time 0.034502
# 	step 84250, loss 0.006393, batch time 0.001777
# 	step 84500, loss 0.004262, batch time 0.001748
# 	step 84750, loss 0.007898, batch time 0.001976
# 85000/150000: test accuracy: 0.927100
# 	step 85000, loss 0.005404, batch time 0.044998
# 	step 85250, loss 0.001108, batch time 0.003020
# 	step 85500, loss 0.004428, batch time 0.001758
# 	step 85750, loss 0.009817, batch time 0.002138
# 86000/150000: test accuracy: 0.928400
# 	step 86000, loss 0.003985, batch time 0.034961
# 	step 86250, loss 0.003594, batch time 0.001617
# 	step 86500, loss 0.002538, batch time 0.001813
# 	step 86750, loss 0.004658, batch time 0.002234
# 87000/150000: test accuracy: 0.928200
# 	step 87000, loss 0.002947, batch time 0.036445
# 	step 87250, loss 0.008770, batch time 0.001861
# 	step 87500, loss 0.001427, batch time 0.001859
# 	step 87750, loss 0.007758, batch time 0.001911
# 88000/150000: test accuracy: 0.927600
# 	step 88000, loss 0.000990, batch time 0.036804
# 	step 88250, loss 0.003283, batch time 0.001730
# 	step 88500, loss 0.010852, batch time 0.001819
# 	step 88750, loss 0.002986, batch time 0.001774
# 89000/150000: test accuracy: 0.929100
# 	step 89000, loss 0.009115, batch time 0.036753
# 	step 89250, loss 0.003266, batch time 0.001940
# 	step 89500, loss 0.005306, batch time 0.001696
# 	step 89750, loss 0.004276, batch time 0.001880
# 90000/150000: test accuracy: 0.927100
# 	step 90000, loss 0.003120, batch time 0.036279
# 	step 90250, loss 0.000915, batch time 0.001403
# 	step 90500, loss 0.006398, batch time 0.001857
# 	step 90750, loss 0.002308, batch time 0.002277
# 91000/150000: test accuracy: 0.928400
# 	step 91000, loss 0.002323, batch time 0.035971
# 	step 91250, loss 0.002816, batch time 0.001575
# 	step 91500, loss 0.004057, batch time 0.002423
# 	step 91750, loss 0.002767, batch time 0.002052
# 92000/150000: test accuracy: 0.929500
# 	step 92000, loss 0.005040, batch time 0.037396
# 	step 92250, loss 0.006687, batch time 0.001897
# 	step 92500, loss 0.002361, batch time 0.003219
# 	step 92750, loss 0.004923, batch time 0.003618
# 93000/150000: test accuracy: 0.929000
# 	step 93000, loss 0.006372, batch time 0.037553
# 	step 93250, loss 0.000182, batch time 0.002151
# 	step 93500, loss 0.002876, batch time 0.001609
# 	step 93750, loss 0.006194, batch time 0.003407
# 94000/150000: test accuracy: 0.927000
# 	step 94000, loss 0.008313, batch time 0.038435
# 	step 94250, loss 0.002804, batch time 0.004404
# 	step 94500, loss 0.005370, batch time 0.002298
# 	step 94750, loss 0.000841, batch time 0.001790
# 95000/150000: test accuracy: 0.930100
# 	step 95000, loss 0.008899, batch time 0.045529
# 	step 95250, loss 0.001365, batch time 0.003852
# 	step 95500, loss 0.003340, batch time 0.003623
# 	step 95750, loss 0.005717, batch time 0.001652
# 96000/150000: test accuracy: 0.928600
# 	step 96000, loss 0.003567, batch time 0.039969
# 	step 96250, loss 0.003647, batch time 0.001970
# 	step 96500, loss 0.006068, batch time 0.002672
# 	step 96750, loss 0.005701, batch time 0.001541
# 97000/150000: test accuracy: 0.927800
# 	step 97000, loss 0.000780, batch time 0.037874
# 	step 97250, loss 0.008032, batch time 0.001873
# 	step 97500, loss 0.008728, batch time 0.001785
# 	step 97750, loss 0.008507, batch time 0.001931
# 98000/150000: test accuracy: 0.927400
# 	step 98000, loss 0.004470, batch time 0.034961
# 	step 98250, loss 0.000696, batch time 0.003386
# 	step 98500, loss 0.012380, batch time 0.001775
# 	step 98750, loss 0.001485, batch time 0.001923
# 99000/150000: test accuracy: 0.929200
# 	step 99000, loss 0.002297, batch time 0.035054
# 	step 99250, loss 0.003786, batch time 0.001953
# 	step 99500, loss 0.005494, batch time 0.002007
# 	step 99750, loss 0.007900, batch time 0.001948
# 100000/150000: test accuracy: 0.926700
# 	step 100000, loss 0.004922, batch time 0.034054
# 	step 100250, loss 0.009987, batch time 0.001734
# 	step 100500, loss 0.017144, batch time 0.002570
# 	step 100750, loss 0.000753, batch time 0.005153
# 101000/150000: test accuracy: 0.929200
# 	step 101000, loss 0.003082, batch time 0.034117
# 	step 101250, loss 0.001458, batch time 0.001326
# 	step 101500, loss 0.003646, batch time 0.001478
# 	step 101750, loss 0.008326, batch time 0.001889
# 102000/150000: test accuracy: 0.929100
# 	step 102000, loss 0.002884, batch time 0.033835
# 	step 102250, loss 0.000698, batch time 0.002024
# 	step 102500, loss 0.004909, batch time 0.001867
# 	step 102750, loss 0.006217, batch time 0.004202
# 103000/150000: test accuracy: 0.927600
# 	step 103000, loss 0.004328, batch time 0.044117
# 	step 103250, loss 0.003613, batch time 0.004386
# 	step 103500, loss 0.000406, batch time 0.001868
# 	step 103750, loss 0.006720, batch time 0.004209
# 104000/150000: test accuracy: 0.929000
# 	step 104000, loss 0.003209, batch time 0.038511
# 	step 104250, loss 0.005075, batch time 0.001991
# 	step 104500, loss 0.002561, batch time 0.001618
# 	step 104750, loss 0.000653, batch time 0.001650
# 105000/150000: test accuracy: 0.928300
# 	step 105000, loss 0.004928, batch time 0.034437
# 	step 105250, loss 0.006155, batch time 0.001627
# 	step 105500, loss 0.000934, batch time 0.001726
# 	step 105750, loss 0.004435, batch time 0.002446
# 106000/150000: test accuracy: 0.929200
# 	step 106000, loss 0.005985, batch time 0.034855
# 	step 106250, loss 0.004245, batch time 0.002079
# 	step 106500, loss 0.008484, batch time 0.002206
# 	step 106750, loss 0.009204, batch time 0.001938
# 107000/150000: test accuracy: 0.929600
# 	step 107000, loss 0.003434, batch time 0.038057
# 	step 107250, loss 0.002625, batch time 0.001724
# 	step 107500, loss 0.005433, batch time 0.001505
# 	step 107750, loss 0.008680, batch time 0.001827
# 108000/150000: test accuracy: 0.928800
# 	step 108000, loss 0.000955, batch time 0.035997
# 	step 108250, loss 0.002697, batch time 0.001797
# 	step 108500, loss 0.005690, batch time 0.001725
# 	step 108750, loss 0.006435, batch time 0.001890
# 109000/150000: test accuracy: 0.927700
# 	step 109000, loss 0.004851, batch time 0.038715
# 	step 109250, loss 0.001737, batch time 0.007032
# 	step 109500, loss 0.003684, batch time 0.002856
# 	step 109750, loss 0.006923, batch time 0.002985
# 110000/150000: test accuracy: 0.928300
# 	step 110000, loss 0.004193, batch time 0.038945
# 	step 110250, loss 0.006362, batch time 0.002125
# 	step 110500, loss 0.002132, batch time 0.001669
# 	step 110750, loss 0.003114, batch time 0.002019
# 111000/150000: test accuracy: 0.928000
# 	step 111000, loss 0.013408, batch time 0.034755
# 	step 111250, loss 0.005820, batch time 0.001893
# 	step 111500, loss 0.004797, batch time 0.001997
# 	step 111750, loss 0.009202, batch time 0.001651
# 112000/150000: test accuracy: 0.927800
# 	step 112000, loss 0.014106, batch time 0.039576
# 	step 112250, loss 0.003295, batch time 0.002427
# 	step 112500, loss 0.000525, batch time 0.003299
# 	step 112750, loss 0.006995, batch time 0.002442
# 113000/150000: test accuracy: 0.927600
# 	step 113000, loss 0.004614, batch time 0.033910
# 	step 113250, loss 0.006807, batch time 0.002324
# 	step 113500, loss 0.005338, batch time 0.001803
# 	step 113750, loss 0.005269, batch time 0.003367
# 114000/150000: test accuracy: 0.928200
# 	step 114000, loss 0.003596, batch time 0.035345
# 	step 114250, loss 0.001564, batch time 0.001976
# 	step 114500, loss 0.006496, batch time 0.001727
# 	step 114750, loss 0.011846, batch time 0.002162
# 115000/150000: test accuracy: 0.928500
# 	step 115000, loss 0.014936, batch time 0.035103
# 	step 115250, loss 0.008046, batch time 0.001810
# 	step 115500, loss 0.006653, batch time 0.001559
# 	step 115750, loss 0.002364, batch time 0.002081
# 116000/150000: test accuracy: 0.927900
# 	step 116000, loss 0.007878, batch time 0.035802
# 	step 116250, loss 0.001039, batch time 0.001989
# 	step 116500, loss 0.005903, batch time 0.001866
# 	step 116750, loss 0.005897, batch time 0.001899
# 117000/150000: test accuracy: 0.928600
# 	step 117000, loss 0.004998, batch time 0.035711
# 	step 117250, loss 0.001681, batch time 0.002010
# 	step 117500, loss 0.003074, batch time 0.004567
# 	step 117750, loss 0.001679, batch time 0.002327
# 118000/150000: test accuracy: 0.929200
# 	step 118000, loss 0.005036, batch time 0.038536
# 	step 118250, loss 0.018084, batch time 0.002227
# 	step 118500, loss 0.003102, batch time 0.001740
# 	step 118750, loss 0.004783, batch time 0.001952
# 119000/150000: test accuracy: 0.928200
# 	step 119000, loss 0.005331, batch time 0.035386
# 	step 119250, loss 0.008304, batch time 0.001956
# 	step 119500, loss 0.002170, batch time 0.002169
# 	step 119750, loss 0.005098, batch time 0.003575
# 120000/150000: test accuracy: 0.928400
# 	step 120000, loss 0.004581, batch time 0.034983
# 	step 120250, loss 0.004544, batch time 0.001710
# 	step 120500, loss 0.002770, batch time 0.001659
# 	step 120750, loss 0.005007, batch time 0.001613
# 121000/150000: test accuracy: 0.930600
# 	step 121000, loss 0.006780, batch time 0.036396
# 	step 121250, loss 0.001855, batch time 0.001850
# 	step 121500, loss 0.001784, batch time 0.001653
# 	step 121750, loss 0.009024, batch time 0.002833
# 122000/150000: test accuracy: 0.927700
# 	step 122000, loss 0.004644, batch time 0.036895
# 	step 122250, loss 0.002999, batch time 0.001844
# 	step 122500, loss 0.004077, batch time 0.001769
# 	step 122750, loss 0.001439, batch time 0.001931
# 123000/150000: test accuracy: 0.929000
# 	step 123000, loss 0.009290, batch time 0.036733
# 	step 123250, loss 0.004429, batch time 0.001729
# 	step 123500, loss 0.005515, batch time 0.001711
# 	step 123750, loss 0.002560, batch time 0.001912
# 124000/150000: test accuracy: 0.927900
# 	step 124000, loss 0.005917, batch time 0.034003
# 	step 124250, loss 0.000528, batch time 0.001966
# 	step 124500, loss 0.004303, batch time 0.001888
# 	step 124750, loss 0.004498, batch time 0.001708
# 125000/150000: test accuracy: 0.928200
# 	step 125000, loss 0.010664, batch time 0.034070
# 	step 125250, loss 0.010266, batch time 0.001804
# 	step 125500, loss 0.004220, batch time 0.001600
# 	step 125750, loss 0.000682, batch time 0.002899
# 126000/150000: test accuracy: 0.928200
# 	step 126000, loss 0.001744, batch time 0.034272
# 	step 126250, loss 0.000917, batch time 0.002767
# 	step 126500, loss 0.007137, batch time 0.002023
# 	step 126750, loss 0.001803, batch time 0.001795
# 127000/150000: test accuracy: 0.929700
# 	step 127000, loss 0.004221, batch time 0.038859
# 	step 127250, loss 0.012144, batch time 0.001595
# 	step 127500, loss 0.004941, batch time 0.001988
# 	step 127750, loss 0.007834, batch time 0.001815
# 128000/150000: test accuracy: 0.929700
# 	step 128000, loss 0.008682, batch time 0.036896
# 	step 128250, loss 0.008433, batch time 0.002218
# 	step 128500, loss 0.006445, batch time 0.002025
# 	step 128750, loss 0.005651, batch time 0.002394
# 129000/150000: test accuracy: 0.927500
# 	step 129000, loss 0.001812, batch time 0.036548
# 	step 129250, loss 0.004673, batch time 0.001915
# 	step 129500, loss 0.005605, batch time 0.001917
# 	step 129750, loss 0.005858, batch time 0.001903
# 130000/150000: test accuracy: 0.928100
# 	step 130000, loss 0.002563, batch time 0.038920
# 	step 130250, loss 0.006318, batch time 0.001668
# 	step 130500, loss 0.004311, batch time 0.001964
# 	step 130750, loss 0.004079, batch time 0.001784
# 131000/150000: test accuracy: 0.928000
# 	step 131000, loss 0.003542, batch time 0.034900
# 	step 131250, loss 0.006336, batch time 0.001803
# 	step 131500, loss 0.001620, batch time 0.002011
# 	step 131750, loss 0.010394, batch time 0.002130
# 132000/150000: test accuracy: 0.928200
# 	step 132000, loss 0.003375, batch time 0.035814
# 	step 132250, loss 0.003287, batch time 0.001880
# 	step 132500, loss 0.010111, batch time 0.001894
# 	step 132750, loss 0.002358, batch time 0.002078
# 133000/150000: test accuracy: 0.928000
# 	step 133000, loss 0.005366, batch time 0.036736
# 	step 133250, loss 0.003894, batch time 0.001806
# 	step 133500, loss 0.000699, batch time 0.001699
# 	step 133750, loss 0.004513, batch time 0.001688
# 134000/150000: test accuracy: 0.929300
# 	step 134000, loss 0.007361, batch time 0.035161
# 	step 134250, loss 0.002364, batch time 0.001693
# 	step 134500, loss 0.006097, batch time 0.003557
# 	step 134750, loss 0.006473, batch time 0.002294
# 135000/150000: test accuracy: 0.929500
# 	step 135000, loss 0.011950, batch time 0.035989
# 	step 135250, loss 0.005485, batch time 0.002951
# 	step 135500, loss 0.004866, batch time 0.001857
# 	step 135750, loss 0.003460, batch time 0.001931
# 136000/150000: test accuracy: 0.927700
# 	step 136000, loss 0.008492, batch time 0.038511
# 	step 136250, loss 0.004979, batch time 0.001671
# 	step 136500, loss 0.005800, batch time 0.001916
# 	step 136750, loss 0.005074, batch time 0.001969
# 137000/150000: test accuracy: 0.930100
# 	step 137000, loss 0.001734, batch time 0.040697
# 	step 137250, loss 0.004899, batch time 0.002209
# 	step 137500, loss 0.001037, batch time 0.002042
# 	step 137750, loss 0.003125, batch time 0.002021
# 138000/150000: test accuracy: 0.928900
# 	step 138000, loss 0.004645, batch time 0.034921
# 	step 138250, loss 0.007250, batch time 0.002034
# 	step 138500, loss 0.003893, batch time 0.001665
# 	step 138750, loss 0.002208, batch time 0.001922
# 139000/150000: test accuracy: 0.928000
# 	step 139000, loss 0.012683, batch time 0.038852
# 	step 139250, loss 0.007719, batch time 0.002589
# 	step 139500, loss 0.006809, batch time 0.002255
# 	step 139750, loss 0.003061, batch time 0.001841
# 140000/150000: test accuracy: 0.928100
# 	step 140000, loss 0.003838, batch time 0.036158
# 	step 140250, loss 0.004090, batch time 0.001674
# 	step 140500, loss 0.003924, batch time 0.001888
# 	step 140750, loss 0.003192, batch time 0.001965
# 141000/150000: test accuracy: 0.929100
# 	step 141000, loss 0.007164, batch time 0.040889
# 	step 141250, loss 0.000468, batch time 0.001589
# 	step 141500, loss 0.000901, batch time 0.002023
# 	step 141750, loss 0.007820, batch time 0.001889
# 142000/150000: test accuracy: 0.928600
# 	step 142000, loss 0.003345, batch time 0.042302
# 	step 142250, loss 0.004667, batch time 0.002859
# 	step 142500, loss 0.007412, batch time 0.003377
# 	step 142750, loss 0.006931, batch time 0.002826
# 143000/150000: test accuracy: 0.929700
# 	step 143000, loss 0.001133, batch time 0.039321
# 	step 143250, loss 0.004278, batch time 0.001745
# 	step 143500, loss 0.004818, batch time 0.003114
# 	step 143750, loss 0.002964, batch time 0.001682
# 144000/150000: test accuracy: 0.927200
# 	step 144000, loss 0.009021, batch time 0.045309
# 	step 144250, loss 0.003209, batch time 0.002037
# 	step 144500, loss 0.005096, batch time 0.004050
# 	step 144750, loss 0.005515, batch time 0.001534
# 145000/150000: test accuracy: 0.927400
# 	step 145000, loss 0.004842, batch time 0.037201
# 	step 145250, loss 0.006314, batch time 0.001783
# 	step 145500, loss 0.006610, batch time 0.001715
# 	step 145750, loss 0.001648, batch time 0.001937
# 146000/150000: test accuracy: 0.929100
# 	step 146000, loss 0.000853, batch time 0.033495
# 	step 146250, loss 0.004608, batch time 0.002223
# 	step 146500, loss 0.003333, batch time 0.001956
# 	step 146750, loss 0.007843, batch time 0.001848
# 147000/150000: test accuracy: 0.926900
# 	step 147000, loss 0.007806, batch time 0.036332
# 	step 147250, loss 0.005483, batch time 0.001974
# 	step 147500, loss 0.000719, batch time 0.001707
# 	step 147750, loss 0.003170, batch time 0.002547
# 148000/150000: test accuracy: 0.928100
# 	step 148000, loss 0.008339, batch time 0.034352
# 	step 148250, loss 0.004711, batch time 0.001923
# 	step 148500, loss 0.005767, batch time 0.002640
# 	step 148750, loss 0.002479, batch time 0.001603
# 149000/150000: test accuracy: 0.929500
# 	step 149000, loss 0.010700, batch time 0.035725
# 	step 149250, loss 0.001739, batch time 0.001936
# 	step 149500, loss 0.003102, batch time 0.001803
# 	step 149750, loss 0.002052, batch time 0.002024
#
# total runtime: 339.079574 seconds

# %%
feed = {x: mnist.test.images, y_: mnist.test.labels, noise_source: normal_noise, awn_param: 0}
acc = accuracy.eval(feed_dict=feed)
print "final test accuracy: {:3f}".format(acc)
# Out:
# final test accuracy: 0.929600

# %% [markdown]
# ## Plot performance

# %%
plt.figure(0, figsize=(16,4))
plt.subplot(121)
plt.title("Loss")
plt.plot(loss_curve[1:,0], loss_curve[1:,1], 'b-')
plt.subplot(122)
plt.title("Accuracy")
plt.plot(acc_curve[1:,0], acc_curve[1:,1], 'r-')

with open('awn.p', 'w') as f:
    pickle.dump(acc_curve, f)

# %% [markdown]
# ## Plot weights

# %%
normal_noise = np.random.randn(xlen, ylen)
feed = {noise_source: normal_noise, awn_param: 0}
W_ = W.eval(feed_dict=feed)

for i in range(0,10,5):
    img1 = np.reshape(W_[:,i], (28,28))
    img2 = np.reshape(W_[:,i+1], (28,28))
    img3 = np.reshape(W_[:,i+2], (28,28))
    img4 = np.reshape(W_[:,i+3], (28,28))
    img5 = np.reshape(W_[:,i+4], (28,28))
    plt.figure(i, figsize=(16,4))
    plt.subplot(151)
    plt.imshow(img1, cmap=cm.gray)
    plt.subplot(152)
    plt.imshow(img2, cmap=cm.gray)
    plt.subplot(153)
    plt.imshow(img3, cmap=cm.gray)
    plt.subplot(154)
    plt.imshow(img4, cmap=cm.gray)
    plt.subplot(155)
    plt.imshow(img5, cmap=cm.gray)

# %%
normal_noise = np.random.randn(xlen, ylen)
feed = {noise_source: normal_noise, awn_param: 0}
S_ = S.eval(feed_dict=feed)
S_ = np.clip(S_,0,5)
for i in range(0,10,5):
    img1 = np.reshape(S_[:,i], (28,28))
    img2 = np.reshape(S_[:,i+1], (28,28))
    img3 = np.reshape(S_[:,i+2], (28,28))
    img4 = np.reshape(S_[:,i+3], (28,28))
    img5 = np.reshape(S_[:,i+4], (28,28))
    plt.figure(i, figsize=(16,4))
    plt.subplot(151)
    plt.imshow(img1, cmap=cm.gray)
    plt.subplot(152)
    plt.imshow(img2, cmap=cm.gray)
    plt.subplot(153)
    plt.imshow(img3, cmap=cm.gray)
    plt.subplot(154)
    plt.imshow(img4, cmap=cm.gray)
    plt.subplot(155)
    plt.imshow(img5, cmap=cm.gray)

# %%
print np.min(W_), np.max(W_), "\n", W_
# Out:
# 5.78272e-07 3.23439
# [[ 0.38362896  0.40658948  0.37953022 ...,  0.38933724  0.41178477
#    0.35187897]
#  [ 0.43885198  0.39484674  0.36036855 ...,  0.35683849  0.3578321
#    0.34337434]
#  [ 0.38985217  0.40301123  0.41275877 ...,  0.36767     0.36992842
#    0.39526299]
#  ...,
#  [ 0.37643221  0.40680289  0.41744515 ...,  0.43124542  0.4051252
#    0.3954227 ]
#  [ 0.4114894   0.39450333  0.41274568 ...,  0.39349276  0.41217601
#    0.38372904]
#  [ 0.39516264  0.39263311  0.3884488  ...,  0.45330378  0.37757951
#    0.38867572]]

# %%
print np.min(S_), np.max(S_), "\n", S_
# Out:
# 0.123159 10.0
# [[ 1.03925633  0.98099685  1.05011463 ...,  1.02439988  0.96823853
#    1.12864387]
#  [ 0.90173328  1.01032138  1.1034286  ...,  1.11378086  1.11084843
#    1.15506673]
#  [ 1.02307379  0.98984998  0.96585655 ...,  1.08257174  1.07626247
#    1.00926709]
#  ...,
#  [ 1.05843747  0.98047072  0.95442367 ...,  0.92071128  0.98461229
#    1.00886297]
#  [ 0.96896154  1.01119208  0.9658885  ...,  1.01375949  0.9672814
#    1.03899324]
#  [ 1.00952113  1.01594949  1.02669311 ...,  0.86303389  1.05534315
#    1.02610672]]

# %% [markdown]
# ## Saver IO

# %%
# saver = tf.train.Saver(tf.all_variables())
# load_was_success = True # yes, I'm being optimistic
# try:
#     save_dir = '/'.join(save_path.split('/')[:-1])
#     ckpt = tf.train.get_checkpoint_state(save_dir)
#     load_path = ckpt.model_checkpoint_path
#     saver.restore(sess, load_path)
# except:
#     print "no saved model to load. starting new session"
#     load_was_success = False
# else:
#     print "loaded model: {}".format(load_path)
#     saver = tf.train.Saver(tf.all_variables())
#     global_step = int(load_path.split('-')[-1])

# %%
# #fc 1 layer
# W1 = tf.get_variable("W1", shape=[xlen,ylen], initializer=init)
# b1 = tf.get_variable("b1", shape=[ylen], initializer=init)
# output = tf.nn.softmax(tf.matmul(x, W1) + b1)
