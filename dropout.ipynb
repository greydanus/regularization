# %% [markdown]
# # Dropout Regularization

# %%
import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

import time
import cPickle as pickle
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ## Model baseline

# %%
batch_size = 32
global_step = 0
save_path = 'models/drop.ckpt'
xlen = 28*28
ylen = 10

train_steps = 150000
info_every = 250
test_every = 1000

# %% [markdown]
# ## Build model

# %%
#awn
tf.reset_default_graph()
sess = tf.InteractiveSession()

x = tf.placeholder(tf.float32, shape=[None, xlen], name="x")
y_ = tf.placeholder(tf.float32, shape=[None, ylen], name="y_")
init = tf.truncated_normal_initializer(mean=0., stddev=.075, seed=1234, dtype=tf.float32)

W = tf.get_variable("W", shape=[xlen,ylen], initializer=init)
x_drop = tf.nn.dropout(x, 0.5)

output = tf.nn.softmax(tf.matmul(x_drop, W))
sess.run(tf.initialize_all_variables())

# %%
loss = tf.nn.l2_loss( y_ - output ) / (ylen*batch_size)

optimizer = tf.train.AdamOptimizer(1e-4)
grads = optimizer.compute_gradients(loss, var_list=tf.trainable_variables())
train_op = optimizer.apply_gradients(grads)

sess.run(tf.initialize_all_variables())

# %% [markdown]
# ## Model overview

# %%
total_parameters = 0 ; print "Model overview:"
for variable in tf.trainable_variables():
    shape = variable.get_shape()
    variable_parameters = 1
    for dim in shape:
        variable_parameters *= dim.value
    print '\tvariable "{}" has {} parameters' \
        .format(variable.name, variable_parameters)
    total_parameters += variable_parameters
print "Total of {} parameters".format(total_parameters)
# Out:
# Model overview:
# 	variable "W:0" has 7840 parameters
# Total of 7840 parameters

# %% [markdown]
# ## Train

# %%
correct_prediction = tf.equal(tf.argmax(output,1), tf.argmax(y_,1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
loss_curve = np.zeros((train_steps/info_every, 2))
acc_curve = np.zeros((train_steps/test_every, 2))

begin = time.time()
for i in range(train_steps):
    batch_start = time.time()
    
    batch = mnist.train.next_batch(batch_size)
    feed = {x: batch[0], y_: batch[1]}
    train_loss, _ = sess.run([loss, train_op], feed_dict=feed)
    
    if i%test_every == 0:
        feed = {x: mnist.test.images, y_: mnist.test.labels}
        acc = accuracy.eval(feed_dict=feed)
        acc_curve[i/test_every,:] = [i, acc]
        print "{}/{}: test accuracy: {:3f}".format(i, train_steps, acc)
    if i%info_every == 0:
        loss_curve[i/info_every,:] = [i, train_loss]
        print "\tstep {}, loss {:3f}, batch time {:3f}".format(i, train_loss, time.time()-batch_start)
print "\ntotal runtime: {:3f} seconds".format(time.time()-begin)
# Out:
# 0/150000: test accuracy: 0.098100
# 	step 0, loss 0.050993, batch time 0.173727
# 	step 250, loss 0.040151, batch time 0.001777
# 	step 500, loss 0.034540, batch time 0.001522
# 	step 750, loss 0.035571, batch time 0.001996
# 1000/150000: test accuracy: 0.654200
# 	step 1000, loss 0.024043, batch time 0.171356
# 	step 1250, loss 0.023260, batch time 0.001543
# 	step 1500, loss 0.020505, batch time 0.001473
# 	step 1750, loss 0.014330, batch time 0.001242
# 2000/150000: test accuracy: 0.768200
# 	step 2000, loss 0.024105, batch time 0.151108
# 	step 2250, loss 0.017532, batch time 0.001975
# 	step 2500, loss 0.016901, batch time 0.001835
# 	step 2750, loss 0.011447, batch time 0.002456
# 3000/150000: test accuracy: 0.809800
# 	step 3000, loss 0.015326, batch time 0.187707
# 	step 3250, loss 0.018588, batch time 0.002370
# 	step 3500, loss 0.013244, batch time 0.001698
# 	step 3750, loss 0.015302, batch time 0.002163
# 4000/150000: test accuracy: 0.832400
# 	step 4000, loss 0.009897, batch time 0.232553
# 	step 4250, loss 0.011483, batch time 0.002715
# 	step 4500, loss 0.014149, batch time 0.001630
# 	step 4750, loss 0.015691, batch time 0.002256
# 5000/150000: test accuracy: 0.844000
# 	step 5000, loss 0.014071, batch time 0.273243
# 	step 5250, loss 0.009538, batch time 0.002207
# 	step 5500, loss 0.016731, batch time 0.001313
# 	step 5750, loss 0.015054, batch time 0.001506
# 6000/150000: test accuracy: 0.848700
# 	step 6000, loss 0.010686, batch time 0.198831
# 	step 6250, loss 0.011477, batch time 0.001413
# 	step 6500, loss 0.010677, batch time 0.001875
# 	step 6750, loss 0.014246, batch time 0.001693
# 7000/150000: test accuracy: 0.853300
# 	step 7000, loss 0.011731, batch time 0.181056
# 	step 7250, loss 0.011827, batch time 0.002009
# 	step 7500, loss 0.008376, batch time 0.001642
# 	step 7750, loss 0.014296, batch time 0.001853
# 8000/150000: test accuracy: 0.860500
# 	step 8000, loss 0.009729, batch time 0.202922
# 	step 8250, loss 0.009759, batch time 0.001917
# 	step 8500, loss 0.008396, batch time 0.001353
# 	step 8750, loss 0.009443, batch time 0.001402
# 9000/150000: test accuracy: 0.865800
# 	step 9000, loss 0.008744, batch time 0.198602
# 	step 9250, loss 0.018473, batch time 0.001329
# 	step 9500, loss 0.011557, batch time 0.002236
# 	step 9750, loss 0.010689, batch time 0.001621
# 10000/150000: test accuracy: 0.869000
# 	step 10000, loss 0.006148, batch time 0.161907
# 	step 10250, loss 0.013078, batch time 0.001814
# 	step 10500, loss 0.009720, batch time 0.001429
# 	step 10750, loss 0.009750, batch time 0.001944
# 11000/150000: test accuracy: 0.871800
# 	step 11000, loss 0.005705, batch time 0.196971
# 	step 11250, loss 0.013102, batch time 0.001941
# 	step 11500, loss 0.015649, batch time 0.002792
# 	step 11750, loss 0.009806, batch time 0.001650
# 12000/150000: test accuracy: 0.870000
# 	step 12000, loss 0.014261, batch time 0.183692
# 	step 12250, loss 0.012030, batch time 0.001492
# 	step 12500, loss 0.011876, batch time 0.001492
# 	step 12750, loss 0.013343, batch time 0.001832
# 13000/150000: test accuracy: 0.873600
# 	step 13000, loss 0.010783, batch time 0.159132
# 	step 13250, loss 0.011560, batch time 0.001687
# 	step 13500, loss 0.013549, batch time 0.001612
# 	step 13750, loss 0.010924, batch time 0.001375
# 14000/150000: test accuracy: 0.876000
# 	step 14000, loss 0.005641, batch time 0.167807
# 	step 14250, loss 0.006173, batch time 0.001497
# 	step 14500, loss 0.018942, batch time 0.001453
# 	step 14750, loss 0.006674, batch time 0.001501
# 15000/150000: test accuracy: 0.873400
# 	step 15000, loss 0.009180, batch time 0.196644
# 	step 15250, loss 0.008614, batch time 0.001550
# 	step 15500, loss 0.009630, batch time 0.001318
# 	step 15750, loss 0.014147, batch time 0.001257
# 16000/150000: test accuracy: 0.877200
# 	step 16000, loss 0.013894, batch time 0.160651
# 	step 16250, loss 0.006806, batch time 0.001493
# 	step 16500, loss 0.009963, batch time 0.011665
# 	step 16750, loss 0.013630, batch time 0.001671
# 17000/150000: test accuracy: 0.879700
# 	step 17000, loss 0.008019, batch time 0.178444
# 	step 17250, loss 0.013209, batch time 0.001633
# 	step 17500, loss 0.007169, batch time 0.001480
# 	step 17750, loss 0.013630, batch time 0.001331
# 18000/150000: test accuracy: 0.880000
# 	step 18000, loss 0.010197, batch time 0.174046
# 	step 18250, loss 0.013733, batch time 0.001475
# 	step 18500, loss 0.009530, batch time 0.001835
# 	step 18750, loss 0.011444, batch time 0.002151
# 19000/150000: test accuracy: 0.879600
# 	step 19000, loss 0.010187, batch time 0.162051
# 	step 19250, loss 0.004943, batch time 0.001979
# 	step 19500, loss 0.004787, batch time 0.001474
# 	step 19750, loss 0.003932, batch time 0.001979
# 20000/150000: test accuracy: 0.879200
# 	step 20000, loss 0.008691, batch time 0.223503
# 	step 20250, loss 0.005513, batch time 0.001475
# 	step 20500, loss 0.011099, batch time 0.001584
# 	step 20750, loss 0.009489, batch time 0.001439
# 21000/150000: test accuracy: 0.881800
# 	step 21000, loss 0.008478, batch time 0.158821
# 	step 21250, loss 0.011133, batch time 0.001403
# 	step 21500, loss 0.010470, batch time 0.001648
# 	step 21750, loss 0.008054, batch time 0.001855
# 22000/150000: test accuracy: 0.880800
# 	step 22000, loss 0.010373, batch time 0.173252
# 	step 22250, loss 0.014042, batch time 0.001258
# 	step 22500, loss 0.011803, batch time 0.001124
# 	step 22750, loss 0.014300, batch time 0.001663
# 23000/150000: test accuracy: 0.882200
# 	step 23000, loss 0.011998, batch time 0.177590
# 	step 23250, loss 0.009642, batch time 0.001495
# 	step 23500, loss 0.006586, batch time 0.001568
# 	step 23750, loss 0.005897, batch time 0.001477
# 24000/150000: test accuracy: 0.882400
# 	step 24000, loss 0.006459, batch time 0.183013
# 	step 24250, loss 0.002710, batch time 0.001302
# 	step 24500, loss 0.004733, batch time 0.001638
# 	step 24750, loss 0.006534, batch time 0.001587
# 25000/150000: test accuracy: 0.874300
# 	step 25000, loss 0.008112, batch time 0.156247
# 	step 25250, loss 0.007499, batch time 0.001857
# 	step 25500, loss 0.007104, batch time 0.001408
# 	step 25750, loss 0.007546, batch time 0.001490
# 26000/150000: test accuracy: 0.884100
# 	step 26000, loss 0.008416, batch time 0.200013
# 	step 26250, loss 0.002901, batch time 0.002447
# 	step 26500, loss 0.010243, batch time 0.001559
# 	step 26750, loss 0.003168, batch time 0.001399
# 27000/150000: test accuracy: 0.884700
# 	step 27000, loss 0.005173, batch time 0.187684
# 	step 27250, loss 0.006856, batch time 0.001499
# 	step 27500, loss 0.005165, batch time 0.001317
# 	step 27750, loss 0.009474, batch time 0.001501
# 28000/150000: test accuracy: 0.886500
# 	step 28000, loss 0.013032, batch time 0.157178
# 	step 28250, loss 0.015384, batch time 0.001392
# 	step 28500, loss 0.004416, batch time 0.001370
# 	step 28750, loss 0.007646, batch time 0.002255
# 29000/150000: test accuracy: 0.884200
# 	step 29000, loss 0.008404, batch time 0.241582
# 	step 29250, loss 0.005501, batch time 0.002628
# 	step 29500, loss 0.004644, batch time 0.002255
# 135000/150000: test accuracy: 0.894300
# 	step 135000, loss 0.005416, batch time 0.170168
# 	step 135250, loss 0.009087, batch time 0.001640
# 	step 135500, loss 0.009415, batch time 0.001901
# 	step 135750, loss 0.007880, batch time 0.001687
# 136000/150000: test accuracy: 0.893900
# 	step 136000, loss 0.009985, batch time 0.160025
# 	step 136250, loss 0.002403, batch time 0.001821
# 	step 136500, loss 0.006931, batch time 0.001395
# 	step 136750, loss 0.008425, batch time 0.001447
# 137000/150000: test accuracy: 0.890400
# 	step 137000, loss 0.010651, batch time 0.190804
# 	step 137250, loss 0.005834, batch time 0.001280
# 	step 137500, loss 0.007603, batch time 0.001502
# 	step 137750, loss 0.004915, batch time 0.001396
# 138000/150000: test accuracy: 0.894300
# 	step 138000, loss 0.010313, batch time 0.158548
# 	step 138250, loss 0.009241, batch time 0.001525
# 	step 138500, loss 0.007346, batch time 0.001289
# 	step 138750, loss 0.012470, batch time 0.001451
# 139000/150000: test accuracy: 0.888600
# 	step 139000, loss 0.003863, batch time 0.179479
# 	step 139250, loss 0.006110, batch time 0.001378
# 	step 139500, loss 0.009328, batch time 0.001233
# 	step 139750, loss 0.008502, batch time 0.001958
# 140000/150000: test accuracy: 0.895000
# 	step 140000, loss 0.011299, batch time 0.161986
# 	step 140250, loss 0.008164, batch time 0.001746
# 	step 140500, loss 0.012314, batch time 0.001494
# 	step 140750, loss 0.003296, batch time 0.001543
# 141000/150000: test accuracy: 0.889600
# 	step 141000, loss 0.012814, batch time 0.159804
# 	step 141250, loss 0.009805, batch time 0.001624
# 	step 141500, loss 0.010136, batch time 0.001586
# 	step 141750, loss 0.005376, batch time 0.001422
# 142000/150000: test accuracy: 0.891800
# 	step 142000, loss 0.006165, batch time 0.175586
# 	step 142250, loss 0.016640, batch time 0.001431
# 	step 142500, loss 0.009324, batch time 0.001170
# 	step 142750, loss 0.008654, batch time 0.001453
# 143000/150000: test accuracy: 0.889800
# 	step 143000, loss 0.009330, batch time 0.151123
# 	step 143250, loss 0.012464, batch time 0.001635
# 	step 143500, loss 0.009511, batch time 0.001129
# 	step 143750, loss 0.009337, batch time 0.001677
# 144000/150000: test accuracy: 0.893400
# 	step 144000, loss 0.005818, batch time 0.176612
# 	step 144250, loss 0.004627, batch time 0.001215
# 	step 144500, loss 0.002242, batch time 0.001446
# 	step 144750, loss 0.019354, batch time 0.001482
# 145000/150000: test accuracy: 0.893100
# 	step 145000, loss 0.006259, batch time 0.166809
# 	step 145250, loss 0.007163, batch time 0.001429
# 	step 145500, loss 0.001045, batch time 0.001478
# 	step 145750, loss 0.013418, batch time 0.001475
# 146000/150000: test accuracy: 0.891400
# 	step 146000, loss 0.013831, batch time 0.154720
# 	step 146250, loss 0.013211, batch time 0.001831
# 	step 146500, loss 0.006103, batch time 0.001370
# 	step 146750, loss 0.005920, batch time 0.001277
# 147000/150000: test accuracy: 0.894900
# 	step 147000, loss 0.006041, batch time 0.164954
# 	step 147250, loss 0.012117, batch time 0.001547
# 	step 147500, loss 0.004159, batch time 0.001404
# 	step 147750, loss 0.002613, batch time 0.001260
# 148000/150000: test accuracy: 0.893700
# 	step 148000, loss 0.006935, batch time 0.154204
# 	step 148250, loss 0.001438, batch time 0.001691
# 	step 148500, loss 0.007656, batch time 0.001312
# 	step 148750, loss 0.007632, batch time 0.001653
# 149000/150000: test accuracy: 0.895700
# 	step 149000, loss 0.005683, batch time 0.163486
# 	step 149250, loss 0.005870, batch time 0.002844
# 	step 149500, loss 0.009099, batch time 0.001415
# 	step 149750, loss 0.002951, batch time 0.002175
#
# total runtime: 299.226150 seconds

# %%
feed = {x: mnist.test.images, y_: mnist.test.labels}
acc = accuracy.eval(feed_dict=feed)
print "final test accuracy: {:3f}".format(acc)
# Out:
# final test accuracy: 0.890300

# %% [markdown]
# ## Plot performance

# %%
plt.figure(0, figsize=(16,4))
plt.subplot(121)
plt.title("Loss")
plt.plot(loss_curve[1:,0], loss_curve[1:,1], 'b-')
plt.subplot(122)
plt.title("Accuracy")
plt.plot(acc_curve[1:,0], acc_curve[1:,1], 'r-')

with open('drop.p', 'w') as f:
    pickle.dump(acc_curve, f)

# %% [markdown]
# ## Plot weights

# %%
W_ = W.eval()
for i in range(0,10,5):
    img1 = np.reshape(W_[:,i], (28,28))
    img2 = np.reshape(W_[:,i+1], (28,28))
    img3 = np.reshape(W_[:,i+2], (28,28))
    img4 = np.reshape(W_[:,i+3], (28,28))
    img5 = np.reshape(W_[:,i+4], (28,28))
    plt.figure(i, figsize=(16,4))
    plt.subplot(151)
    plt.imshow(img1, cmap=cm.gray)
    plt.subplot(152)
    plt.imshow(img2, cmap=cm.gray)
    plt.subplot(153)
    plt.imshow(img3, cmap=cm.gray)
    plt.subplot(154)
    plt.imshow(img4, cmap=cm.gray)
    plt.subplot(155)
    plt.imshow(img5, cmap=cm.gray)

# %%
print np.min(W_), np.max(W_), "\n", W_
# Out:
# -1.41672 1.20642
# [[-0.00069543  0.10616847  0.14442869 ...,  0.02159248  0.01485336
#    0.00361652]
#  [-0.01920345 -0.1181918  -0.01577493 ...,  0.01301968  0.1056585
#   -0.06576784]
#  [ 0.00270616  0.02949165  0.12064238 ..., -0.11946047  0.02407905
#    0.03926005]
#  ...,
#  [ 0.06655551 -0.10019524  0.05699619 ...,  0.04986557 -0.03840929
#   -0.03092184]
#  [-0.07648222  0.08235262  0.12059913 ..., -0.06768475  0.00258058
#    0.04289221]
#  [-0.04916897  0.0642411  -0.01822088 ...,  0.07932158 -0.03541511
#    0.00911945]]

# %% [markdown]
# ## Saver IO

# %%
# saver = tf.train.Saver(tf.all_variables())
# load_was_success = True # yes, I'm being optimistic
# try:
#     save_dir = '/'.join(save_path.split('/')[:-1])
#     ckpt = tf.train.get_checkpoint_state(save_dir)
#     load_path = ckpt.model_checkpoint_path
#     saver.restore(sess, load_path)
# except:
#     print "no saved model to load. starting new session"
#     load_was_success = False
# else:
#     print "loaded model: {}".format(load_path)
#     saver = tf.train.Saver(tf.all_variables())
#     global_step = int(load_path.split('-')[-1])

# %%
# #fc 1 layer
# W1 = tf.get_variable("W1", shape=[xlen,ylen], initializer=init)
# b1 = tf.get_variable("b1", shape=[ylen], initializer=init)
# output = tf.nn.softmax(tf.matmul(x, W1) + b1)
